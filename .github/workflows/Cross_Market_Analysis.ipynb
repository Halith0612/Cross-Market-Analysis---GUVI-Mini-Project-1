# %% [markdown]
# --------------------------------------------------------------------------------
# # **Author** : ***Mohamed Halith M K***
# ## **Title**  : ***Cross Market Analysis***
# ### ***GUVI Mini Project - 1***
# --------------------------------------------------------------------------------

# %% [markdown]
# # Data Collection

# %%
import requests
import time
import pandas as pd

# %%
data_crypto = []

for page_num in range(1,6):
  url = f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page=1&sparkline=False"
  response = requests.get(url)
  if response.status_code == 200:
    data_crypto.extend(response.json()) # Extend the list with data from current page
    print(f"Collected data from page {page_num}")
  else:
    print(f"Error collecting data from page {page_num}: {response.status_code}")
    page_num += 1
  time.sleep(5) # Increased wait time to 1 second to avoid rate limiting

print ("==========================================")
print(f"Total data collected: {len(data_crypto)}")
# Out:
# Collected data from page 1
# Collected data from page 2
# Collected data from page 3
# Collected data from page 4
# Collected data from page 5
# ==========================================
# Total data collected: 1250

# %%
import pprint

# %%
pprint.pprint(data_crypto)
# Out:
# Streaming output truncated to the last 5000 lines.
#   'market_cap': 131971891489,
#   'market_cap_change_24h': 886664570,
#   'market_cap_change_percentage_24h': 0.6764,
#   'market_cap_rank': 60,
#   'max_supply': 2000000000.0,
#   'name': 'Bitget Token',
#   'price_change_24h': 1.27,
#   'price_change_percentage_24h': 0.67635,
#   'roi': None,
#   'symbol': 'bgb',
#   'total_supply': 913931280.9787906,
#   'total_volume': 1333691748},
#  {'ath': 96.87,
#   'ath_change_percentage': -1.35307,
#   'ath_date': '2026-05-20T14:15:46.804Z',
#   'atl': 86.85,
#   'atl_change_percentage': 10.03244,
#   'atl_date': '2025-08-19T09:52:03.013Z',
#   'circulating_supply': 1320000000.0,
#   'current_price': 95.56,
#   'fully_diluted_valuation': 126136257990,
#   'high_24h': 95.57,
#   'id': 'bfusd',
#   'image': 'https://coin-images.coingecko.com/coins/images/68227/large/bfusd.png?1755132827',
#   'last_updated': '2026-05-24T15:50:44.955Z',
#   'low_24h': 95.54,
#   'market_cap': 126136257990,
#   'market_cap_change_24h': -11579478.175567627,
#   'market_cap_change_percentage_24h': -0.00918,
#   'market_cap_rank': 61,
#   'max_supply': None,
#   'name': 'BFUSD',
#   'price_change_24h': 0.00053679,
#   'price_change_percentage_24h': 0.00056,
#   'roi': None,
#   'symbol': 'bfusd',
#   'total_supply': 1320000000.0,
#   'total_volume': 26017132},
#  {'ath': 48387,
#   'ath_change_percentage': -83.03395,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 1933.39,
#   'atl_change_percentage': 324.61262,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'circulating_supply': 15179911.874935383,
#   'current_price': 8209.31,
#   'fully_diluted_valuation': 131320785241,
#   'high_24h': 8483.17,
#   'id': 'aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'last_updated': '2026-05-24T15:50:41.332Z',
#   'low_24h': 8146.8,
#   'market_cap': 124589871707,
#   'market_cap_change_24h': 994394199,
#   'market_cap_change_percentage_24h': 0.80456,
#   'market_cap_rank': 62,
#   'max_supply': 16000000.0,
#   'name': 'Aave',
#   'price_change_24h': 61.1,
#   'price_change_percentage_24h': 0.74982,
#   'roi': None,
#   'symbol': 'aave',
#   'total_supply': 16000000.0,
#   'total_volume': 14589508807},
#  {'ath': 31427,
#   'ath_change_percentage': -75.70164,
#   'ath_date': '2021-09-11T09:15:00.668Z',
#   'atl': 15.06,
#   'atl_change_percentage': 50606.10272,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'circulating_supply': 14544176.164081175,
#   'current_price': 7635.99,
#   'fully_diluted_valuation': 111554661270,
#   'high_24h': 7994.03,
#   'id': 'quant-network',
#   'image': 'https://coin-images.coingecko.com/coins/images/3370/large/5ZOu7brX_400x400.jpg?1696504070',
#   'last_updated': '2026-05-24T15:50:42.789Z',
#   'low_24h': 7328.71,
#   'market_cap': 111033117034,
#   'market_cap_change_24h': 2331316968,
#   'market_cap_change_percentage_24h': 2.14469,
#   'market_cap_rank': 63,
#   'max_supply': 14612493.0,
#   'name': 'Quant',
#   'price_change_24h': 179.3,
#   'price_change_percentage_24h': 2.40454,
#   'roi': {'currency': 'eth',
#           'percentage': 1538.6860900415477,
#           'times': 15.386860900415478},
#   'symbol': 'qnt',
#   'total_supply': 14612493.0,
#   'total_volume': 1964770461},
#  {'ath': 96.94,
#   'ath_change_percentage': -1.34173,
#   'ath_date': '2026-05-20T14:15:56.839Z',
#   'atl': 77.41,
#   'atl_change_percentage': 23.55274,
#   'atl_date': '2025-07-17T08:05:52.672Z',
#   'circulating_supply': 1089208402.796182,
#   'current_price': 95.64,
#   'fully_diluted_valuation': 104166724701,
#   'high_24h': 95.66,
#   'id': 'usdtb',
#   'image': 'https://coin-images.coingecko.com/coins/images/52804/large/76357aa8-4ef7-446c-bad3-a3f944eeec7a.jpeg?1758277468',
#   'last_updated': '2026-05-24T15:50:43.916Z',
#   'low_24h': 95.6,
#   'market_cap': 104166724701,
#   'market_cap_change_24h': 39011703,
#   'market_cap_change_percentage_24h': 0.03747,
#   'market_cap_rank': 64,
#   'max_supply': None,
#   'name': 'USDtb',
#   'price_change_24h': 0.03903312,
#   'price_change_percentage_24h': 0.04083,
#   'roi': None,
#   'symbol': 'usdtb',
#   'total_supply': 1089208402.796182,
#   'total_volume': 100005078},
#  {'ath': 2158.41,
#   'ath_change_percentage': -64.38301,
#   'ath_date': '2021-12-01T15:09:35.541Z',
#   'atl': 24.48,
#   'atl_change_percentage': 3040.14819,
#   'atl_date': '2019-02-13T00:00:00.000Z',
#   'circulating_supply': 134655021.7355671,
#   'current_price': 768.69,
#   'fully_diluted_valuation': 109243693470,
#   'high_24h': 779.01,
#   'id': 'kucoin-shares',
#   'image': 'https://coin-images.coingecko.com/coins/images/1047/large/sa9z79.png?1696502152',
#   'last_updated': '2026-05-24T15:50:40.738Z',
#   'low_24h': 753.85,
#   'market_cap': 103480072242,
#   'market_cap_change_24h': 1783997743,
#   'market_cap_change_percentage_24h': 1.75424,
#   'market_cap_rank': 65,
#   'max_supply': None,
#   'name': 'KuCoin',
#   'price_change_24h': 13.54,
#   'price_change_percentage_24h': 1.79331,
#   'roi': None,
#   'symbol': 'kcs',
#   'total_supply': 142155021.7355671,
#   'total_volume': 257282156},
#  {'ath': 118.63,
#   'ath_change_percentage': -1.50318,
#   'ath_date': '2026-05-21T01:00:19.118Z',
#   'atl': 84.72,
#   'atl_change_percentage': 37.92456,
#   'atl_date': '2024-08-20T06:40:12.965Z',
#   'circulating_supply': 866127792.27097,
#   'current_price': 116.84,
#   'fully_diluted_valuation': 101201254851,
#   'high_24h': 116.84,
#   'id': 'eutbl',
#   'image': 'https://coin-images.coingecko.com/coins/images/39657/large/EUTBL.png?1723517425',
#   'last_updated': '2026-05-24T15:40:18.683Z',
#   'low_24h': 116.84,
#   'market_cap': 101201254851,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 66,
#   'max_supply': None,
#   'name': 'Spiko EU T-Bills Money Market Fund',
#   'price_change_24h': -1.4211e-14,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'eutbl',
#   'total_supply': 866127792.27097,
#   'total_volume': None},
#  {'ath': 3233.07,
#   'ath_change_percentage': -93.91577,
#   'ath_date': '2022-01-17T00:00:00.000Z',
#   'atl': 87.61,
#   'atl_change_percentage': 124.51914,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'circulating_supply': 510310254.147613,
#   'current_price': 196.46,
#   'fully_diluted_valuation': 100316438756,
#   'high_24h': 204.55,
#   'id': 'cosmos',
#   'image': 'https://coin-images.coingecko.com/coins/images/1481/large/cosmos_hub.png?1696502525',
#   'last_updated': '2026-05-24T15:50:41.944Z',
#   'low_24h': 195.95,
#   'market_cap': 100314901809,
#   'market_cap_change_24h': -527758611.0467987,
#   'market_cap_change_percentage_24h': -0.52335,
#   'market_cap_rank': 67,
#   'max_supply': None,
#   'name': 'Cosmos Hub',
#   'price_change_24h': -1.2652485574532761,
#   'price_change_percentage_24h': -0.63989,
#   'roi': {'currency': 'usd',
#           'percentage': 1952.895911391896,
#           'times': 19.52895911391896},
#   'symbol': 'atom',
#   'total_supply': 510318072.721986,
#   'total_volume': 3256036587},
#  {'ath': 971.56,
#   'ath_change_percentage': -97.04911,
#   'ath_date': '2024-03-10T00:10:42.330Z',
#   'atl': 22.04,
#   'atl_change_percentage': 30.08748,
#   'atl_date': '2026-05-02T05:30:44.240Z',
#   'circulating_supply': 3414545758.127662,
#   'current_price': 28.86,
#   'fully_diluted_valuation': 288526425980,
#   'high_24h': 29.71,
#   'id': 'worldcoin-wld',
#   'image': 'https://coin-images.coingecko.com/coins/images/31069/large/worldcoin.jpeg?1696529903',
#   'last_updated': '2026-05-24T15:50:42.633Z',
#   'low_24h': 26.8,
#   'market_cap': 98518668394,
#   'market_cap_change_24h': 6679048642,
#   'market_cap_change_percentage_24h': 7.27251,
#   'market_cap_rank': 68,
#   'max_supply': 10000000000.0,
#   'name': 'Worldcoin',
#   'price_change_24h': 1.94,
#   'price_change_percentage_24h': 7.22192,
#   'roi': None,
#   'symbol': 'wld',
#   'total_supply': 10000000000.0,
#   'total_volume': 22483575602},
#  {'ath': 97.11,
#   'ath_change_percentage': -1.4453,
#   'ath_date': '2026-05-21T00:55:29.223Z',
#   'atl': 86.73,
#   'atl_change_percentage': 10.35314,
#   'atl_date': '2025-12-21T00:47:20.303Z',
#   'circulating_supply': 1027858682.01,
#   'current_price': 95.61,
#   'fully_diluted_valuation': 98310690334,
#   'high_24h': 95.83,
#   'id': 'united-stables',
#   'image': 'https://coin-images.coingecko.com/coins/images/71157/large/united-stables-logo.jpg?1766061640',
#   'last_updated': '2026-05-24T15:50:26.041Z',
#   'low_24h': 95.29,
#   'market_cap': 98310690334,
#   'market_cap_change_24h': -53757997.33546448,
#   'market_cap_change_percentage_24h': -0.05465,
#   'market_cap_rank': 69,
#   'max_supply': None,
#   'name': 'United Stables',
#   'price_change_24h': -0.08506152615230178,
#   'price_change_percentage_24h': -0.08888,
#   'roi': None,
#   'symbol': 'u',
#   'total_supply': 1027858682.01,
#   'total_volume': 17032050473},
#  {'ath': 1121.89,
#   'ath_change_percentage': -83.33128,
#   'ath_date': '2024-03-17T16:30:24.636Z',
#   'atl': 2.79,
#   'atl_change_percentage': 6602.69334,
#   'atl_date': '2020-06-16T13:22:25.900Z',
#   'circulating_supply': 518743261.0140742,
#   'current_price': 187.47,
#   'fully_diluted_valuation': 99977328025,
#   'high_24h': 193.02,
#   'id': 'render-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11636/large/rndr.png?1696511529',
#   'last_updated': '2026-05-24T15:50:41.096Z',
#   'low_24h': 178.68,
#   'market_cap': 97211305183,
#   'market_cap_change_24h': 4203131627,
#   'market_cap_change_percentage_24h': 4.5191,
#   'market_cap_rank': 70,
#   'max_supply': 644245094.0,
#   'name': 'Render',
#   'price_change_24h': 7.99,
#   'price_change_percentage_24h': 4.45306,
#   'roi': None,
#   'symbol': 'render',
#   'total_supply': 533503434.2940742,
#   'total_volume': 8415390519},
#  {'ath': 247.29,
#   'ath_change_percentage': -95.6615,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 7.26,
#   'atl_change_percentage': 47.87824,
#   'atl_date': '2023-09-11T19:42:08.247Z',
#   'circulating_supply': 8917352824.722261,
#   'current_price': 10.73,
#   'fully_diluted_valuation': 95672433907,
#   'high_24h': 11.13,
#   'id': 'algorand',
#   'image': 'https://coin-images.coingecko.com/coins/images/4380/large/download.png?1696504978',
#   'last_updated': '2026-05-24T15:50:43.807Z',
#   'low_24h': 10.69,
#   'market_cap': 95670090709,
#   'market_cap_change_24h': -486979416.9368744,
#   'market_cap_change_percentage_24h': -0.50644,
#   'market_cap_rank': 71,
#   'max_supply': 10000000000.0,
#   'name': 'Algorand',
#   'price_change_24h': -0.05853485939745262,
#   'price_change_percentage_24h': -0.5424,
#   'roi': {'currency': 'usd',
#           'percentage': -95.3269147815317,
#           'times': -0.9532691478153169},
#   'symbol': 'algo',
#   'total_supply': 8917571232.868385,
#   'total_volume': 2457034921},
#  {'ath': 1075.49,
#   'ath_change_percentage': -1.32153,
#   'ath_date': '2026-05-20T14:15:03.147Z',
#   'atl': 876.83,
#   'atl_change_percentage': 21.03571,
#   'atl_date': '2024-11-01T12:45:33.122Z',
#   'circulating_supply': 88650971.385841,
#   'current_price': 1061.28,
#   'fully_diluted_valuation': 94274430976,
#   'high_24h': 1061.28,
#   'id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'image': 'https://coin-images.coingecko.com/coins/images/35012/large/ustb.jpeg?1707102680',
#   'last_updated': '2026-05-24T15:50:09.424Z',
#   'low_24h': 1061.28,
#   'market_cap': 94083079579,
#   'market_cap_change_24h': 483827546,
#   'market_cap_change_percentage_24h': 0.51691,
#   'market_cap_rank': 72,
#   'max_supply': None,
#   'name': 'Superstate Short Duration U.S. Government Securities Fund (USTB)',
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'ustb',
#   'total_supply': 88831274.659553,
#   'total_volume': None},
#  {'ath': 10258.25,
#   'ath_change_percentage': -1.35388,
#   'ath_date': '2026-05-20T14:20:11.624Z',
#   'atl': 1516.02,
#   'atl_change_percentage': 567.49681,
#   'atl_date': '2025-06-02T23:15:02.895Z',
#   'circulating_supply': 9112111.0,
#   'current_price': 10119.37,
#   'fully_diluted_valuation': 92208808457,
#   'high_24h': 10119.37,
#   'id': 'blockchain-capital',
#   'image': 'https://coin-images.coingecko.com/coins/images/56040/large/bcap_logo_200.png?1748088291',
#   'last_updated': '2026-05-24T15:50:08.833Z',
#   'low_24h': 10119.37,
#   'market_cap': 92208808457,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 73,
#   'max_supply': None,
#   'name': 'Blockchain Capital',
#   'price_change_24h': -1.818989e-12,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'bcap',
#   'total_supply': 9112111.0,
#   'total_volume': None},
#  {'ath': 106.68,
#   'ath_change_percentage': -91.89189,
#   'ath_date': '2024-03-13T18:55:06.692Z',
#   'atl': 7.58,
#   'atl_change_percentage': 14.07064,
#   'atl_date': '2026-04-12T22:30:40.372Z',
#   'circulating_supply': 10648620284.29958,
#   'current_price': 8.65,
#   'fully_diluted_valuation': 92139200891,
#   'high_24h': 8.8,
#   'id': 'polygon-ecosystem-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/32440/large/pol.png?1759114181',
#   'last_updated': '2026-05-24T15:50:42.551Z',
#   'low_24h': 8.6,
#   'market_cap': 92139200891,
#   'market_cap_change_24h': 251591437,
#   'market_cap_change_percentage_24h': 0.2738,
#   'market_cap_rank': 74,
#   'max_supply': None,
#   'name': 'POL (ex-MATIC)',
#   'price_change_24h': 0.02022389,
#   'price_change_percentage_24h': 0.23425,
#   'roi': None,
#   'symbol': 'pol',
#   'total_supply': 10648620284.29958,
#   'total_volume': 3111322585},
#  {'ath': 107.1,
#   'ath_change_percentage': -1.33735,
#   'ath_date': '2026-05-20T14:20:22.965Z',
#   'atl': 95.98,
#   'atl_change_percentage': 10.08908,
#   'atl_date': '2025-11-19T05:25:04.387Z',
#   'circulating_supply': 850609381.31547,
#   'current_price': 105.67,
#   'fully_diluted_valuation': 89880863090,
#   'high_24h': 105.67,
#   'id': 'janus-henderson-anemoy-treasury-fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/70445/large/JTRSY.png?1762078582',
#   'last_updated': '2026-05-24T15:50:02.868Z',
#   'low_24h': 105.67,
#   'market_cap': 89880863090,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 75,
#   'max_supply': None,
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'price_change_24h': -1.4211e-14,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'jtrsy',
#   'total_supply': 850609381.31547,
#   'total_volume': None},
#  {'ath': 1952.18,
#   'ath_change_percentage': -1.69245,
#   'ath_date': '2025-01-28T00:06:36.780Z',
#   'atl': 82.42,
#   'atl_change_percentage': 2228.58945,
#   'atl_date': '2025-12-01T16:26:06.891Z',
#   'circulating_supply': 46342744.63030691,
#   'current_price': 1936.66,
#   'fully_diluted_valuation': 155163465090,
#   'high_24h': 1945.32,
#   'id': 'venice-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/54023/large/VVV_Token_Transparent.png?1741856877',
#   'last_updated': '2026-05-24T15:50:44.125Z',
#   'low_24h': 1669.43,
#   'market_cap': 89797860428,
#   'market_cap_change_24h': 10554902218,
#   'market_cap_change_percentage_24h': 13.31967,
#   'market_cap_rank': 76,
#   'max_supply': None,
#   'name': 'Venice Token',
#   'price_change_24h': 207.67,
#   'price_change_percentage_24h': 12.01108,
#   'roi': None,
#   'symbol': 'vvv',
#   'total_supply': 80076527.48421782,
#   'total_volume': 8525081209},
#  {'ath': 17.36,
#   'ath_change_percentage': -81.66209,
#   'ath_date': '2024-08-01T00:40:47.164Z',
#   'atl': 0.01327337,
#   'atl_change_percentage': 23884.66203,
#   'atl_date': '2022-05-26T14:42:59.316Z',
#   'circulating_supply': 27416658504.52483,
#   'current_price': 3.18,
#   'fully_diluted_valuation': 87464421865,
#   'high_24h': 3.28,
#   'id': 'kaspa',
#   'image': 'https://coin-images.coingecko.com/coins/images/25751/large/kaspa-icon-exchanges.png?1696524837',
#   'last_updated': '2026-05-24T15:50:42.124Z',
#   'low_24h': 3.17,
#   'market_cap': 87326526770,
#   'market_cap_change_24h': 240805986,
#   'market_cap_change_percentage_24h': 0.27652,
#   'market_cap_rank': 77,
#   'max_supply': 28704026601.0,
#   'name': 'Kaspa',
#   'price_change_24h': 0.00860159,
#   'price_change_percentage_24h': 0.27083,
#   'roi': None,
#   'symbol': 'kas',
#   'total_supply': 27459951452.02709,
#   'total_volume': 967630709},
#  {'ath': 126.48,
#   'ath_change_percentage': -92.5228,
#   'ath_date': '2024-04-11T13:15:15.057Z',
#   'atl': 7.15,
#   'atl_change_percentage': 32.32412,
#   'atl_date': '2026-04-05T12:50:40.489Z',
#   'circulating_supply': 9026562500.0,
#   'current_price': 9.47,
#   'fully_diluted_valuation': 141941060340,
#   'high_24h': 10.09,
#   'id': 'ethena',
#   'image': 'https://coin-images.coingecko.com/coins/images/36530/large/ethena.png?1711701436',
#   'last_updated': '2026-05-24T15:50:43.484Z',
#   'low_24h': 9.35,
#   'market_cap': 85415990165,
#   'market_cap_change_24h': 969336310,
#   'market_cap_change_percentage_24h': 1.14787,
#   'market_cap_rank': 78,
#   'max_supply': 15000000000.0,
#   'name': 'Ethena',
#   'price_change_24h': 0.112647,
#   'price_change_percentage_24h': 1.20402,
#   'roi': None,
#   'symbol': 'ena',
#   'total_supply': 15000000000.0,
#   'total_volume': 7443735015},
#  {'ath': 298.99,
#   'ath_change_percentage': -72.50908,
#   'ath_date': '2021-05-12T14:37:47.535Z',
#   'atl': 3.25,
#   'atl_change_percentage': 2430.56971,
#   'atl_date': '2018-09-13T00:00:00.000Z',
#   'circulating_supply': 1000000000.0,
#   'current_price': 82.14,
#   'fully_diluted_valuation': 82212193771,
#   'high_24h': 84.69,
#   'id': 'nexo',
#   'image': 'https://coin-images.coingecko.com/coins/images/3695/large/CG-nexo-token-200x200_2x.png?1730414360',
#   'last_updated': '2026-05-24T15:50:43.110Z',
#   'low_24h': 80.69,
#   'market_cap': 82212193771,
#   'market_cap_change_24h': 10238240,
#   'market_cap_change_percentage_24h': 0.01245,
#   'market_cap_rank': 79,
#   'max_supply': 1000000000.0,
#   'name': 'NEXO',
#   'price_change_24h': -0.05556838608373482,
#   'price_change_percentage_24h': -0.06761,
#   'roi': {'currency': 'usd',
#           'percentage': 758.3037617170729,
#           'times': 7.583037617170729},
#   'symbol': 'nexo',
#   'total_supply': 1000000000.0,
#   'total_volume': 806736029},
#  {'ath': 14.19,
#   'ath_change_percentage': -36.96454,
#   'ath_date': '2021-04-05T04:34:23.454Z',
#   'atl': 0.359754,
#   'atl_change_percentage': 2386.98543,
#   'atl_date': '2020-05-09T06:08:54.872Z',
#   'circulating_supply': 8543764567.312736,
#   'current_price': 8.95,
#   'fully_diluted_valuation': 76424935329,
#   'high_24h': 8.96,
#   'id': 'just',
#   'image': 'https://coin-images.coingecko.com/coins/images/11095/large/JUST.jpg?1696511035',
#   'last_updated': '2026-05-24T15:50:40.912Z',
#   'low_24h': 8.76,
#   'market_cap': 76424935329,
#   'market_cap_change_24h': 1536122416,
#   'market_cap_change_percentage_24h': 2.0512,
#   'market_cap_rank': 80,
#   'max_supply': 9900000000.0,
#   'name': 'JUST',
#   'price_change_24h': 0.182543,
#   'price_change_percentage_24h': 2.08289,
#   'roi': None,
#   'symbol': 'jst',
#   'total_supply': 8543764567.312736,
#   'total_volume': 2301823368},
#  {'ath': 1622.34,
#   'ath_change_percentage': -94.41154,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 72.2,
#   'atl_change_percentage': 25.56878,
#   'atl_date': '2026-02-23T01:30:53.133Z',
#   'circulating_supply': 819473954.8464024,
#   'current_price': 90.78,
#   'fully_diluted_valuation': 109202525786,
#   'high_24h': 95.23,
#   'id': 'aptos',
#   'image': 'https://coin-images.coingecko.com/coins/images/26455/large/Aptos-Network-Symbol-Black-RGB-1x.png?1761789140',
#   'last_updated': '2026-05-24T15:50:42.186Z',
#   'low_24h': 89.81,
#   'market_cap': 74378410916,
#   'market_cap_change_24h': 616055957,
#   'market_cap_change_percentage_24h': 0.83519,
#   'market_cap_rank': 81,
#   'max_supply': 2100000000.0,
#   'name': 'Aptos',
#   'price_change_24h': 0.755662,
#   'price_change_percentage_24h': 0.83943,
#   'roi': None,
#   'symbol': 'apt',
#   'total_supply': 1203153234.69234,
#   'total_volume': 5668901303},
#  {'ath': 4.08,
#   'ath_change_percentage': -21.21695,
#   'ath_date': '2026-05-14T23:25:26.430Z',
#   'atl': 0.827533,
#   'atl_change_percentage': 288.82326,
#   'atl_date': '2025-12-24T05:49:32.232Z',
#   'circulating_supply': 22967292181.0,
#   'current_price': 3.22,
#   'fully_diluted_valuation': 321972089732,
#   'high_24h': 3.31,
#   'id': 'stable-2',
#   'image': 'https://coin-images.coingecko.com/coins/images/69242/large/stable-logotype-framed-square-light.png?1762753913',
#   'last_updated': '2026-05-24T15:50:45.356Z',
#   'low_24h': 3.17,
#   'market_cap': 73948270590,
#   'market_cap_change_24h': 592670649,
#   'market_cap_change_percentage_24h': 0.80794,
#   'market_cap_rank': 82,
#   'max_supply': 100000000000.0,
#   'name': '\u200b\u200bStable',
#   'price_change_24h': 0.02222416,
#   'price_change_percentage_24h': 0.69507,
#   'roi': None,
#   'symbol': 'stable',
#   'total_supply': 100000000000.0,
#   'total_volume': 1465955037},
#  {'ath': 17367.85,
#   'ath_change_percentage': -99.47464,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 73.41,
#   'atl_change_percentage': 24.29784,
#   'atl_date': '2026-02-06T00:30:17.896Z',
#   'circulating_supply': 783061104.0,
#   'current_price': 91.26,
#   'fully_diluted_valuation': 178613730994,
#   'high_24h': 96.01,
#   'id': 'filecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/12817/large/filecoin.png?1696512609',
#   'last_updated': '2026-05-24T15:50:42.831Z',
#   'low_24h': 90.59,
#   'market_cap': 71440605913,
#   'market_cap_change_24h': 70542117,
#   'market_cap_change_percentage_24h': 0.09884,
#   'market_cap_rank': 83,
#   'max_supply': None,
#   'name': 'Filecoin',
#   'price_change_24h': -0.38244224487175416,
#   'price_change_percentage_24h': -0.41734,
#   'roi': None,
#   'symbol': 'fil',
#   'total_supply': 1957786662.0,
#   'total_volume': 6559973456},
#  {'ath': 2187.52,
#   'ath_change_percentage': -69.37856,
#   'ath_date': '2025-01-26T00:00:00.000Z',
#   'atl': 19.44,
#   'atl_change_percentage': 3346.32508,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'circulating_supply': 106483509.17747103,
#   'current_price': 670.46,
#   'fully_diluted_valuation': 81317729071,
#   'high_24h': 674.08,
#   'id': 'gatechain-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8183/large/200X200.png?1735246724',
#   'last_updated': '2026-05-24T15:50:26.011Z',
#   'low_24h': 661.51,
#   'market_cap': 71382144949,
#   'market_cap_change_24h': 906489030,
#   'market_cap_change_percentage_24h': 1.28624,
#   'market_cap_rank': 84,
#   'max_supply': 121304804.66747102,
#   'name': 'Gate',
#   'price_change_24h': 8.62,
#   'price_change_percentage_24h': 1.30169,
#   'roi': None,
#   'symbol': 'gt',
#   'total_supply': 121304804.66747102,
#   'total_volume': 171013361},
#  {'ath': 12.35,
#   'ath_change_percentage': -93.55542,
#   'ath_date': '2023-01-10T03:14:05.921Z',
#   'atl': 0.674474,
#   'atl_change_percentage': 17.96602,
#   'atl_date': '2026-04-07T18:55:08.564Z',
#   'circulating_supply': 86293192101.18527,
#   'current_price': 0.796591,
#   'fully_diluted_valuation': 84342788731,
#   'high_24h': 0.809875,
#   'id': 'flare-networks',
#   'image': 'https://coin-images.coingecko.com/coins/images/28624/large/FLR-icon200x200.png?1696527609',
#   'last_updated': '2026-05-24T15:50:42.162Z',
#   'low_24h': 0.790476,
#   'market_cap': 68735284211,
#   'market_cap_change_24h': 362751397,
#   'market_cap_change_percentage_24h': 0.53055,
#   'market_cap_rank': 85,
#   'max_supply': None,
#   'name': 'Flare',
#   'price_change_24h': 0.00418598,
#   'price_change_percentage_24h': 0.52826,
#   'roi': None,
#   'symbol': 'flr',
#   'total_supply': 105887515472.5254,
#   'total_volume': 206836896},
#  {'ath': 2374.75,
#   'ath_change_percentage': -39.78493,
#   'ath_date': '2021-03-08T13:29:57.935Z',
#   'atl': 49.7,
#   'atl_change_percentage': 2777.23685,
#   'atl_date': '2020-11-06T19:31:40.144Z',
#   'circulating_supply': 46750552.58384035,
#   'current_price': 1433.38,
#   'fully_diluted_valuation': 138244310156,
#   'high_24h': 1432.14,
#   'id': 'dexe',
#   'image': 'https://coin-images.coingecko.com/coins/images/12713/large/DEXE_token_logo.png?1696512514',
#   'last_updated': '2026-05-24T15:50:43.892Z',
#   'low_24h': 1296.55,
#   'market_cap': 66970879480,
#   'market_cap_change_24h': 5280151062,
#   'market_cap_change_percentage_24h': 8.55907,
#   'market_cap_rank': 86,
#   'max_supply': None,
#   'name': 'DeXe',
#   'price_change_24h': 115.4,
#   'price_change_percentage_24h': 8.75588,
#   'roi': None,
#   'symbol': 'dexe',
#   'total_supply': 96504599.33609451,
#   'total_volume': 2347667732},
#  {'ath': 166.05,
#   'ath_change_percentage': -88.33975,
#   'ath_date': '2024-01-31T15:02:47.304Z',
#   'atl': 12.3,
#   'atl_change_percentage': 57.37774,
#   'atl_date': '2026-02-12T18:35:44.925Z',
#   'circulating_supply': 3320312968.08,
#   'current_price': 19.38,
#   'fully_diluted_valuation': 133000319779,
#   'high_24h': 20.45,
#   'id': 'jupiter-exchange-solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/34188/large/jup.png?1704266489',
#   'last_updated': '2026-05-24T15:50:42.820Z',
#   'low_24h': 18.79,
#   'market_cap': 64350725487,
#   'market_cap_change_24h': 1751398407,
#   'market_cap_change_percentage_24h': 2.79779,
#   'market_cap_rank': 87,
#   'max_supply': 10000000000.0,
#   'name': 'Jupiter',
#   'price_change_24h': 0.512742,
#   'price_change_percentage_24h': 2.7173,
#   'roi': None,
#   'symbol': 'jup',
#   'total_supply': 6862435243.466898,
#   'total_volume': 2459193461},
#  {'ath': 198.19,
#   'ath_change_percentage': -94.89942,
#   'ath_date': '2024-01-12T12:29:59.231Z',
#   'atl': 8.07,
#   'atl_change_percentage': 25.22832,
#   'atl_date': '2026-02-23T01:30:53.292Z',
#   'circulating_supply': 6255821492.0,
#   'current_price': 10.13,
#   'fully_diluted_valuation': 101247860052,
#   'high_24h': 10.66,
#   'id': 'arbitrum',
#   'image': 'https://coin-images.coingecko.com/coins/images/16547/large/arb.jpg?1721358242',
#   'last_updated': '2026-05-24T15:50:41.864Z',
#   'low_24h': 10.08,
#   'market_cap': 63338853893,
#   'market_cap_change_24h': -1006862630.7700729,
#   'market_cap_change_percentage_24h': -1.56477,
#   'market_cap_rank': 88,
#   'max_supply': 10000000000.0,
#   'name': 'Arbitrum',
#   'price_change_24h': -0.16103749985194682,
#   'price_change_percentage_24h': -1.56507,
#   'roi': None,
#   'symbol': 'arb',
#   'total_supply': 10000000000.0,
#   'total_volume': 4452722311},
#  {'ath': 0.77853,
#   'ath_change_percentage': -78.61927,
#   'ath_date': '2025-09-14T16:42:40.248Z',
#   'atl': 0.146589,
#   'atl_change_percentage': 13.55232,
#   'atl_date': '2026-04-02T13:47:10.933Z',
#   'circulating_supply': 353682237994.0652,
#   'current_price': 0.166455,
#   'fully_diluted_valuation': 143751752695,
#   'high_24h': 0.175346,
#   'id': 'pump-fun',
#   'image': 'https://coin-images.coingecko.com/coins/images/67164/large/pump.jpg?1751949376',
#   'last_updated': '2026-05-24T15:50:45.105Z',
#   'low_24h': 0.162867,
#   'market_cap': 58836312479,
#   'market_cap_change_24h': 1226378315,
#   'market_cap_change_percentage_24h': 2.12876,
#   'market_cap_rank': 89,
#   'max_supply': 1000000000000.0,
#   'name': 'Pump.fun',
#   'price_change_24h': 0.00358844,
#   'price_change_percentage_24h': 2.20329,
#   'roi': None,
#   'symbol': 'pump',
#   'total_supply': 864133720602.132,
#   'total_volume': 3690807395},
#  {'ath': 14.32,
#   'ath_change_percentage': -79.41079,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.02721364,
#   'atl_change_percentage': 10735.66574,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'circulating_supply': 19946688440.0,
#   'current_price': 2.95,
#   'fully_diluted_valuation': 112185465008,
#   'high_24h': 3.06,
#   'id': 'xdce-crowd-sale',
#   'image': 'https://coin-images.coingecko.com/coins/images/2912/large/xdc-icon.png?1696503661',
#   'last_updated': '2026-05-24T15:50:42.301Z',
#   'low_24h': 2.91,
#   'market_cap': 58785975722,
#   'market_cap_change_24h': -1501452429.5840683,
#   'market_cap_change_percentage_24h': -2.49049,
#   'market_cap_rank': 90,
#   'max_supply': None,
#   'name': 'XDC Network',
#   'price_change_24h': -0.07334764626978707,
#   'price_change_percentage_24h': -2.42731,
#   'roi': {'currency': 'eth',
#           'percentage': 95.67380569423378,
#           'times': 0.9567380569423377},
#   'symbol': 'xdc',
#   'total_supply': 38065686425.1,
#   'total_volume': 1505592471},
#  {'ath': 32.42,
#   'ath_change_percentage': -76.71779,
#   'ath_date': '2018-12-17T00:00:00.000Z',
#   'atl': 0.01949843,
#   'atl_change_percentage': 38612.32702,
#   'atl_date': '2019-11-01T11:05:12.090Z',
#   'circulating_supply': 7738278439.774086,
#   'current_price': 7.55,
#   'fully_diluted_valuation': 74996191727,
#   'high_24h': 7.56,
#   'id': 'beldex',
#   'image': 'https://coin-images.coingecko.com/coins/images/5111/large/Beldex.png?1696505631',
#   'last_updated': '2026-05-24T15:50:43.675Z',
#   'low_24h': 7.52,
#   'market_cap': 58396794153,
#   'market_cap_change_24h': 148980874,
#   'market_cap_change_percentage_24h': 0.25577,
#   'market_cap_rank': 91,
#   'max_supply': None,
#   'name': 'Beldex',
#   'price_change_24h': 0.02381334,
#   'price_change_percentage_24h': 0.31645,
#   'roi': {'currency': 'usd',
#           'percentage': -68.44771638506087,
#           'times': -0.6844771638506087},
#   'symbol': 'bdx',
#   'total_supply': 9937898508.232578,
#   'total_volume': 951979065},
#  {'ath': 96.91,
#   'ath_change_percentage': -1.36266,
#   'ath_date': '2026-05-20T14:16:04.230Z',
#   'atl': 76.18,
#   'atl_change_percentage': 25.4768,
#   'atl_date': '2023-10-24T04:41:04.568Z',
#   'circulating_supply': 584000000.0,
#   'current_price': 95.59,
#   'fully_diluted_valuation': 55823402949,
#   'high_24h': 95.61,
#   'id': 'gho',
#   'image': 'https://coin-images.coingecko.com/coins/images/30663/large/gho-token-logo.png?1720517092',
#   'last_updated': '2026-05-24T15:50:42.523Z',
#   'low_24h': 95.58,
#   'market_cap': 55823402949,
#   'market_cap_change_24h': 3711282,
#   'market_cap_change_percentage_24h': 0.00665,
#   'market_cap_rank': 92,
#   'max_supply': None,
#   'name': 'GHO',
#   'price_change_24h': 0.00700811,
#   'price_change_percentage_24h': 0.00733,
#   'roi': None,
#   'symbol': 'gho',
#   'total_supply': 584000000.0,
#   'total_volume': 365340252},
#  {'ath': 95552,
#   'ath_change_percentage': -95.46537,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 13.82,
#   'atl_change_percentage': 31262.43151,
#   'atl_date': '2014-02-14T00:00:00.000Z',
#   'circulating_supply': 12712104.75401168,
#   'current_price': 4362.99,
#   'fully_diluted_valuation': 55316191154,
#   'high_24h': 4443.9,
#   'id': 'dash',
#   'image': 'https://coin-images.coingecko.com/coins/images/19/large/dash-logo.png?1696501423',
#   'last_updated': '2026-05-24T15:50:41.792Z',
#   'low_24h': 4246.54,
#   'market_cap': 55314158123,
#   'market_cap_change_24h': 702868158,
#   'market_cap_change_percentage_24h': 1.28704,
#   'market_cap_rank': 93,
#   'max_supply': 18920000.0,
#   'name': 'Dash',
#   'price_change_24h': 57.56,
#   'price_change_percentage_24h': 1.33688,
#   'roi': None,
#   'symbol': 'dash',
#   'total_supply': 12712571.97805868,
#   'total_volume': 11018068328},
#  {'ath': 20.95,
#   'ath_change_percentage': -96.9752,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.144791,
#   'atl_change_percentage': 337.56252,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'circulating_supply': 85985041177.0,
#   'current_price': 0.634507,
#   'fully_diluted_valuation': 54510469201,
#   'high_24h': 0.664275,
#   'id': 'vechain',
#   'image': 'https://coin-images.coingecko.com/coins/images/1167/large/VET.png?1742383283',
#   'last_updated': '2026-05-24T15:50:45.039Z',
#   'low_24h': 0.627468,
#   'market_cap': 54510469201,
#   'market_cap_change_24h': 483451816,
#   'market_cap_change_percentage_24h': 0.89483,
#   'market_cap_rank': 94,
#   'max_supply': 86712634466.0,
#   'name': 'VeChain',
#   'price_change_24h': 0.00603364,
#   'price_change_percentage_24h': 0.96005,
#   'roi': {'currency': 'eth',
#           'percentage': 10.83236478115795,
#           'times': 0.1083236478115795},
#   'symbol': 'vet',
#   'total_supply': 85985041177.0,
#   'total_volume': 1360733454},
#  {'ath': 5.31,
#   'ath_change_percentage': -80.813,
#   'ath_date': '2025-09-14T16:52:41.627Z',
#   'atl': 0.841042,
#   'atl_change_percentage': 21.13085,
#   'atl_date': '2026-04-17T13:35:51.984Z',
#   'circulating_supply': 53364802524.0,
#   'current_price': 1.018,
#   'fully_diluted_valuation': 96700732990,
#   'high_24h': 1.13,
#   'id': 'hash-2',
#   'image': 'https://coin-images.coingecko.com/coins/images/66154/large/Hastra_Icon.png?1748497203',
#   'last_updated': '2026-05-24T15:50:44.803Z',
#   'low_24h': 0.98039,
#   'market_cap': 54332473758,
#   'market_cap_change_24h': -3710874417.390915,
#   'market_cap_change_percentage_24h': -6.39328,
#   'market_cap_rank': 95,
#   'max_supply': 100000000000.0,
#   'name': 'Provenance Blockchain',
#   'price_change_24h': -0.06986638194551564,
#   'price_change_percentage_24h': -6.42155,
#   'roi': None,
#   'symbol': 'hash',
#   'total_supply': 94978475357.64638,
#   'total_volume': 1518063},
#  {'ath': 10.66,
#   'ath_change_percentage': -69.51483,
#   'ath_date': '2025-12-09T09:29:38.386Z',
#   'atl': 2.14,
#   'atl_change_percentage': 51.98398,
#   'atl_date': '2025-12-09T09:48:36.670Z',
#   'circulating_supply': 16607399400.63495,
#   'current_price': 3.24,
#   'fully_diluted_valuation': 77946782216,
#   'high_24h': 3.3,
#   'id': 'midnight-3',
#   'image': 'https://coin-images.coingecko.com/coins/images/71015/large/midnight.png?1765193080',
#   'last_updated': '2026-05-24T15:50:25.956Z',
#   'low_24h': 3.16,
#   'market_cap': 53937222677,
#   'market_cap_change_24h': 1063306546,
#   'market_cap_change_percentage_24h': 2.01102,
#   'market_cap_rank': 96,
#   'max_supply': 24000000000.0,
#   'name': 'Midnight',
#   'price_change_24h': 0.062294,
#   'price_change_percentage_24h': 1.95895,
#   'roi': None,
#   'symbol': 'night',
#   'total_supply': 24000000000.0,
#   'total_volume': 958752497},
#  {'ath': 5.81,
#   'ath_change_percentage': -85.2832,
#   'ath_date': '2024-12-17T13:05:22.873Z',
#   'atl': 0.320882,
#   'atl_change_percentage': 166.54111,
#   'atl_date': '2025-04-09T01:31:57.832Z',
#   'circulating_supply': 62860396090.0,
#   'current_price': 0.856653,
#   'fully_diluted_valuation': 68137520632,
#   'high_24h': 0.888352,
#   'id': 'pudgy-penguins',
#   'image': 'https://coin-images.coingecko.com/coins/images/52622/large/PUDGY_PENGUINS_PENGU_PFP.png?1733809110',
#   'last_updated': '2026-05-24T15:50:43.865Z',
#   'low_24h': 0.8442,
#   'market_cap': 53828350375,
#   'market_cap_change_24h': 823250160,
#   'market_cap_change_percentage_24h': 1.55315,
#   'market_cap_rank': 97,
#   'max_supply': 88888888888.0,
#   'name': 'Pudgy Penguins',
#   'price_change_24h': 0.01245229,
#   'price_change_percentage_24h': 1.47504,
#   'roi': None,
#   'symbol': 'pengu',
#   'total_supply': 79570551682.74667,
#   'total_volume': 10967599390},
#  {'ath': 110.74,
#   'ath_change_percentage': -13.7093,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 81.88,
#   'atl_change_percentage': 16.70415,
#   'atl_date': '2024-08-05T06:27:12.976Z',
#   'circulating_supply': 555227276.2276015,
#   'current_price': 95.56,
#   'fully_diluted_valuation': 53065120937,
#   'high_24h': 95.58,
#   'id': 'usual-usd',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'last_updated': '2026-05-24T15:50:43.181Z',
#   'low_24h': 95.54,
#   'market_cap': 53065120937,
#   'market_cap_change_24h': 12309083,
#   'market_cap_change_percentage_24h': 0.0232,
#   'market_cap_rank': 98,
#   'max_supply': None,
#   'name': 'Usual USD',
#   'price_change_24h': 0.00744863,
#   'price_change_percentage_24h': 0.0078,
#   'roi': None,
#   'symbol': 'usd0',
#   'total_supply': 555227276.2276015,
#   'total_volume': 97567},
#  {'ath': 11182.59,
#   'ath_change_percentage': -1.30403,
#   'ath_date': '2026-05-21T01:05:10.620Z',
#   'atl': 7844.42,
#   'atl_change_percentage': 40.69578,
#   'atl_date': '2023-03-22T20:00:17.106Z',
#   'circulating_supply': 4797002.629046694,
#   'current_price': 11036.77,
#   'fully_diluted_valuation': 52943413128,
#   'high_24h': 11036.77,
#   'id': 'ousg',
#   'image': 'https://coin-images.coingecko.com/coins/images/29023/large/OUSG.png?1696527993',
#   'last_updated': '2026-05-24T15:45:18.954Z',
#   'low_24h': 11036.77,
#   'market_cap': 52943413128,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 99,
#   'max_supply': None,
#   'name': 'OUSG',
#   'price_change_24h': -1.818989e-12,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'ousg',
#   'total_supply': 4797002.629046694,
#   'total_volume': 0.0},
#  {'ath': 0.00491619,
#   'ath_change_percentage': -88.33953,
#   'ath_date': '2024-11-20T04:01:06.465Z',
#   'atl': 7.14e-06,
#   'atl_change_percentage': 7933.60723,
#   'atl_date': '2022-12-29T22:48:46.755Z',
#   'circulating_supply': 87994731471052.36,
#   'current_price': 0.00057364,
#   'fully_diluted_valuation': 50458841342,
#   'high_24h': 0.00059959,
#   'id': 'bonk',
#   'image': 'https://coin-images.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#   'last_updated': '2026-05-24T15:50:42.624Z',
#   'low_24h': 0.00056813,
#   'market_cap': 50458841342,
#   'market_cap_change_24h': 109837989,
#   'market_cap_change_percentage_24h': 0.21815,
#   'market_cap_rank': 100,
#   'max_supply': 87995282867000.55,
#   'name': 'Bonk',
#   'price_change_24h': 1.37e-06,
#   'price_change_percentage_24h': 0.23942,
#   'roi': None,
#   'symbol': 'bonk',
#   'total_supply': 87994731471052.36,
#   'total_volume': 2878759582},
#  {'ath': 103.77,
#   'ath_change_percentage': -7.80994,
#   'ath_date': '2026-03-23T17:34:21.546Z',
#   'atl': 80.73,
#   'atl_change_percentage': 18.50833,
#   'atl_date': '2026-04-19T05:35:48.839Z',
#   'circulating_supply': 519050593.822553,
#   'current_price': 95.68,
#   'fully_diluted_valuation': 49655096307,
#   'high_24h': 95.69,
#   'id': 'apxusd',
#   'image': 'https://coin-images.coingecko.com/coins/images/102172243/large/apxUSD.png?1772448502',
#   'last_updated': '2026-05-24T15:50:45.315Z',
#   'low_24h': 95.66,
#   'market_cap': 49655096307,
#   'market_cap_change_24h': 20065760,
#   'market_cap_change_percentage_24h': 0.04043,
#   'market_cap_rank': 101,
#   'max_supply': None,
#   'name': 'apxUSD',
#   'price_change_24h': 0.02442644,
#   'price_change_percentage_24h': 0.02553,
#   'roi': None,
#   'symbol': 'apxusd',
#   'total_supply': 519050593.822553,
#   'total_volume': 1962792820},
#  {'ath': 4364.19,
#   'ath_change_percentage': -88.75054,
#   'ath_date': '2024-03-14T15:06:22.124Z',
#   'atl': 49.02,
#   'atl_change_percentage': 901.62421,
#   'atl_date': '2020-11-03T16:19:30.576Z',
#   'circulating_supply': 100000000.0,
#   'current_price': 492.11,
#   'fully_diluted_valuation': 49134966510,
#   'high_24h': 526.63,
#   'id': 'injective-protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/12882/large/Other_200x200.png?1738782212',
#   'last_updated': '2026-05-24T15:50:41.350Z',
#   'low_24h': 487.42,
#   'market_cap': 49134966510,
#   'market_cap_change_24h': -820075965.5436783,
#   'market_cap_change_percentage_24h': -1.64163,
#   'market_cap_rank': 102,
#   'max_supply': None,
#   'name': 'Injective',
#   'price_change_24h': -7.713011798008495,
#   'price_change_percentage_24h': -1.54314,
#   'roi': None,
#   'symbol': 'inj',
#   'total_supply': 100000000.0,
#   'total_volume': 11812015944},
#  {'ath': 96.98,
#   'ath_change_percentage': -1.3254,
#   'ath_date': '2026-05-20T14:15:24.953Z',
#   'atl': 87.62,
#   'atl_change_percentage': 9.2192,
#   'atl_date': '2025-08-27T20:03:18.161Z',
#   'circulating_supply': 509537707.41,
#   'current_price': 95.7,
#   'fully_diluted_valuation': 48760552894,
#   'high_24h': 95.7,
#   'id': 'ylds',
#   'image': 'https://coin-images.coingecko.com/coins/images/66486/large/YLDS.png?1772560579',
#   'last_updated': '2026-05-24T15:50:44.699Z',
#   'low_24h': 95.66,
#   'market_cap': 48760552894,
#   'market_cap_change_24h': 14125226,
#   'market_cap_change_percentage_24h': 0.02898,
#   'market_cap_rank': 103,
#   'max_supply': None,
#   'name': 'YLDS',
#   'price_change_24h': 0.02772165,
#   'price_change_percentage_24h': 0.02898,
#   'roi': None,
#   'symbol': 'ylds',
#   'total_supply': 509537707.41,
#   'total_volume': 16409455},
#  {'ath': 20.14,
#   'ath_change_percentage': -93.86744,
#   'ath_date': '2025-08-14T23:03:39.275Z',
#   'atl': 0.00091492,
#   'atl_change_percentage': 134875.91596,
#   'atl_date': '2025-08-21T17:43:44.693Z',
#   'circulating_supply': 39210300116.64074,
#   'current_price': 1.23,
#   'fully_diluted_valuation': 48422007896,
#   'high_24h': 1.25,
#   'id': 'a7a5',
#   'image': 'https://coin-images.coingecko.com/coins/images/66657/large/A7A5_200.png?1750163839',
#   'last_updated': '2026-05-24T15:50:44.927Z',
#   'low_24h': 1.22,
#   'market_cap': 48422007896,
#   'market_cap_change_24h': 57058140,
#   'market_cap_change_percentage_24h': 0.11797,
#   'market_cap_rank': 104,
#   'max_supply': None,
#   'name': 'A7A5',
#   'price_change_24h': 0.00146461,
#   'price_change_percentage_24h': 0.11874,
#   'roi': None,
#   'symbol': 'a7a5',
#   'total_supply': 39210300116.64074,
#   'total_volume': 460076},
#  {'ath': 112.93,
#   'ath_change_percentage': -15.40591,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 64.32,
#   'atl_change_percentage': 48.53472,
#   'atl_date': '2018-03-25T00:00:00.000Z',
#   'circulating_supply': 494515083.0,
#   'current_price': 95.56,
#   'fully_diluted_valuation': 47246192894,
#   'high_24h': 95.66,
#   'id': 'true-usd',
#   'image': 'https://coin-images.coingecko.com/coins/images/3449/large/tusd.png?1696504140',
#   'last_updated': '2026-05-24T15:50:42.810Z',
#   'low_24h': 95.51,
#   'market_cap': 47246192894,
#   'market_cap_change_24h': -31102859.823310852,
#   'market_cap_change_percentage_24h': -0.06579,
#   'market_cap_rank': 105,
#   'max_supply': None,
#   'name': 'TrueUSD',
#   'price_change_24h': -0.049441159802739776,
#   'price_change_percentage_24h': -0.05171,
#   'roi': None,
#   'symbol': 'tusd',
#   'total_supply': 494515083.0,
#   'total_volume': 1138656258},
#  {'ath': 6357.94,
#   'ath_change_percentage': -96.88263,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 188.85,
#   'atl_change_percentage': 4.95004,
#   'atl_date': '2026-05-23T08:05:33.425Z',
#   'circulating_supply': 237414040.342428,
#   'current_price': 198.17,
#   'fully_diluted_valuation': 198133528351,
#   'high_24h': 202.46,
#   'id': 'official-trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'last_updated': '2026-05-24T15:50:44.099Z',
#   'low_24h': 196.26,
#   'market_cap': 47039681493,
#   'market_cap_change_24h': 452973385,
#   'market_cap_change_percentage_24h': 0.97232,
#   'market_cap_rank': 106,
#   'max_supply': 1000000000.0,
#   'name': 'Official Trump',
#   'price_change_24h': 1.69,
#   'price_change_percentage_24h': 0.85835,
#   'roi': None,
#   'symbol': 'trump',
#   'total_supply': 1000000000.0,
#   'total_volume': 5325187373},
#  {'ath': 434.45,
#   'ath_change_percentage': -83.57321,
#   'ath_date': '2025-01-02T06:15:38.599Z',
#   'atl': 0.622571,
#   'atl_change_percentage': 11363.1716,
#   'atl_date': '2024-01-23T20:55:21.653Z',
#   'circulating_supply': 656986027.2170838,
#   'current_price': 71.48,
#   'fully_diluted_valuation': 71466384348,
#   'high_24h': 74.65,
#   'id': 'virtual-protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/34057/large/LOGOMARK.png?1708356054',
#   'last_updated': '2026-05-24T15:50:43.277Z',
#   'low_24h': 69.18,
#   'market_cap': 46952415933,
#   'market_cap_change_24h': 1427211580,
#   'market_cap_change_percentage_24h': 3.13499,
#   'market_cap_rank': 107,
#   'max_supply': 1000000000.0,
#   'name': 'Virtuals Protocol',
#   'price_change_24h': 1.96,
#   'price_change_percentage_24h': 2.81728,
#   'roi': None,
#   'symbol': 'virtual',
#   'total_supply': 1000000000.0,
#   'total_volume': 9127405940},
#  {'ath': 287.87,
#   'ath_change_percentage': -93.02569,
#   'ath_date': '2024-03-28T17:21:18.050Z',
#   'atl': 0.616804,
#   'atl_change_percentage': 3155.04976,
#   'atl_date': '2020-03-13T02:24:18.347Z',
#   'circulating_supply': 2258881093.9307284,
#   'current_price': 20.14,
#   'fully_diluted_valuation': 54497867827,
#   'high_24h': 20.72,
#   'id': 'fetch-ai',
#   'image': 'https://coin-images.coingecko.com/coins/images/5681/large/ASI.png?1719827289',
#   'last_updated': '2026-05-24T15:50:44.682Z',
#   'low_24h': 19.6,
#   'market_cap': 45352528788,
#   'market_cap_change_24h': 452023310,
#   'market_cap_change_percentage_24h': 1.00672,
#   'market_cap_rank': 108,
#   'max_supply': 2714384546.672,
#   'name': 'Artificial Superintelligence Alliance',
#   'price_change_24h': 0.227643,
#   'price_change_percentage_24h': 1.14312,
#   'roi': {'currency': 'usd',
#           'percentage': 142.7547807923648,
#           'times': 1.427547807923648},
#   'symbol': 'fet',
#   'total_supply': 2714384546.672,
#   'total_volume': 8706916105},
#  {'ath': 29.33,
#   'ath_change_percentage': -33.94176,
#   'ath_date': '2026-03-06T10:30:09.941Z',
#   'atl': 5.48,
#   'atl_change_percentage': 253.55123,
#   'atl_date': '2025-11-04T08:21:02.065Z',
#   'circulating_supply': 2273255814.0,
#   'current_price': 19.4,
#   'fully_diluted_valuation': 193919211187,
#   'high_24h': 19.82,
#   'id': 'kite-2',
#   'image': 'https://coin-images.coingecko.com/coins/images/70426/large/KITE-ICON.png?1762328605',
#   'last_updated': '2026-05-24T15:50:45.680Z',
#   'low_24h': 18.99,
#   'market_cap': 44082797428,
#   'market_cap_change_24h': 258075334,
#   'market_cap_change_percentage_24h': 0.58888,
#   'market_cap_rank': 109,
#   'max_supply': 10000000000.0,
#   'name': 'Kite',
#   'price_change_24h': 0.119548,
#   'price_change_percentage_24h': 0.62009,
#   'roi': None,
#   'symbol': 'kite',
#   'total_supply': 10000000000.0,
#   'total_volume': 2586496908},
#  {'ath': 3259.75,
#   'ath_change_percentage': -95.88199,
#   'ath_date': '2021-04-30T03:23:20.257Z',
#   'atl': 14.48,
#   'atl_change_percentage': 827.00786,
#   'atl_date': '2020-11-03T14:29:34.165Z',
#   'circulating_supply': 325808307.9496637,
#   'current_price': 134.22,
#   'fully_diluted_valuation': 45385137313,
#   'high_24h': 137.46,
#   'id': 'pancakeswap-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/12632/large/pancakeswap-cake-logo_%281%29.png?1696512440',
#   'last_updated': '2026-05-24T15:50:41.113Z',
#   'low_24h': 133.92,
#   'market_cap': 43717325692,
#   'market_cap_change_24h': 115594861,
#   'market_cap_change_percentage_24h': 0.26512,
#   'market_cap_rank': 110,
#   'max_supply': 400000000.0,
#   'name': 'PancakeSwap',
#   'price_change_24h': 0.302429,
#   'price_change_percentage_24h': 0.22583,
#   'roi': None,
#   'symbol': 'cake',
#   'total_supply': 338237862.4500047,
#   'total_volume': 1802862828},
#  {'ath': 148.19,
#   'ath_change_percentage': -15.8764,
#   'ath_date': '2026-05-22T00:25:41.284Z',
#   'atl': 46.44,
#   'atl_change_percentage': 168.41535,
#   'atl_date': '2026-03-31T11:19:17.616Z',
#   'circulating_supply': 350000000.0,
#   'current_price': 124.97,
#   'fully_diluted_valuation': 124774642600,
#   'high_24h': 127.81,
#   'id': 'edgex',
#   'image': 'https://coin-images.coingecko.com/coins/images/102172616/large/edgex.png?1774332310',
#   'last_updated': '2026-05-24T15:50:44.925Z',
#   'low_24h': 120.62,
#   'market_cap': 43671124910,
#   'market_cap_change_24h': -929892244.3708038,
#   'market_cap_change_percentage_24h': -2.08491,
#   'market_cap_rank': 111,
#   'max_supply': 1000000000.0,
#   'name': 'edgeX',
#   'price_change_24h': -2.461712647146328,
#   'price_change_percentage_24h': -1.93178,
#   'roi': None,
#   'symbol': 'edge',
#   'total_supply': 1000000000.0,
#   'total_volume': 762318224},
#  {'ath': 51.48,
#   'ath_change_percentage': -16.65502,
#   'ath_date': '2026-04-18T07:30:47.095Z',
#   'atl': 3.64,
#   'atl_change_percentage': 1077.87252,
#   'atl_date': '2026-03-29T00:45:47.059Z',
#   'circulating_supply': 1000000000.0,
#   'current_price': 42.93,
#   'fully_diluted_valuation': 42873394864,
#   'high_24h': 43.66,
#   'id': 'bianrensheng',
#   'image': 'https://coin-images.coingecko.com/coins/images/69848/large/%E5%B8%81%E5%AE%89%E4%BA%BA%E7%94%9F.png?1759839225',
#   'last_updated': '2026-05-24T15:50:45.521Z',
#   'low_24h': 41.99,
#   'market_cap': 42873394864,
#   'market_cap_change_24h': 105953183,
#   'market_cap_change_percentage_24h': 0.24774,
#   'market_cap_rank': 112,
#   'max_supply': 1000000000.0,
#   'name': '币安人生 (BinanceLife)',
#   'price_change_24h': 0.392811,
#   'price_change_percentage_24h': 0.92336,
#   'roi': None,
#   'symbol': '币安人生',
#   'total_supply': 1000000000.0,
#   'total_volume': 1570678158},
#  {'ath': 112.74,
#   'ath_change_percentage': -1.45782,
#   'ath_date': '2026-05-21T00:55:24.532Z',
#   'atl': 4.35,
#   'atl_change_percentage': 2455.61644,
#   'atl_date': '2022-12-09T03:16:34.877Z',
#   'circulating_supply': 383497842.1424131,
#   'current_price': 111.08,
#   'fully_diluted_valuation': 42624942958,
#   'high_24h': 111.11,
#   'id': 'euro-coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/26045/large/EURC.png?1769615705',
#   'last_updated': '2026-05-24T15:50:42.454Z',
#   'low_24h': 110.92,
#   'market_cap': 42596064108,
#   'market_cap_change_24h': 38018671,
#   'market_cap_change_percentage_24h': 0.08933,
#   'market_cap_rank': 113,
#   'max_supply': None,
#   'name': 'EURC',
#   'price_change_24h': 0.143247,
#   'price_change_percentage_24h': 0.12913,
#   'roi': None,
#   'symbol': 'eurc',
#   'total_supply': 383757842.1424131,
#   'total_volume': 1539658996},
#  {'ath': 322.23,
#   'ath_change_percentage': -92.84003,
# ...
#   'high_24h': 1.47,
#   'id': 'zksync',
#   'image': 'https://coin-images.coingecko.com/coins/images/38043/large/ZKTokenBlack.png?1718614502',
#   'last_updated': '2026-05-24T15:50:43.363Z',
#   'low_24h': 1.38,
#   'market_cap': 13506513852,
#   'market_cap_change_24h': -69278161.81829071,
#   'market_cap_change_percentage_24h': -0.51031,
#   'market_cap_rank': 233,
#   'max_supply': 21000000000.0,
#   'name': 'ZKsync',
#   'price_change_24h': -0.006951617970050394,
#   'price_change_percentage_24h': -0.49679,
#   'roi': None,
#   'symbol': 'zk',
#   'total_supply': 21000000000.0,
#   'total_volume': 916386426},
#  {'ath': 97.0,
#   'ath_change_percentage': -1.33986,
#   'ath_date': '2026-05-20T14:15:19.089Z',
#   'atl': 87.63,
#   'atl_change_percentage': 9.21553,
#   'atl_date': '2025-10-16T02:45:09.963Z',
#   'circulating_supply': 140174080.2,
#   'current_price': 95.7,
#   'fully_diluted_valuation': 13414726338,
#   'high_24h': 95.7,
#   'id': 'fidelity-digital-interest-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/69097/large/Se9OAY6C_400x400.jpg?1757491787',
#   'last_updated': '2026-05-24T15:45:22.650Z',
#   'low_24h': 95.7,
#   'market_cap': 13414726338,
#   'market_cap_change_24h': -244705155.98519516,
#   'market_cap_change_percentage_24h': -1.79147,
#   'market_cap_rank': 234,
#   'max_supply': None,
#   'name': 'Fidelity Digital Interest Token',
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'fdit',
#   'total_supply': 140174080.2,
#   'total_volume': None},
#  {'ath': 305.14,
#   'ath_change_percentage': -91.24657,
#   'ath_date': '2021-02-09T18:30:34.250Z',
#   'atl': 21.02,
#   'atl_change_percentage': 27.03996,
#   'atl_date': '2026-02-06T00:26:27.638Z',
#   'circulating_supply': 500000000.0,
#   'current_price': 26.71,
#   'fully_diluted_valuation': 13356099995,
#   'high_24h': 27.61,
#   'id': 'safepal',
#   'image': 'https://coin-images.coingecko.com/coins/images/13905/large/sfp.png?1696513647',
#   'last_updated': '2026-05-24T15:50:41.482Z',
#   'low_24h': 26.52,
#   'market_cap': 13356099995,
#   'market_cap_change_24h': 88871701,
#   'market_cap_change_percentage_24h': 0.66986,
#   'market_cap_rank': 235,
#   'max_supply': 500000000.0,
#   'name': 'SafePal',
#   'price_change_24h': 0.166972,
#   'price_change_percentage_24h': 0.62909,
#   'roi': None,
#   'symbol': 'sfp',
#   'total_supply': 500000000.0,
#   'total_volume': 142407402},
#  {'ath': 709.31,
#   'ath_change_percentage': -97.78644,
#   'ath_date': '2021-11-26T01:03:01.536Z',
#   'atl': 12.12,
#   'atl_change_percentage': 29.53803,
#   'atl_date': '2026-04-05T21:40:26.388Z',
#   'circulating_supply': 842444578.3296283,
#   'current_price': 15.72,
#   'fully_diluted_valuation': 31429293274,
#   'high_24h': 16.54,
#   'id': 'immutable-x',
#   'image': 'https://coin-images.coingecko.com/coins/images/17233/large/immutableX-symbol-BLK-RGB.png?1696516787',
#   'last_updated': '2026-05-24T15:50:41.567Z',
#   'low_24h': 15.53,
#   'market_cap': 13238718860,
#   'market_cap_change_24h': -146908864.52708054,
#   'market_cap_change_percentage_24h': -1.09751,
#   'market_cap_rank': 236,
#   'max_supply': 2000000000.0,
#   'name': 'Immutable',
#   'price_change_24h': -0.17465259739036654,
#   'price_change_percentage_24h': -1.09894,
#   'roi': None,
#   'symbol': 'imx',
#   'total_supply': 2000000000.0,
#   'total_volume': 1012329009},
#  {'ath': 97.76,
#   'ath_change_percentage': -1.2925,
#   'ath_date': '2026-05-20T14:20:12.483Z',
#   'atl': 92.76,
#   'atl_change_percentage': 4.0356,
#   'atl_date': '2026-04-17T14:50:03.643Z',
#   'circulating_supply': 136442447.51924,
#   'current_price': 96.5,
#   'fully_diluted_valuation': 13166847253,
#   'high_24h': 96.5,
#   'id': 'safo',
#   'image': 'https://coin-images.coingecko.com/coins/images/102172590/large/Fund_usdSAFO.png?1774104804',
#   'last_updated': '2026-05-24T15:50:05.261Z',
#   'low_24h': 96.5,
#   'market_cap': 13166847253,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 237,
#   'max_supply': None,
#   'name': 'Spiko Amundi Overnight Swap Fund',
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'safo',
#   'total_supply': 136442447.51924,
#   'total_volume': None},
#  {'ath': 10352.99,
#   'ath_change_percentage': -6.30841,
#   'ath_date': '2026-03-22T13:35:15.433Z',
#   'atl': 8523.09,
#   'atl_change_percentage': 13.80707,
#   'atl_date': '2026-02-06T03:49:57.099Z',
#   'circulating_supply': 1354000.472948681,
#   'current_price': 9699.45,
#   'fully_diluted_valuation': 23195814202,
#   'high_24h': 9811.25,
#   'id': 'strategy-pp-variable-xstock',
#   'image': 'https://coin-images.coingecko.com/coins/images/71033/large/Ticker_STRCx__Company_Name_Strategy_PP_Variable__size_200x200.png?1765380234',
#   'last_updated': '2026-05-24T15:50:45.546Z',
#   'low_24h': 9676.77,
#   'market_cap': 13133125006,
#   'market_cap_change_24h': -135014810.88300896,
#   'market_cap_change_percentage_24h': -1.01759,
#   'market_cap_rank': 238,
#   'max_supply': None,
#   'name': 'Strategy PP Variable xStock',
#   'price_change_24h': -101.52538754563284,
#   'price_change_percentage_24h': -1.03587,
#   'roi': None,
#   'symbol': 'strcx',
#   'total_supply': 2391444.792124266,
#   'total_volume': 4910735},
#  {'ath': 1.49,
#   'ath_change_percentage': -91.13717,
#   'ath_date': '2025-03-11T15:16:32.915Z',
#   'atl': 0.00031373,
#   'atl_change_percentage': 41905.08217,
#   'atl_date': '2022-10-11T02:32:18.937Z',
#   'circulating_supply': 98823661261.46,
#   'current_price': 0.131815,
#   'fully_diluted_valuation': 13006660535,
#   'high_24h': 0.133877,
#   'id': 'newton-project',
#   'image': 'https://coin-images.coingecko.com/coins/images/4376/large/400%E6%96%B9.png?1740377493',
#   'last_updated': '2026-05-24T15:50:43.524Z',
#   'low_24h': 0.131542,
#   'market_cap': 13006660535,
#   'market_cap_change_24h': -194129427.1142254,
#   'market_cap_change_percentage_24h': -1.47059,
#   'market_cap_rank': 239,
#   'max_supply': 100000000000.0,
#   'name': 'AB',
#   'price_change_24h': -0.001748255158395245,
#   'price_change_percentage_24h': -1.30893,
#   'roi': {'currency': 'usd',
#           'percentage': -42.60955360601396,
#           'times': -0.42609553606013956},
#   'symbol': 'ab',
#   'total_supply': 98823661261.46,
#   'total_volume': 241840886},
#  {'ath': 7.64,
#   'ath_change_percentage': -38.13507,
#   'ath_date': '2026-05-16T21:45:25.072Z',
#   'atl': 0.268609,
#   'atl_change_percentage': 1658.82592,
#   'atl_date': '2025-12-26T01:53:50.914Z',
#   'circulating_supply': 2737797495.975969,
#   'current_price': 4.75,
#   'fully_diluted_valuation': 12999617715,
#   'high_24h': 5.11,
#   'id': 'xphere',
#   'image': 'https://coin-images.coingecko.com/coins/images/54874/large/oAapmKlz_400x400.png?1742236858',
#   'last_updated': '2026-05-24T15:50:44.193Z',
#   'low_24h': 4.63,
#   'market_cap': 12999127737,
#   'market_cap_change_24h': 143936213,
#   'market_cap_change_percentage_24h': 1.11967,
#   'market_cap_rank': 240,
#   'max_supply': 5500000000.0,
#   'name': 'Xphere',
#   'price_change_24h': 0.04879811,
#   'price_change_percentage_24h': 1.03843,
#   'roi': None,
#   'symbol': 'xp',
#   'total_supply': 2737900692.160037,
#   'total_volume': 137703100},
#  {'ath': 2044.73,
#   'ath_change_percentage': -99.36453,
#   'ath_date': '2022-04-28T21:44:21.164Z',
#   'atl': 7.6,
#   'atl_change_percentage': 71.01576,
#   'atl_date': '2026-04-02T21:56:48.220Z',
#   'circulating_supply': 1000000000.0,
#   'current_price': 13.0,
#   'fully_diluted_valuation': 12994806894,
#   'high_24h': 13.79,
#   'id': 'apecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/24383/large/APECOIN.png?1756551529',
#   'last_updated': '2026-05-24T15:50:41.966Z',
#   'low_24h': 12.96,
#   'market_cap': 12994806894,
#   'market_cap_change_24h': -22170551.138721466,
#   'market_cap_change_percentage_24h': -0.17032,
#   'market_cap_rank': 241,
#   'max_supply': 1000000000.0,
#   'name': 'ApeCoin',
#   'price_change_24h': -0.021788864266339303,
#   'price_change_percentage_24h': -0.16736,
#   'roi': None,
#   'symbol': 'ape',
#   'total_supply': 1000000000.0,
#   'total_volume': 1359803051},
#  {'ath': 6640.2,
#   'ath_change_percentage': -97.03263,
#   'ath_date': '2021-11-05T04:14:42.689Z',
#   'atl': 21.36,
#   'atl_change_percentage': 822.39944,
#   'atl_date': '2020-01-31T06:47:36.543Z',
#   'circulating_supply': 65652466.0,
#   'current_price': 197.13,
#   'fully_diluted_valuation': 12950962195,
#   'high_24h': 205.25,
#   'id': 'arweave',
#   'image': 'https://coin-images.coingecko.com/coins/images/4343/large/oRt6SiEN_400x400.jpg?1696504946',
#   'last_updated': '2026-05-24T15:50:43.574Z',
#   'low_24h': 195.41,
#   'market_cap': 12950962195,
#   'market_cap_change_24h': 32322380,
#   'market_cap_change_percentage_24h': 0.2502,
#   'market_cap_rank': 242,
#   'max_supply': 66000000.0,
#   'name': 'Arweave',
#   'price_change_24h': 0.287002,
#   'price_change_percentage_24h': 0.1458,
#   'roi': {'currency': 'usd',
#           'percentage': 178.36233688150946,
#           'times': 1.7836233688150946},
#   'symbol': 'ar',
#   'total_supply': 65652466.0,
#   'total_volume': 1126438373},
#  {'ath': 97.0,
#   'ath_change_percentage': -1.33986,
#   'ath_date': '2026-05-20T14:15:13.357Z',
#   'atl': 85.32,
#   'atl_change_percentage': 12.17045,
#   'atl_date': '2025-07-04T05:20:06.471Z',
#   'circulating_supply': 134000000.0,
#   'current_price': 95.7,
#   'fully_diluted_valuation': 12823863918,
#   'high_24h': 95.7,
#   'id': 'tradable-latam-fintech-sstn',
#   'image': 'https://coin-images.coingecko.com/coins/images/66796/large/tradable.jpg?1750576421',
#   'last_updated': '2026-05-24T15:45:18.283Z',
#   'low_24h': 95.7,
#   'market_cap': 12823863918,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'market_cap_rank': 243,
#   'max_supply': 300000000.0,
#   'name': 'Tradable LatAm Fintech SSTN',
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'roi': None,
#   'symbol': 'pc0000097',
#   'total_supply': 134000000.0,
#   'total_volume': None},
#  {'ath': 96.99,
#   'ath_change_percentage': -1.35281,
#   'ath_date': '2026-05-21T00:46:05.395Z',
#   'atl': 83.77,
#   'atl_change_percentage': 14.21654,
#   'atl_date': '2025-05-02T06:32:33.156Z',
#   'circulating_supply': 133241059.9183565,
#   'current_price': 95.67,
#   'fully_diluted_valuation': 12746875372,
#   'high_24h': 95.71,
#   'id': 'frax-usd',
#   'image': 'https://coin-images.coingecko.com/coins/images/53963/large/frxUSD.png?1737792154',
#   'last_updated': '2026-05-24T15:50:44.163Z',
#   'low_24h': 95.63,
#   'market_cap': 12747180230,
#   'market_cap_change_24h': 147276790,
#   'market_cap_change_percentage_24h': 1.16887,
#   'market_cap_rank': 244,
#   'max_supply': None,
#   'name': 'Frax USD',
#   'price_change_24h': 0.04607242,
#   'price_change_percentage_24h': 0.04818,
#   'roi': None,
#   'symbol': 'frxusd',
#   'total_supply': 133237873.3657171,
#   'total_volume': 531894811},
#  {'ath': 96.99,
#   'ath_change_percentage': -1.36803,
#   'ath_date': '2026-05-20T14:20:05.204Z',
#   'atl': 80.49,
#   'atl_change_percentage': 18.84984,
#   'atl_date': '2024-12-05T22:30:43.844Z',
#   'circulating_supply': 129222631.851641,
#   'current_price': 95.66,
#   'fully_diluted_valuation': 12361882467,
#   'high_24h': 95.68,
#   'id': 'agora-dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/39284/large/AUSD_1024px.png?1764684132',
#   'last_updated': '2026-05-24T15:50:43.380Z',
#   'low_24h': 95.64,
#   'market_cap': 12361882467,
#   'market_cap_change_24h': 353568,
#   'market_cap_change_percentage_24h': 0.00286,
#   'market_cap_rank': 245,
#   'max_supply': None,
#   'name': 'AUSD',
#   'price_change_24h': -0.000820631716592857,
#   'price_change_percentage_24h': -0.00086,
#   'roi': None,
#   'symbol': 'ausd',
#   'total_supply': 129222631.851641,
#   'total_volume': 3517345144},
#  {'ath': 66.55,
#   'ath_change_percentage': -88.73412,
#   'ath_date': '2025-05-28T08:22:53.913Z',
#   'atl': 6.41,
#   'atl_change_percentage': 16.92889,
#   'atl_date': '2026-02-06T00:26:29.688Z',
#   'circulating_supply': 1643370241.7458,
#   'current_price': 7.49,
#   'fully_diluted_valuation': 15736109147,
#   'high_24h': 7.82,
#   'id': 'vaulta',
#   'image': 'https://coin-images.coingecko.com/coins/images/55616/large/Vaulta_CEX_Icon_Circle_-_cmc.png?1746859132',
#   'last_updated': '2026-05-24T15:50:44.512Z',
#   'low_24h': 7.48,
#   'market_cap': 12314406425,
#   'market_cap_change_24h': -230707291.25224113,
#   'market_cap_change_percentage_24h': -1.83902,
#   'market_cap_rank': 246,
#   'max_supply': 2100000000.0,
#   'name': 'Vaulta',
#   'price_change_24h': -0.14479575149042834,
#   'price_change_percentage_24h': -1.89546,
#   'roi': None,
#   'symbol': 'a',
#   'total_supply': 2100000000.0,
#   'total_volume': 1145041761},
#  {'ath': 1799.83,
#   'ath_change_percentage': -91.23055,
#   'ath_date': '2021-06-16T20:02:32.097Z',
#   'atl': 30.33,
#   'atl_change_percentage': 420.36698,
#   'atl_date': '2022-12-28T16:20:48.360Z',
#   'circulating_supply': 77946996.82034639,
#   'current_price': 157.93,
#   'fully_diluted_valuation': 15783242009,
#   'high_24h': 169.56,
#   'id': 'instadapp',
#   'image': 'https://coin-images.coingecko.com/coins/images/14688/large/Logo_1_%28brighter%29.png?1734430693',
#   'last_updated': '2026-05-24T15:50:41.360Z',
#   'low_24h': 156.82,
#   'market_cap': 12302563147,
#   'market_cap_change_24h': -271470682.9871254,
#   'market_cap_change_percentage_24h': -2.15898,
#   'market_cap_rank': 247,
#   'max_supply': 100000000.0,
#   'name': 'Fluid',
#   'price_change_24h': -3.38293222572716,
#   'price_change_percentage_24h': -2.09708,
#   'roi': None,
#   'symbol': 'fluid',
#   'total_supply': 100000000.0,
#   'total_volume': 278754665},
#  {'ath': 1836.35,
#   'ath_change_percentage': -98.55392,
#   'ath_date': '2021-11-21T17:33:44.178Z',
#   'atl': 9.55,
#   'atl_change_percentage': 178.19297,
#   'atl_date': '2021-06-22T12:52:49.089Z',
#   'circulating_supply': 462277841.3255647,
#   'current_price': 26.56,
#   'fully_diluted_valuation': 14670611911,
#   'high_24h': 26.91,
#   'id': 'wemix-token',
#   'image': 'https://coin-images.coingecko.com/coins/images/12998/large/wemixcoin_color_200.png?1696512788',
#   'last_updated': '2026-05-24T15:50:41.231Z',
#   'low_24h': 26.47,
#   'market_cap': 12275525199,
#   'market_cap_change_24h': -162766.87848472595,
#   'market_cap_change_percentage_24h': -0.00133,
#   'market_cap_rank': 248,
#   'max_supply': 590000000.0,
#   'name': 'WEMIX',
#   'price_change_24h': -0.08716355028953515,
#   'price_change_percentage_24h': -0.32716,
#   'roi': None,
#   'symbol': 'wemix',
#   'total_supply': 552473209.5478008,
#   'total_volume': 101345471},
#  {'ath': 648.39,
#   'ath_change_percentage': -98.6617,
#   'ath_date': '2021-10-27T08:24:54.808Z',
#   'atl': 7.55,
#   'atl_change_percentage': 14.87791,
#   'atl_date': '2026-02-06T00:25:45.794Z',
#   'circulating_supply': 1405573965.7275033,
#   'current_price': 8.68,
#   'fully_diluted_valuation': 13014419920,
#   'high_24h': 8.92,
#   'id': '1inch',
#   'image': 'https://coin-images.coingecko.com/coins/images/13469/large/1inch-logo.jpeg?1759404663',
#   'last_updated': '2026-05-24T15:50:41.289Z',
#   'low_24h': 8.62,
#   'market_cap': 12195153213,
#   'market_cap_change_24h': 72260145,
#   'market_cap_change_percentage_24h': 0.59606,
#   'market_cap_rank': 249,
#   'max_supply': 1500000000.0,
#   'name': '1INCH',
#   'price_change_24h': 0.051035,
#   'price_change_percentage_24h': 0.59166,
#   'roi': None,
#   'symbol': '1inch',
#   'total_supply': 1499999999.997,
#   'total_volume': 620990737},
#  {'ath': 100.55,
#   'ath_change_percentage': -2.30706,
#   'ath_date': '2026-05-21T14:35:25.347Z',
#   'atl': 80.46,
#   'atl_change_percentage': 22.08861,
#   'atl_date': '2025-10-10T21:35:37.536Z',
#   'circulating_supply': 123642410.177315,
#   'current_price': 98.06,
#   'fully_diluted_valuation': 12111736268,
#   'high_24h': 98.7,
#   'id': 'theo-short-duration-us-treasury-fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/67650/large/thBILL.png?1753401034',
#   'last_updated': '2026-05-24T15:50:44.963Z',
#   'low_24h': 97.15,
#   'market_cap': 12111736268,
#   'market_cap_change_24h': -42948410.112298965,
#   'market_cap_change_percentage_24h': -0.35335,
#   'market_cap_rank': 250,
#   'max_supply': None,
#   'name': 'Theo Short Duration US Treasury Fund',
#   'price_change_24h': -0.2273013881797823,
#   'price_change_percentage_24h': -0.23126,
#   'roi': None,
#   'symbol': 'thbill',
#   'total_supply': 123642410.177315,
#   'total_volume': 16383173}]

# %%
print(f"Total Data of Cryptocurrencies: {len(data_crypto)}")
# Out:
# Total Data of Cryptocurrencies: 1250

# %% [markdown]
# **Column Rename**

# %%
rename_columns = []

for i in data_crypto:
  rename_columns.append(dict(
      coin_id = i['id'],
      symbol = i['symbol'],
      coin_name = i['name'],
      current_price = i['current_price'],
      market_cap = i['market_cap'],
      market_cap_rank = i['market_cap_rank'],
      total_volume = i['total_volume'],
      circulating_supply = i['circulating_supply'],
      total_supply = i['total_supply'],
      ath = i['ath'],
      atl = i['atl'],
      last_updated = i['last_updated']
      ))

# %%
pprint.pprint(rename_columns)
# Out:
# [{'ath': 11187013,
#   'atl': 3993.42,
#   'circulating_supply': 20033796.0,
#   'coin_id': 'bitcoin',
#   'coin_name': 'Bitcoin',
#   'current_price': 7308304,
#   'last_updated': '2026-05-24T15:50:44.026Z',
#   'market_cap': 146386017371486,
#   'market_cap_rank': 1,
#   'symbol': 'btc',
#   'total_supply': 20033812.0,
#   'total_volume': 3076641747343},
#  {'ath': 431946,
#   'atl': 28.13,
#   'circulating_supply': 120685539.9707651,
#   'coin_id': 'ethereum',
#   'coin_name': 'Ethereum',
#   'current_price': 200378,
#   'last_updated': '2026-05-24T15:50:42.835Z',
#   'market_cap': 24171984843745,
#   'market_cap_rank': 2,
#   'symbol': 'eth',
#   'total_supply': 120685539.9707651,
#   'total_volume': 1266676989227},
#  {'ath': 105.52,
#   'atl': 36.86,
#   'circulating_supply': 189721145805.9203,
#   'coin_id': 'tether',
#   'coin_name': 'Tether',
#   'current_price': 95.59,
#   'last_updated': '2026-05-24T15:50:43.161Z',
#   'market_cap': 18134047627886,
#   'market_cap_rank': 3,
#   'symbol': 'usdt',
#   'total_supply': 195188087011.4462,
#   'total_volume': 4368704898282},
#  {'ath': 121422,
#   'atl': 2.58,
#   'circulating_supply': 134784946.87,
#   'coin_id': 'binancecoin',
#   'coin_name': 'BNB',
#   'current_price': 62682,
#   'last_updated': '2026-05-24T15:50:44.003Z',
#   'market_cap': 8446532286283,
#   'market_cap_rank': 4,
#   'symbol': 'bnb',
#   'total_supply': 134784944.32,
#   'total_volume': 65614528770},
#  {'ath': 313.99,
#   'atl': 0.159343,
#   'circulating_supply': 61858321245.0,
#   'coin_id': 'ripple',
#   'coin_name': 'XRP',
#   'current_price': 128.98,
#   'last_updated': '2026-05-24T15:50:43.908Z',
#   'market_cap': 7981145342833,
#   'market_cap_rank': 5,
#   'symbol': 'xrp',
#   'total_supply': 99985662685.0,
#   'total_volume': 131052848373},
#  {'ath': 96.98,
#   'atl': 65.31,
#   'circulating_supply': 76433067144.85255,
#   'coin_id': 'usd-coin',
#   'coin_name': 'USDC',
#   'current_price': 95.67,
#   'last_updated': '2026-05-24T15:50:44.789Z',
#   'market_cap': 7313713649235,
#   'market_cap_rank': 6,
#   'symbol': 'usdc',
#   'total_supply': 76431607223.50403,
#   'total_volume': 927080008295},
#  {'ath': 25396,
#   'atl': 38.03,
#   'circulating_supply': 578098853.5945314,
#   'coin_id': 'solana',
#   'coin_name': 'Solana',
#   'current_price': 8159.19,
#   'last_updated': '2026-05-24T15:50:43.635Z',
#   'market_cap': 4715132292418,
#   'market_cap_rank': 7,
#   'symbol': 'sol',
#   'total_supply': 627007423.1525741,
#   'total_volume': 251118010707},
#  {'ath': 36.53,
#   'atl': 0.117589,
#   'circulating_supply': 94804720740.6219,
#   'coin_id': 'tron',
#   'coin_name': 'TRON',
#   'current_price': 34.97,
#   'last_updated': '2026-05-24T15:50:41.309Z',
#   'market_cap': 3315695110115,
#   'market_cap_rank': 8,
#   'symbol': 'trx',
#   'total_supply': 94807953257.69919,
#   'total_volume': 43313747786},
#  {'ath': 100.4,
#   'atl': 13.78,
#   'circulating_supply': 18079770536.887,
#   'coin_id': 'figure-heloc',
#   'coin_name': 'Figure Heloc',
#   'current_price': 98.57,
#   'last_updated': '2026-05-24T03:06:45.343Z',
#   'market_cap': 1782149944364,
#   'market_cap_rank': 9,
#   'symbol': 'figr_heloc',
#   'total_supply': 18079770536.887,
#   'total_volume': 10151878},
#  {'ath': 53.62,
#   'atl': 0.00552883,
#   'circulating_supply': 154372206383.7052,
#   'coin_id': 'dogecoin',
#   'coin_name': 'Dogecoin',
#   'current_price': 9.75,
#   'last_updated': '2026-05-24T15:50:43.904Z',
#   'market_cap': 1504990371577,
#   'market_cap_rank': 10,
#   'symbol': 'doge',
#   'total_supply': 170084603126.5791,
#   'total_volume': 66426758963},
#  {'ath': 6151.13,
#   'atl': 321.88,
#   'circulating_supply': 238385315.9541414,
#   'coin_id': 'hyperliquid',
#   'coin_name': 'Hyperliquid',
#   'current_price': 6089.03,
#   'last_updated': '2026-05-24T15:50:43.693Z',
#   'market_cap': 1448002731593,
#   'market_cap_rank': 11,
#   'symbol': 'hype',
#   'total_supply': 962274028.9541414,
#   'total_volume': 117577835209},
#  {'ath': 107.5,
#   'atl': 79.67,
#   'circulating_supply': 11137719564.26634,
#   'coin_id': 'usds',
#   'coin_name': 'USDS',
#   'current_price': 95.65,
#   'last_updated': '2026-05-24T15:50:43.629Z',
#   'market_cap': 1065270069740,
#   'market_cap_rank': 12,
#   'symbol': 'usds',
#   'total_supply': 11140584915.09768,
#   'total_volume': 1479260502},
#  {'ath': 211171,
#   'atl': 1342.38,
#   'circulating_supply': 16688225.1655448,
#   'coin_id': 'zcash',
#   'coin_name': 'Zcash',
#   'current_price': 63059,
#   'last_updated': '2026-05-24T15:50:44.260Z',
#   'market_cap': 1050950478259,
#   'market_cap_rank': 13,
#   'symbol': 'zec',
#   'total_supply': 16688225.1655448,
#   'total_volume': 77819571095},
#  {'ath': 1004.84,
#   'atl': 56.97,
#   'circulating_supply': 920557129.9,
#   'coin_id': 'leo-token',
#   'coin_name': 'LEO Token',
#   'current_price': 959.99,
#   'last_updated': '2026-05-24T15:50:44.058Z',
#   'market_cap': 883730613959,
#   'market_cap_rank': 14,
#   'symbol': 'leo',
#   'total_supply': 985239504.0,
#   'total_volume': 29171687},
#  {'ath': 225.26,
#   'atl': 1.38,
#   'circulating_supply': 37001084154.71531,
#   'coin_id': 'cardano',
#   'coin_name': 'Cardano',
#   'current_price': 23.23,
#   'last_updated': '2026-05-24T15:50:26.533Z',
#   'market_cap': 859452927743,
#   'market_cap_rank': 15,
#   'symbol': 'ada',
#   'total_supply': 45000000000.0,
#   'total_volume': 28951389938},
#  {'ath': 72026,
#   'atl': 13.57,
#   'circulating_supply': 18446744.07370955,
#   'coin_id': 'monero',
#   'coin_name': 'Monero',
#   'current_price': 37436,
#   'last_updated': '2026-05-24T15:50:45.582Z',
#   'market_cap': 690297446998,
#   'market_cap_rank': 16,
#   'symbol': 'xmr',
#   'total_supply': 18446744.07370955,
#   'total_volume': 7636066882},
#  {'ath': 242198,
#   'atl': 5536.54,
#   'circulating_supply': 20038790.52165078,
#   'coin_id': 'bitcoin-cash',
#   'coin_name': 'Bitcoin Cash',
#   'current_price': 33442,
#   'last_updated': '2026-05-24T15:50:26.115Z',
#   'market_cap': 670250122485,
#   'market_cap_rank': 17,
#   'symbol': 'bch',
#   'total_supply': 20038812.39665078,
#   'total_volume': 33899343093},
#  {'ath': 3862.15,
#   'atl': 9.55,
#   'circulating_supply': 727099970.4255477,
#   'coin_id': 'chainlink',
#   'coin_name': 'Chainlink',
#   'current_price': 901.86,
#   'last_updated': '2026-05-24T15:50:26.440Z',
#   'market_cap': 655446791110,
#   'market_cap_rank': 18,
#   'symbol': 'link',
#   'total_supply': 1000000000.0,
#   'total_volume': 27156662223},
#  {'ath': 5788.09,
#   'atl': 245.71,
#   'circulating_supply': 118458551.0,
#   'coin_id': 'whitebit',
#   'coin_name': 'WhiteBIT Coin',
#   'current_price': 5388.19,
#   'last_updated': '2026-05-24T15:50:42.222Z',
#   'market_cap': 638269818133,
#   'market_cap_rank': 19,
#   'symbol': 'wbt',
#   'total_supply': 294358550.0,
#   'total_volume': 11160114781},
#  {'ath': 17.72,
#   'atl': 5.31,
#   'circulating_supply': 38614942722.34335,
#   'coin_id': 'canton-network',
#   'coin_name': 'Canton',
#   'current_price': 15.92,
#   'last_updated': '2026-05-24T15:50:45.583Z',
#   'market_cap': 614386906069,
#   'market_cap_rank': 20,
#   'symbol': 'cc',
#   'total_supply': 38616169338.51177,
#   'total_volume': 895609104},
#  {'ath': 55.54,
#   'atl': 0.02966141,
#   'circulating_supply': 33528148789.57752,
#   'coin_id': 'stellar',
#   'coin_name': 'Stellar',
#   'current_price': 14.06,
#   'last_updated': '2026-05-24T15:50:40.802Z',
#   'market_cap': 470986503474,
#   'market_cap_rank': 21,
#   'symbol': 'xlm',
#   'total_supply': 50001786839.91458,
#   'total_volume': 8057299098},
#  {'ath': 96.97,
#   'atl': 83.75,
#   'circulating_supply': 4786390649.798471,
#   'coin_id': 'usd1-wlfi',
#   'coin_name': 'USD1',
#   'current_price': 95.58,
#   'last_updated': '2026-05-24T15:50:44.606Z',
#   'market_cap': 457467285809,
#   'market_cap_rank': 22,
#   'symbol': 'usd1',
#   'total_supply': 4786440649.798471,
#   'total_volume': 100596899081},
#  {'ath': 689.6,
#   'atl': 38.25,
#   'circulating_supply': 2694356840.120929,
#   'coin_id': 'the-open-network',
#   'coin_name': 'Toncoin',
#   'current_price': 166.83,
#   'last_updated': '2026-05-24T15:50:41.597Z',
#   'market_cap': 449416165462,
#   'market_cap_rank': 23,
#   'symbol': 'ton',
#   'total_supply': 5185282276.235128,
#   'total_volume': 19381731942},
#  {'ath': 96.97,
#   'atl': 78.05,
#   'circulating_supply': 4451953432.964992,
#   'coin_id': 'ethena-usde',
#   'coin_name': 'Ethena USDe',
#   'current_price': 95.58,
#   'last_updated': '2026-05-24T15:50:42.815Z',
#   'market_cap': 425550103695,
#   'market_cap_rank': 24,
#   'symbol': 'usde',
#   'total_supply': 4451953432.964992,
#   'total_volume': 8776759505},
#  {'ath': 96.98,
#   'atl': 64.85,
#   'circulating_supply': 4354615071.439,
#   'coin_id': 'dai',
#   'coin_name': 'Dai',
#   'current_price': 95.67,
#   'last_updated': '2026-05-24T15:50:26.322Z',
#   'market_cap': 416597711374,
#   'market_cap_rank': 25,
#   'symbol': 'dai',
#   'total_supply': 4360140886.711814,
#   'total_volume': 11579340563},
#  {'ath': 458.6,
#   'atl': 30.36,
#   'circulating_supply': 4005418369.566699,
#   'coin_id': 'sui',
#   'coin_name': 'Sui',
#   'current_price': 99.91,
#   'last_updated': '2026-05-24T15:50:42.080Z',
#   'market_cap': 400170787791,
#   'market_cap_rank': 26,
#   'symbol': 'sui',
#   'total_supply': 10000000000.0,
#   'total_volume': 64068759832},
#  {'ath': 30082,
#   'atl': 72.12,
#   'circulating_supply': 77202401.98347135,
#   'coin_id': 'litecoin',
#   'coin_name': 'Litecoin',
#   'current_price': 5048.59,
#   'last_updated': '2026-05-24T15:50:42.010Z',
#   'market_cap': 389903076118,
#   'market_cap_rank': 27,
#   'symbol': 'ltc',
#   'total_supply': 77204958.23347135,
#   'total_volume': 20060594503},
#  {'ath': 10772.35,
#   'atl': 204.63,
#   'circulating_supply': 431771961.1772119,
#   'coin_id': 'avalanche-2',
#   'coin_name': 'Avalanche',
#   'current_price': 883.29,
#   'last_updated': '2026-05-24T15:50:41.137Z',
#   'market_cap': 381145954550,
#   'market_cap_rank': 28,
#   'symbol': 'avax',
#   'total_supply': 463441061.1772119,
#   'total_volume': 17511556323},
#  {'ath': 41.81,
#   'atl': 0.703644,
#   'circulating_supply': 43373490530.38489,
#   'coin_id': 'hedera-hashgraph',
#   'coin_name': 'Hedera',
#   'current_price': 8.49,
#   'last_updated': '2026-05-24T15:50:43.163Z',
#   'market_cap': 368054799228,
#   'market_cap_rank': 29,
#   'symbol': 'hbar',
#   'total_supply': 50000000000.0,
#   'total_volume': 4960197001},
#  {'ath': 453.47,
#   'atl': 4.05,
#   'circulating_supply': 1304954247.430681,
#   'coin_id': 'memecore',
#   'coin_name': 'MemeCore',
#   'current_price': 280.03,
#   'last_updated': '2026-05-24T15:50:44.261Z',
#   'market_cap': 365650915031,
#   'market_cap_rank': 30,
#   'symbol': 'm',
#   'total_supply': 5372286439.832738,
#   'total_volume': 620441116},
#  {'ath': 100.8,
#   'atl': 80.95,
#   'circulating_supply': 3615224440.932459,
#   'coin_id': 'paypal-usd',
#   'coin_name': 'PayPal USD',
#   'current_price': 95.67,
#   'last_updated': '2026-05-24T15:50:42.447Z',
#   'market_cap': 345868652166,
#   'market_cap_rank': 31,
#   'symbol': 'pyusd',
#   'total_supply': 3615224440.932459,
#   'total_volume': 3488766511},
#  {'ath': 0.989197,
#   'atl': 0.196087,
#   'circulating_supply': 479110542855.1364,
#   'coin_id': 'rain',
#   'coin_name': 'Rain',
#   'current_price': 0.70993,
#   'last_updated': '2026-05-24T15:50:45.225Z',
#   'market_cap': 340153477535,
#   'market_cap_rank': 32,
#   'symbol': 'rain',
#   'total_supply': 1149896726504.505,
#   'total_volume': 2214970136},
#  {'ath': 0.00645756,
#   'atl': 4.169e-09,
#   'circulating_supply': 589243266197270.2,
#   'coin_id': 'shiba-inu',
#   'coin_name': 'Shiba Inu',
#   'current_price': 0.00053427,
#   'last_updated': '2026-05-24T15:50:41.131Z',
#   'market_cap': 314561876646,
#   'market_cap_rank': 33,
#   'symbol': 'shib',
#   'total_supply': 589499893114273.9,
#   'total_volume': 6695015795},
#  {'ath': 1518.16,
#   'atl': 39.17,
#   'circulating_supply': 1296351039.0,
#   'coin_id': 'near',
#   'coin_name': 'NEAR Protocol',
#   'current_price': 233.25,
#   'last_updated': '2026-05-24T15:50:40.972Z',
#   'market_cap': 301526439787,
#   'market_cap_rank': 34,
#   'symbol': 'near',
#   'total_supply': 1296351031.0,
#   'total_volume': 97591563889},
#  {'ath': 66.37,
#   'atl': 0.864137,
#   'circulating_supply': 44791304735.57631,
#   'coin_id': 'crypto-com-chain',
#   'coin_name': 'Cronos',
#   'current_price': 6.59,
#   'last_updated': '2026-05-24T15:50:25.964Z',
#   'market_cap': 295420529141,
#   'market_cap_rank': 35,
#   'symbol': 'cro',
#   'total_supply': 98657996172.03961,
#   'total_volume': 818233742},
#  {'ath': 108.39,
#   'atl': 86.89,
#   'circulating_supply': 2663603923.787158,
#   'coin_id': 'hashnote-usyc',
#   'coin_name': 'Circle USYC',
#   'current_price': 107.76,
#   'last_updated': '2026-05-23T17:47:24.985Z',
#   'market_cap': 287039708901,
#   'market_cap_rank': 36,
#   'symbol': 'usyc',
#   'total_supply': 2663603923.787158,
#   'total_volume': 459392},
#  {'ath': 143.35,
#   'atl': 76.61,
#   'circulating_supply': 2748812719.020469,
#   'coin_id': 'global-dollar',
#   'coin_name': 'Global Dollar',
#   'current_price': 95.68,
#   'last_updated': '2026-05-24T15:50:43.692Z',
#   'market_cap': 263007037190,
#   'market_cap_rank': 37,
#   'symbol': 'usdg',
#   'total_supply': 2748812719.020469,
#   'total_volume': 4881925031},
#  {'ath': 506656,
#   'atl': 108167,
#   'circulating_supply': 592823.659532,
#   'coin_id': 'tether-gold',
#   'coin_name': 'Tether Gold',
#   'current_price': 431043,
#   'last_updated': '2026-05-24T15:50:40.846Z',
#   'market_cap': 255521860640,
#   'market_cap_rank': 38,
#   'symbol': 'xaut',
#   'total_supply': 707747.089,
#   'total_volume': 19948714630},
#  {'ath': 62722,
#   'atl': 2535.93,
#   'circulating_supply': 9597491.0,
#   'coin_id': 'bittensor',
#   'coin_name': 'Bittensor',
#   'current_price': 26357,
#   'last_updated': '2026-05-24T15:50:42.381Z',
#   'market_cap': 252861240590,
#   'market_cap_rank': 39,
#   'symbol': 'tao',
#   'total_supply': 21000000.0,
#   'total_volume': 20749195767},
#  {'ath': 97.01,
#   'atl': 83.81,
#   'circulating_supply': 2511778552.860449,
#   'coin_id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'coin_name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:50:11.693Z',
#   'market_cap': 240378405627,
#   'market_cap_rank': 40,
#   'symbol': 'buidl',
#   'total_supply': 2511778552.860449,
#   'total_volume': None},
#  {'ath': 253.43,
#   'atl': 25.64,
#   'circulating_supply': 3302294382.53684,
#   'coin_id': 'mantle',
#   'coin_name': 'Mantle',
#   'current_price': 62.45,
#   'last_updated': '2026-05-24T15:50:42.520Z',
#   'market_cap': 206219195821,
#   'market_cap_rank': 41,
#   'symbol': 'mnt',
#   'total_supply': 6219316794.889999,
#   'total_volume': 2657354055},
#  {'ath': 181.52,
#   'atl': 6.83,
#   'circulating_supply': 4869330647.0,
#   'coin_id': 'ondo-finance',
#   'coin_name': 'Ondo',
#   'current_price': 42.38,
#   'last_updated': '2026-05-24T15:50:42.101Z',
#   'market_cap': 206121562016,
#   'market_cap_rank': 42,
#   'symbol': 'ondo',
#   'total_supply': 10000000000.0,
#   'total_volume': 31794600035},
#  {'ath': 3333.06,
#   'atl': 75.81,
#   'circulating_supply': 635699562.7428479,
#   'coin_id': 'uniswap',
#   'coin_name': 'Uniswap',
#   'current_price': 323.98,
#   'last_updated': '2026-05-24T15:50:41.757Z',
#   'market_cap': 205888395550,
#   'market_cap_rank': 43,
#   'symbol': 'uni',
#   'total_supply': 895334420.0329479,
#   'total_volume': 11846948456},
#  {'ath': 110.62,
#   'atl': 77.42,
#   'circulating_supply': 1889179688.172766,
#   'coin_id': 'ondo-us-dollar-yield',
#   'coin_name': 'Ondo US Dollar Yield',
#   'current_price': 108.84,
#   'last_updated': '2026-05-24T15:50:43.011Z',
#   'market_cap': 205605566707,
#   'market_cap_rank': 44,
#   'symbol': 'usdy',
#   'total_supply': 1889179688.172766,
#   'total_volume': 138590042},
#  {'ath': 4095.22,
#   'atl': 103.91,
#   'circulating_supply': 1685286630.383482,
#   'coin_id': 'polkadot',
#   'coin_name': 'Polkadot',
#   'current_price': 120.65,
#   'last_updated': '2026-05-24T15:50:41.094Z',
#   'market_cap': 203269632527,
#   'market_cap_rank': 45,
#   'symbol': 'dot',
#   'total_supply': 1685290894.794631,
#   'total_volume': 13105577203},
#  {'ath': 516779,
#   'atl': 100361,
#   'circulating_supply': 470301.37,
#   'coin_id': 'pax-gold',
#   'coin_name': 'PAX Gold',
#   'current_price': 432263,
#   'last_updated': '2026-05-24T15:50:26.286Z',
#   'market_cap': 203267724908,
#   'market_cap_rank': 46,
#   'symbol': 'paxg',
#   'total_supply': 470301.37,
#   'total_volume': 10023294350},
#  {'ath': 29.22,
#   'atl': 4.9,
#   'circulating_supply': 31773134306.0,
#   'coin_id': 'world-liberty-financial',
#   'coin_name': 'World Liberty Financial',
#   'current_price': 5.9,
#   'last_updated': '2026-05-24T15:50:43.971Z',
#   'market_cap': 187289112999,
#   'market_cap_rank': 47,
#   'symbol': 'wlfi',
#   'total_supply': 100000000000.0,
#   'total_volume': 2941231216},
#  {'ath': 213.7,
#   'atl': 8.76,
#   'circulating_supply': 2579922243.4698935,
#   'coin_id': 'aster-2',
#   'coin_name': 'Aster',
#   'current_price': 67.8,
#   'last_updated': '2026-05-24T15:50:45.506Z',
#   'market_cap': 174601420984,
#   'market_cap_rank': 48,
#   'symbol': 'aster',
#   'total_supply': 7822218820.515041,
#   'total_volume': 14559512365},
#  {'ath': 0.00031771,
#   'atl': 6.739e-05,
#   'circulating_supply': 905707664073577.8,
#   'coin_id': 'htx-dao',
#   'coin_name': 'HTX DAO',
#   'current_price': 0.00019226,
#   'last_updated': '2026-05-24T15:50:43.462Z',
#   'market_cap': 174123333410,
#   'market_cap_rank': 49,
#   'symbol': 'htx',
#   'total_supply': 905707664073577.8,
#   'total_volume': 1413592548},
#  {'ath': 96.79,
#   'atl': 80.47,
#   'circulating_supply': 1784655676.344749,
#   'coin_id': 'falcon-finance',
#   'coin_name': 'Falcon USD',
#   'current_price': 95.39,
#   'last_updated': '2026-05-24T15:50:44.184Z',
#   'market_cap': 170234003987,
#   'market_cap_rank': 50,
#   'symbol': 'usdf',
#   'total_supply': 1784655676.344749,
#   'total_volume': 133730542},
#  {'ath': 97.01,
#   'atl': 81.72,
#   'circulating_supply': 1749663362.596745,
#   'coin_id': 'ripple-usd',
#   'coin_name': 'Ripple USD',
#   'current_price': 95.71,
#   'last_updated': '2026-05-24T15:50:43.437Z',
#   'market_cap': 167465878885,
#   'market_cap_rank': 51,
#   'symbol': 'rlusd',
#   'total_supply': 1749663362.596745,
#   'total_volume': 8910509348},
#  {'ath': 20297,
#   'atl': 40.86,
#   'circulating_supply': 21000000.0,
#   'coin_id': 'okb',
#   'coin_name': 'OKB',
#   'current_price': 7884.57,
#   'last_updated': '2026-05-24T15:50:43.606Z',
#   'market_cap': 165559057149,
#   'market_cap_rank': 52,
#   'symbol': 'okb',
#   'total_supply': 21000000.0,
#   'total_volume': 864745778},
#  {'ath': 8.62,
#   'atl': 3.12,
#   'circulating_supply': 23227109059.381252,
#   'coin_id': 'sky',
#   'coin_name': 'Sky',
#   'current_price': 6.68,
#   'last_updated': '2026-05-24T15:50:43.529Z',
#   'market_cap': 154981014009,
#   'market_cap_rank': 53,
#   'symbol': 'sky',
#   'total_supply': 23462665147.36596,
#   'total_volume': 703422845},
#  {'ath': 260.4,
#   'atl': 11.91,
#   'circulating_supply': 10592041067.84851,
#   'coin_id': 'pi-network',
#   'coin_name': 'Pi Network',
#   'current_price': 14.32,
#   'last_updated': '2026-05-24T15:50:44.140Z',
#   'market_cap': 151646165864,
#   'market_cap_rank': 54,
#   'symbol': 'pi',
#   'total_supply': 16295447796.69001,
#   'total_volume': 971608863},
#  {'ath': 96.99,
#   'atl': 72.35,
#   'circulating_supply': 1512858460.0,
#   'coin_id': 'usdd',
#   'coin_name': 'USDD',
#   'current_price': 95.59,
#   'last_updated': '2026-05-24T15:50:41.931Z',
#   'market_cap': 144607507907,
#   'market_cap_rank': 55,
#   'symbol': 'usdd',
#   'total_supply': 1512808460.0,
#   'total_volume': 220908411},
#  {'ath': 0.00237833,
#   'atl': 4.52e-06,
#   'circulating_supply': 420690000000000.0,
#   'coin_id': 'pepe',
#   'coin_name': 'Pepe',
#   'current_price': 0.00034224,
#   'last_updated': '2026-05-24T15:50:42.366Z',
#   'market_cap': 143915962587,
#   'market_cap_rank': 56,
#   'symbol': 'pepe',
#   'total_supply': 420690000000000.0,
#   'total_volume': 15232014668},
#  {'ath': 51433,
#   'atl': 183.62,
#   'circulating_supply': 553022826.3414009,
#   'coin_id': 'internet-computer',
#   'coin_name': 'Internet Computer',
#   'current_price': 244.19,
#   'last_updated': '2026-05-24T15:50:41.567Z',
#   'market_cap': 134995860562,
#   'market_cap_rank': 57,
#   'symbol': 'icp',
#   'total_supply': 553022826.3414009,
#   'total_volume': 5496175444},
#  {'ath': 361.23,
#   'atl': 60.2,
#   'circulating_supply': 633139698.5374187,
#   'coin_id': 'morpho',
#   'coin_name': 'Morpho',
#   'current_price': 212.62,
#   'last_updated': '2026-05-24T15:50:42.252Z',
#   'market_cap': 134592832613,
#   'market_cap_rank': 58,
#   'symbol': 'morpho',
#   'total_supply': 1000000000.0,
#   'total_volume': 1689718222},
#  {'ath': 12296.58,
#   'atl': 41.44,
#   'circulating_supply': 156559601.6228963,
#   'coin_id': 'ethereum-classic',
#   'coin_name': 'Ethereum Classic',
#   'current_price': 854.2,
#   'last_updated': '2026-05-24T15:50:43.862Z',
#   'market_cap': 133586853365,
#   'market_cap_rank': 59,
#   'symbol': 'etc',
#   'total_supply': 156559601.6228963,
#   'total_volume': 3453421675},
#  {'ath': 722.65,
#   'atl': 1.081,
#   'circulating_supply': 699992035.9787906,
#   'coin_id': 'bitget-token',
#   'coin_name': 'Bitget Token',
#   'current_price': 188.52,
#   'last_updated': '2026-05-24T15:50:40.852Z',
#   'market_cap': 131971891489,
#   'market_cap_rank': 60,
#   'symbol': 'bgb',
#   'total_supply': 913931280.9787906,
#   'total_volume': 1333691748},
#  {'ath': 96.87,
#   'atl': 86.85,
#   'circulating_supply': 1320000000.0,
#   'coin_id': 'bfusd',
#   'coin_name': 'BFUSD',
#   'current_price': 95.56,
#   'last_updated': '2026-05-24T15:50:44.955Z',
#   'market_cap': 126136257990,
#   'market_cap_rank': 61,
#   'symbol': 'bfusd',
#   'total_supply': 1320000000.0,
#   'total_volume': 26017132},
#  {'ath': 48387,
#   'atl': 1933.39,
#   'circulating_supply': 15179911.874935383,
#   'coin_id': 'aave',
#   'coin_name': 'Aave',
#   'current_price': 8209.31,
#   'last_updated': '2026-05-24T15:50:41.332Z',
#   'market_cap': 124589871707,
#   'market_cap_rank': 62,
#   'symbol': 'aave',
#   'total_supply': 16000000.0,
#   'total_volume': 14589508807},
#  {'ath': 31427,
#   'atl': 15.06,
#   'circulating_supply': 14544176.164081175,
#   'coin_id': 'quant-network',
#   'coin_name': 'Quant',
#   'current_price': 7635.99,
#   'last_updated': '2026-05-24T15:50:42.789Z',
#   'market_cap': 111033117034,
#   'market_cap_rank': 63,
#   'symbol': 'qnt',
#   'total_supply': 14612493.0,
#   'total_volume': 1964770461},
#  {'ath': 96.94,
#   'atl': 77.41,
#   'circulating_supply': 1089208402.796182,
#   'coin_id': 'usdtb',
#   'coin_name': 'USDtb',
#   'current_price': 95.64,
#   'last_updated': '2026-05-24T15:50:43.916Z',
#   'market_cap': 104166724701,
#   'market_cap_rank': 64,
#   'symbol': 'usdtb',
#   'total_supply': 1089208402.796182,
#   'total_volume': 100005078},
#  {'ath': 2158.41,
#   'atl': 24.48,
#   'circulating_supply': 134655021.7355671,
#   'coin_id': 'kucoin-shares',
#   'coin_name': 'KuCoin',
#   'current_price': 768.69,
#   'last_updated': '2026-05-24T15:50:40.738Z',
#   'market_cap': 103480072242,
#   'market_cap_rank': 65,
#   'symbol': 'kcs',
#   'total_supply': 142155021.7355671,
#   'total_volume': 257282156},
#  {'ath': 118.63,
#   'atl': 84.72,
#   'circulating_supply': 866127792.27097,
#   'coin_id': 'eutbl',
#   'coin_name': 'Spiko EU T-Bills Money Market Fund',
#   'current_price': 116.84,
#   'last_updated': '2026-05-24T15:40:18.683Z',
#   'market_cap': 101201254851,
#   'market_cap_rank': 66,
#   'symbol': 'eutbl',
#   'total_supply': 866127792.27097,
#   'total_volume': None},
#  {'ath': 3233.07,
#   'atl': 87.61,
#   'circulating_supply': 510310254.147613,
#   'coin_id': 'cosmos',
#   'coin_name': 'Cosmos Hub',
#   'current_price': 196.46,
#   'last_updated': '2026-05-24T15:50:41.944Z',
#   'market_cap': 100314901809,
#   'market_cap_rank': 67,
#   'symbol': 'atom',
#   'total_supply': 510318072.721986,
#   'total_volume': 3256036587},
#  {'ath': 971.56,
#   'atl': 22.04,
#   'circulating_supply': 3414545758.127662,
#   'coin_id': 'worldcoin-wld',
#   'coin_name': 'Worldcoin',
#   'current_price': 28.86,
#   'last_updated': '2026-05-24T15:50:42.633Z',
#   'market_cap': 98518668394,
#   'market_cap_rank': 68,
#   'symbol': 'wld',
#   'total_supply': 10000000000.0,
#   'total_volume': 22483575602},
#  {'ath': 97.11,
#   'atl': 86.73,
#   'circulating_supply': 1027858682.01,
#   'coin_id': 'united-stables',
#   'coin_name': 'United Stables',
#   'current_price': 95.61,
#   'last_updated': '2026-05-24T15:50:26.041Z',
#   'market_cap': 98310690334,
#   'market_cap_rank': 69,
#   'symbol': 'u',
#   'total_supply': 1027858682.01,
#   'total_volume': 17032050473},
#  {'ath': 1121.89,
#   'atl': 2.79,
#   'circulating_supply': 518743261.0140742,
#   'coin_id': 'render-token',
#   'coin_name': 'Render',
#   'current_price': 187.47,
#   'last_updated': '2026-05-24T15:50:41.096Z',
#   'market_cap': 97211305183,
#   'market_cap_rank': 70,
#   'symbol': 'render',
#   'total_supply': 533503434.2940742,
#   'total_volume': 8415390519},
#  {'ath': 247.29,
#   'atl': 7.26,
#   'circulating_supply': 8917352824.722261,
#   'coin_id': 'algorand',
#   'coin_name': 'Algorand',
#   'current_price': 10.73,
#   'last_updated': '2026-05-24T15:50:43.807Z',
#   'market_cap': 95670090709,
#   'market_cap_rank': 71,
#   'symbol': 'algo',
#   'total_supply': 8917571232.868385,
#   'total_volume': 2457034921},
#  {'ath': 1075.49,
#   'atl': 876.83,
#   'circulating_supply': 88650971.385841,
#   'coin_id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'coin_name': 'Superstate Short Duration U.S. Government Securities Fund '
#                '(USTB)',
#   'current_price': 1061.28,
#   'last_updated': '2026-05-24T15:50:09.424Z',
#   'market_cap': 94083079579,
#   'market_cap_rank': 72,
#   'symbol': 'ustb',
#   'total_supply': 88831274.659553,
#   'total_volume': None},
#  {'ath': 10258.25,
#   'atl': 1516.02,
#   'circulating_supply': 9112111.0,
#   'coin_id': 'blockchain-capital',
#   'coin_name': 'Blockchain Capital',
#   'current_price': 10119.37,
#   'last_updated': '2026-05-24T15:50:08.833Z',
#   'market_cap': 92208808457,
#   'market_cap_rank': 73,
#   'symbol': 'bcap',
#   'total_supply': 9112111.0,
#   'total_volume': None},
#  {'ath': 106.68,
#   'atl': 7.58,
#   'circulating_supply': 10648620284.29958,
#   'coin_id': 'polygon-ecosystem-token',
#   'coin_name': 'POL (ex-MATIC)',
#   'current_price': 8.65,
#   'last_updated': '2026-05-24T15:50:42.551Z',
#   'market_cap': 92139200891,
#   'market_cap_rank': 74,
#   'symbol': 'pol',
#   'total_supply': 10648620284.29958,
#   'total_volume': 3111322585},
#  {'ath': 107.1,
#   'atl': 95.98,
#   'circulating_supply': 850609381.31547,
#   'coin_id': 'janus-henderson-anemoy-treasury-fund',
#   'coin_name': 'Janus Henderson Anemoy Treasury Fund',
#   'current_price': 105.67,
#   'last_updated': '2026-05-24T15:50:02.868Z',
#   'market_cap': 89880863090,
#   'market_cap_rank': 75,
#   'symbol': 'jtrsy',
#   'total_supply': 850609381.31547,
#   'total_volume': None},
#  {'ath': 1952.18,
#   'atl': 82.42,
#   'circulating_supply': 46342744.63030691,
#   'coin_id': 'venice-token',
#   'coin_name': 'Venice Token',
#   'current_price': 1936.66,
#   'last_updated': '2026-05-24T15:50:44.125Z',
#   'market_cap': 89797860428,
#   'market_cap_rank': 76,
#   'symbol': 'vvv',
#   'total_supply': 80076527.48421782,
#   'total_volume': 8525081209},
#  {'ath': 17.36,
#   'atl': 0.01327337,
#   'circulating_supply': 27416658504.52483,
#   'coin_id': 'kaspa',
#   'coin_name': 'Kaspa',
#   'current_price': 3.18,
#   'last_updated': '2026-05-24T15:50:42.124Z',
#   'market_cap': 87326526770,
#   'market_cap_rank': 77,
#   'symbol': 'kas',
#   'total_supply': 27459951452.02709,
#   'total_volume': 967630709},
#  {'ath': 126.48,
#   'atl': 7.15,
#   'circulating_supply': 9026562500.0,
#   'coin_id': 'ethena',
#   'coin_name': 'Ethena',
#   'current_price': 9.47,
#   'last_updated': '2026-05-24T15:50:43.484Z',
#   'market_cap': 85415990165,
#   'market_cap_rank': 78,
#   'symbol': 'ena',
#   'total_supply': 15000000000.0,
#   'total_volume': 7443735015},
#  {'ath': 298.99,
#   'atl': 3.25,
#   'circulating_supply': 1000000000.0,
#   'coin_id': 'nexo',
#   'coin_name': 'NEXO',
#   'current_price': 82.14,
#   'last_updated': '2026-05-24T15:50:43.110Z',
#   'market_cap': 82212193771,
#   'market_cap_rank': 79,
#   'symbol': 'nexo',
#   'total_supply': 1000000000.0,
#   'total_volume': 806736029},
#  {'ath': 14.19,
#   'atl': 0.359754,
#   'circulating_supply': 8543764567.312736,
#   'coin_id': 'just',
#   'coin_name': 'JUST',
#   'current_price': 8.95,
#   'last_updated': '2026-05-24T15:50:40.912Z',
#   'market_cap': 76424935329,
#   'market_cap_rank': 80,
#   'symbol': 'jst',
#   'total_supply': 8543764567.312736,
#   'total_volume': 2301823368},
#  {'ath': 1622.34,
#   'atl': 72.2,
#   'circulating_supply': 819473954.8464024,
#   'coin_id': 'aptos',
#   'coin_name': 'Aptos',
#   'current_price': 90.78,
#   'last_updated': '2026-05-24T15:50:42.186Z',
#   'market_cap': 74378410916,
#   'market_cap_rank': 81,
#   'symbol': 'apt',
#   'total_supply': 1203153234.69234,
#   'total_volume': 5668901303},
#  {'ath': 4.08,
#   'atl': 0.827533,
#   'circulating_supply': 22967292181.0,
#   'coin_id': 'stable-2',
#   'coin_name': '\u200b\u200bStable',
#   'current_price': 3.22,
#   'last_updated': '2026-05-24T15:50:45.356Z',
#   'market_cap': 73948270590,
#   'market_cap_rank': 82,
#   'symbol': 'stable',
#   'total_supply': 100000000000.0,
#   'total_volume': 1465955037},
#  {'ath': 17367.85,
#   'atl': 73.41,
#   'circulating_supply': 783061104.0,
#   'coin_id': 'filecoin',
#   'coin_name': 'Filecoin',
#   'current_price': 91.26,
#   'last_updated': '2026-05-24T15:50:42.831Z',
#   'market_cap': 71440605913,
#   'market_cap_rank': 83,
#   'symbol': 'fil',
#   'total_supply': 1957786662.0,
#   'total_volume': 6559973456},
#  {'ath': 2187.52,
#   'atl': 19.44,
#   'circulating_supply': 106483509.17747103,
#   'coin_id': 'gatechain-token',
#   'coin_name': 'Gate',
#   'current_price': 670.46,
#   'last_updated': '2026-05-24T15:50:26.011Z',
#   'market_cap': 71382144949,
#   'market_cap_rank': 84,
#   'symbol': 'gt',
#   'total_supply': 121304804.66747102,
#   'total_volume': 171013361},
#  {'ath': 12.35,
#   'atl': 0.674474,
#   'circulating_supply': 86293192101.18527,
#   'coin_id': 'flare-networks',
#   'coin_name': 'Flare',
#   'current_price': 0.796591,
#   'last_updated': '2026-05-24T15:50:42.162Z',
#   'market_cap': 68735284211,
#   'market_cap_rank': 85,
#   'symbol': 'flr',
#   'total_supply': 105887515472.5254,
#   'total_volume': 206836896},
#  {'ath': 2374.75,
#   'atl': 49.7,
#   'circulating_supply': 46750552.58384035,
#   'coin_id': 'dexe',
#   'coin_name': 'DeXe',
#   'current_price': 1433.38,
#   'last_updated': '2026-05-24T15:50:43.892Z',
#   'market_cap': 66970879480,
#   'market_cap_rank': 86,
#   'symbol': 'dexe',
#   'total_supply': 96504599.33609451,
#   'total_volume': 2347667732},
#  {'ath': 166.05,
#   'atl': 12.3,
#   'circulating_supply': 3320312968.08,
#   'coin_id': 'jupiter-exchange-solana',
#   'coin_name': 'Jupiter',
#   'current_price': 19.38,
#   'last_updated': '2026-05-24T15:50:42.820Z',
#   'market_cap': 64350725487,
#   'market_cap_rank': 87,
#   'symbol': 'jup',
#   'total_supply': 6862435243.466898,
#   'total_volume': 2459193461},
#  {'ath': 198.19,
#   'atl': 8.07,
#   'circulating_supply': 6255821492.0,
#   'coin_id': 'arbitrum',
#   'coin_name': 'Arbitrum',
#   'current_price': 10.13,
#   'last_updated': '2026-05-24T15:50:41.864Z',
#   'market_cap': 63338853893,
#   'market_cap_rank': 88,
#   'symbol': 'arb',
#   'total_supply': 10000000000.0,
#   'total_volume': 4452722311},
#  {'ath': 0.77853,
#   'atl': 0.146589,
#   'circulating_supply': 353682237994.0652,
#   'coin_id': 'pump-fun',
#   'coin_name': 'Pump.fun',
#   'current_price': 0.166455,
#   'last_updated': '2026-05-24T15:50:45.105Z',
#   'market_cap': 58836312479,
#   'market_cap_rank': 89,
#   'symbol': 'pump',
#   'total_supply': 864133720602.132,
#   'total_volume': 3690807395},
#  {'ath': 14.32,
#   'atl': 0.02721364,
#   'circulating_supply': 19946688440.0,
#   'coin_id': 'xdce-crowd-sale',
#   'coin_name': 'XDC Network',
#   'current_price': 2.95,
#   'last_updated': '2026-05-24T15:50:42.301Z',
#   'market_cap': 58785975722,
#   'market_cap_rank': 90,
#   'symbol': 'xdc',
#   'total_supply': 38065686425.1,
#   'total_volume': 1505592471},
#  {'ath': 32.42,
#   'atl': 0.01949843,
#   'circulating_supply': 7738278439.774086,
#   'coin_id': 'beldex',
#   'coin_name': 'Beldex',
#   'current_price': 7.55,
#   'last_updated': '2026-05-24T15:50:43.675Z',
#   'market_cap': 58396794153,
#   'market_cap_rank': 91,
#   'symbol': 'bdx',
#   'total_supply': 9937898508.232578,
#   'total_volume': 951979065},
#  {'ath': 96.91,
#   'atl': 76.18,
#   'circulating_supply': 584000000.0,
#   'coin_id': 'gho',
#   'coin_name': 'GHO',
#   'current_price': 95.59,
#   'last_updated': '2026-05-24T15:50:42.523Z',
#   'market_cap': 55823402949,
#   'market_cap_rank': 92,
#   'symbol': 'gho',
#   'total_supply': 584000000.0,
#   'total_volume': 365340252},
#  {'ath': 95552,
#   'atl': 13.82,
#   'circulating_supply': 12712104.75401168,
#   'coin_id': 'dash',
#   'coin_name': 'Dash',
#   'current_price': 4362.99,
#   'last_updated': '2026-05-24T15:50:41.792Z',
#   'market_cap': 55314158123,
#   'market_cap_rank': 93,
#   'symbol': 'dash',
#   'total_supply': 12712571.97805868,
#   'total_volume': 11018068328},
#  {'ath': 20.95,
#   'atl': 0.144791,
#   'circulating_supply': 85985041177.0,
#   'coin_id': 'vechain',
#   'coin_name': 'VeChain',
#   'current_price': 0.634507,
#   'last_updated': '2026-05-24T15:50:45.039Z',
#   'market_cap': 54510469201,
#   'market_cap_rank': 94,
#   'symbol': 'vet',
#   'total_supply': 85985041177.0,
#   'total_volume': 1360733454},
#  {'ath': 5.31,
#   'atl': 0.841042,
#   'circulating_supply': 53364802524.0,
#   'coin_id': 'hash-2',
#   'coin_name': 'Provenance Blockchain',
#   'current_price': 1.018,
#   'last_updated': '2026-05-24T15:50:44.803Z',
#   'market_cap': 54332473758,
#   'market_cap_rank': 95,
#   'symbol': 'hash',
#   'total_supply': 94978475357.64638,
#   'total_volume': 1518063},
#  {'ath': 10.66,
#   'atl': 2.14,
#   'circulating_supply': 16607399400.63495,
#   'coin_id': 'midnight-3',
#   'coin_name': 'Midnight',
#   'current_price': 3.24,
#   'last_updated': '2026-05-24T15:50:25.956Z',
#   'market_cap': 53937222677,
#   'market_cap_rank': 96,
#   'symbol': 'night',
#   'total_supply': 24000000000.0,
#   'total_volume': 958752497},
#  {'ath': 5.81,
#   'atl': 0.320882,
#   'circulating_supply': 62860396090.0,
#   'coin_id': 'pudgy-penguins',
#   'coin_name': 'Pudgy Penguins',
#   'current_price': 0.856653,
#   'last_updated': '2026-05-24T15:50:43.865Z',
#   'market_cap': 53828350375,
#   'market_cap_rank': 97,
#   'symbol': 'pengu',
#   'total_supply': 79570551682.74667,
#   'total_volume': 10967599390},
#  {'ath': 110.74,
#   'atl': 81.88,
#   'circulating_supply': 555227276.2276015,
#   'coin_id': 'usual-usd',
#   'coin_name': 'Usual USD',
#   'current_price': 95.56,
#   'last_updated': '2026-05-24T15:50:43.181Z',
#   'market_cap': 53065120937,
#   'market_cap_rank': 98,
#   'symbol': 'usd0',
#   'total_supply': 555227276.2276015,
#   'total_volume': 97567},
#  {'ath': 11182.59,
#   'atl': 7844.42,
#   'circulating_supply': 4797002.629046694,
#   'coin_id': 'ousg',
#   'coin_name': 'OUSG',
#   'current_price': 11036.77,
#   'last_updated': '2026-05-24T15:45:18.954Z',
#   'market_cap': 52943413128,
#   'market_cap_rank': 99,
#   'symbol': 'ousg',
#   'total_supply': 4797002.629046694,
#   'total_volume': 0.0},
#  {'ath': 0.00491619,
#   'atl': 7.14e-06,
#   'circulating_supply': 87994731471052.36,
#   'coin_id': 'bonk',
#   'coin_name': 'Bonk',
#   'current_price': 0.00057364,
#   'last_updated': '2026-05-24T15:50:42.624Z',
#   'market_cap': 50458841342,
#   'market_cap_rank': 100,
#   'symbol': 'bonk',
#   'total_supply': 87994731471052.36,
#   'total_volume': 2878759582},
#  {'ath': 103.77,
#   'atl': 80.73,
#   'circulating_supply': 519050593.822553,
#   'coin_id': 'apxusd',
#   'coin_name': 'apxUSD',
#   'current_price': 95.68,
#   'last_updated': '2026-05-24T15:50:45.315Z',
#   'market_cap': 49655096307,
#   'market_cap_rank': 101,
#   'symbol': 'apxusd',
#   'total_supply': 519050593.822553,
#   'total_volume': 1962792820},
#  {'ath': 4364.19,
#   'atl': 49.02,
#   'circulating_supply': 100000000.0,
#   'coin_id': 'injective-protocol',
#   'coin_name': 'Injective',
#   'current_price': 492.11,
#   'last_updated': '2026-05-24T15:50:41.350Z',
#   'market_cap': 49134966510,
#   'market_cap_rank': 102,
#   'symbol': 'inj',
#   'total_supply': 100000000.0,
#   'total_volume': 11812015944},
#  {'ath': 96.98,
#   'atl': 87.62,
#   'circulating_supply': 509537707.41,
#   'coin_id': 'ylds',
#   'coin_name': 'YLDS',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:50:44.699Z',
#   'market_cap': 48760552894,
#   'market_cap_rank': 103,
#   'symbol': 'ylds',
#   'total_supply': 509537707.41,
#   'total_volume': 16409455},
#  {'ath': 20.14,
#   'atl': 0.00091492,
#   'circulating_supply': 39210300116.64074,
#   'coin_id': 'a7a5',
#   'coin_name': 'A7A5',
#   'current_price': 1.23,
#   'last_updated': '2026-05-24T15:50:44.927Z',
#   'market_cap': 48422007896,
#   'market_cap_rank': 104,
#   'symbol': 'a7a5',
#   'total_supply': 39210300116.64074,
#   'total_volume': 460076},
#  {'ath': 112.93,
#   'atl': 64.32,
#   'circulating_supply': 494515083.0,
#   'coin_id': 'true-usd',
#   'coin_name': 'TrueUSD',
#   'current_price': 95.56,
#   'last_updated': '2026-05-24T15:50:42.810Z',
#   'market_cap': 47246192894,
#   'market_cap_rank': 105,
#   'symbol': 'tusd',
#   'total_supply': 494515083.0,
#   'total_volume': 1138656258},
#  {'ath': 6357.94,
#   'atl': 188.85,
#   'circulating_supply': 237414040.342428,
#   'coin_id': 'official-trump',
#   'coin_name': 'Official Trump',
#   'current_price': 198.17,
#   'last_updated': '2026-05-24T15:50:44.099Z',
#   'market_cap': 47039681493,
#   'market_cap_rank': 106,
#   'symbol': 'trump',
#   'total_supply': 1000000000.0,
#   'total_volume': 5325187373},
#  {'ath': 434.45,
#   'atl': 0.622571,
#   'circulating_supply': 656986027.2170838,
#   'coin_id': 'virtual-protocol',
#   'coin_name': 'Virtuals Protocol',
#   'current_price': 71.48,
#   'last_updated': '2026-05-24T15:50:43.277Z',
#   'market_cap': 46952415933,
#   'market_cap_rank': 107,
#   'symbol': 'virtual',
#   'total_supply': 1000000000.0,
#   'total_volume': 9127405940},
#  {'ath': 287.87,
#   'atl': 0.616804,
#   'circulating_supply': 2258881093.9307284,
#   'coin_id': 'fetch-ai',
#   'coin_name': 'Artificial Superintelligence Alliance',
#   'current_price': 20.14,
#   'last_updated': '2026-05-24T15:50:44.682Z',
#   'market_cap': 45352528788,
#   'market_cap_rank': 108,
#   'symbol': 'fet',
#   'total_supply': 2714384546.672,
#   'total_volume': 8706916105},
#  {'ath': 29.33,
#   'atl': 5.48,
#   'circulating_supply': 2273255814.0,
#   'coin_id': 'kite-2',
#   'coin_name': 'Kite',
#   'current_price': 19.4,
#   'last_updated': '2026-05-24T15:50:45.680Z',
#   'market_cap': 44082797428,
#   'market_cap_rank': 109,
#   'symbol': 'kite',
#   'total_supply': 10000000000.0,
#   'total_volume': 2586496908},
#  {'ath': 3259.75,
#   'atl': 14.48,
#   'circulating_supply': 325808307.9496637,
#   'coin_id': 'pancakeswap-token',
#   'coin_name': 'PancakeSwap',
#   'current_price': 134.22,
#   'last_updated': '2026-05-24T15:50:41.113Z',
#   'market_cap': 43717325692,
#   'market_cap_rank': 110,
#   'symbol': 'cake',
#   'total_supply': 338237862.4500047,
#   'total_volume': 1802862828},
#  {'ath': 148.19,
#   'atl': 46.44,
#   'circulating_supply': 350000000.0,
#   'coin_id': 'edgex',
#   'coin_name': 'edgeX',
#   'current_price': 124.97,
#   'last_updated': '2026-05-24T15:50:44.925Z',
#   'market_cap': 43671124910,
#   'market_cap_rank': 111,
#   'symbol': 'edge',
#   'total_supply': 1000000000.0,
#   'total_volume': 762318224},
#  {'ath': 51.48,
#   'atl': 3.64,
#   'circulating_supply': 1000000000.0,
#   'coin_id': 'bianrensheng',
#   'coin_name': '币安人生 (BinanceLife)',
#   'current_price': 42.93,
#   'last_updated': '2026-05-24T15:50:45.521Z',
#   'market_cap': 42873394864,
#   'market_cap_rank': 112,
#   'symbol': '币安人生',
#   'total_supply': 1000000000.0,
#   'total_volume': 1570678158},
#  {'ath': 112.74,
#   'atl': 4.35,
#   'circulating_supply': 383497842.1424131,
#   'coin_id': 'euro-coin',
#   'coin_name': 'EURC',
#   'current_price': 111.08,
#   'last_updated': '2026-05-24T15:50:42.454Z',
#   'market_cap': 42596064108,
#   'market_cap_rank': 113,
#   'symbol': 'eurc',
#   'total_supply': 383757842.1424131,
#   'total_volume': 1539658996},
#  {'ath': 322.23,
#   'atl': 3.44,
#   'circulating_supply': 1846373527.96056,
#   'coin_id': 'blockstack',
#   'coin_name': 'Stacks',
#   'current_price': 23.04,
#   'last_updated': '2026-05-24T15:50:41.989Z',
#   'market_cap': 42527829181,
#   'market_cap_rank': 114,
#   'symbol': 'stx',
#   'total_supply': 1846373527.96056,
#   'total_volume': 1297654581},
#  {'ath': 8974.09,
#   'atl': 7.733e-05,
#   'circulating_supply': 5541865807406.259,
#   'coin_id': 'terra-luna',
#   'coin_name': 'Terra Luna Classic',
#   'current_price': 0.00758589,
#   'last_updated': '2026-05-24T15:50:26.124Z',
#   'market_cap': 42062869039,
#   'market_cap_rank': 115,
#   'symbol': 'lunc',
#   'total_supply': 6459138486717.241,
#   'total_volume': 2263257898},
#  {'ath': 100.39,
#   'atl': 89.64,
#   'circulating_supply': 417851775.905293,
#   'coin_id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'coin_name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'current_price': 99.08,
#   'last_updated': '2026-05-24T15:50:05.004Z',
#   'market_cap': 41402331750,
#   'market_cap_rank': 116,
#   'symbol': 'jaaa',
#   'total_supply': 417851775.905293,
#   'total_volume': None},
#  {'ath': 113.28,
#   'atl': 108.94,
#   'circulating_supply': 361849177.54321,
#   'coin_id': 'spiko-amundi-overnight-swap-fund-eur',
#   'coin_name': 'Spiko Amundi Overnight Swap Fund (EUR)',
#   'current_price': 111.6,
#   'last_updated': '2026-05-24T15:50:04.704Z',
#   'market_cap': 40383034817,
#   'market_cap_rank': 117,
#   'symbol': 'eursafo',
#   'total_supply': 361849177.54321,
#   'total_volume': None},
#  {'ath': 196.44,
#   'atl': 0.0015484,
#   'circulating_supply': 941460195.3308003,
#   'coin_id': 'aerodrome-finance',
#   'coin_name': 'Aerodrome Finance',
#   'current_price': 41.69,
#   'last_updated': '2026-05-24T15:50:42.868Z',
#   'market_cap': 39229555389,
#   'market_cap_rank': 118,
#   'symbol': 'aero',
#   'total_supply': 1903187204.534856,
#   'total_volume': 2470684381},
#  {'ath': 94.47,
#   'atl': 4.55,
#   'circulating_supply': 6733333333.0,
#   'coin_id': 'sei-network',
#   'coin_name': 'Sei',
#   'current_price': 5.81,
#   'last_updated': '2026-05-24T15:50:44.037Z',
#   'market_cap': 39149869004,
#   'market_cap_rank': 119,
#   'symbol': 'sei',
#   'total_supply': 10000000000.0,
#   'total_volume': 4539156920},
#  {'ath': 421.78,
#   'atl': 87.73,
#   'circulating_supply': 104035514.216296,
#   'coin_id': 'adi-token',
#   'coin_name': 'ADI',
#   'current_price': 374.68,
#   'last_updated': '2026-05-24T15:50:45.156Z',
#   'market_cap': 39098843438,
#   'market_cap_rank': 120,
#   'symbol': 'adi',
#   'total_supply': 999999999.0,
#   'total_volume': 117600367},
#  {'ath': 96.97,
#   'atl': 74.4,
#   'circulating_supply': 401413271.431927,
#   'coin_id': 'usx',
#   'coin_name': 'USX',
#   'current_price': 95.64,
#   'last_updated': '2026-05-24T15:50:44.984Z',
#   'market_cap': 38391017126,
#   'market_cap_rank': 121,
#   'symbol': 'usx',
#   'total_supply': 401413271.431927,
#   'total_volume': 93399523},
#  {'ath': 34.11,
#   'atl': 1.55,
#   'circulating_supply': 1825000000.0,
#   'coin_id': 'humanity',
#   'coin_name': 'Humanity',
#   'current_price': 20.89,
#   'last_updated': '2026-05-24T15:50:44.757Z',
#   'market_cap': 38145162906,
#   'market_cap_rank': 122,
#   'symbol': 'h',
#   'total_supply': 10000000000.0,
#   'total_volume': 2332510311},
#  {'ath': 23.28,
#   'atl': 0.909123,
#   'circulating_supply': 2500000000.0,
#   'coin_id': 'unibase',
#   'coin_name': 'Unibase',
#   'current_price': 15.28,
#   'last_updated': '2026-05-24T15:50:45.152Z',
#   'market_cap': 37837320634,
#   'market_cap_rank': 123,
#   'symbol': 'ub',
#   'total_supply': 10000000000.0,
#   'total_volume': 2440169724},
#  {'ath': 4880.96,
#   'atl': 0.374246,
#   'circulating_supply': 19226535882.26254,
#   'coin_id': 'sun-token',
#   'coin_name': 'Sun Token',
#   'current_price': 1.92,
#   'last_updated': '2026-05-24T15:50:41.088Z',
#   'market_cap': 37006435344,
#   'market_cap_rank': 124,
#   'symbol': 'sun',
#   'total_supply': 19900730000.0,
#   'total_volume': 5163307171},
#  {'ath': 1730.96,
#   'atl': 25.29,
#   'circulating_supply': 921187929.175959,
#   'coin_id': 'celestia',
#   'coin_name': 'Celestia',
#   'current_price': 39.78,
#   'last_updated': '2026-05-24T15:50:42.628Z',
#   'market_cap': 36632927217,
#   'market_cap_rank': 125,
#   'symbol': 'tia',
#   'total_supply': 1168906328.53509,
#   'total_volume': 4135957834},
#  {'ath': 63.87,
#   'atl': 0.290329,
#   'circulating_supply': 10378321506.0,
#   'coin_id': 'chiliz',
#   'coin_name': 'Chiliz',
#   'current_price': 3.52,
#   'last_updated': '2026-05-24T15:50:26.244Z',
#   'market_cap': 36570633443,
#   'market_cap_rank': 126,
#   'symbol': 'chz',
#   'total_supply': 10378400904.0,
#   'total_volume': 8117221816},
#  {'ath': 100.07,
#   'atl': 78.29,
#   'circulating_supply': 374148542.730216,
#   'coin_id': 'first-digital-usd',
#   'coin_name': 'First Digital USD',
#   'current_price': 95.4,
#   'last_updated': '2026-05-24T15:50:45.574Z',
#   'market_cap': 35717046328,
#   'market_cap_rank': 127,
#   'symbol': 'fdusd',
#   'total_supply': 374148542.730216,
#   'total_volume': 2931552870},
#  {'ath': 338.92,
#   'atl': 2.3,
#   'circulating_supply': 726788283.0466105,
#   'coin_id': 'siren-2',
#   'coin_name': 'Siren',
#   'current_price': 48.85,
#   'last_updated': '2026-05-24T15:50:44.141Z',
#   'market_cap': 35505022540,
#   'market_cap_rank': 128,
#   'symbol': 'siren',
#   'total_supply': 726788283.0466105,
#   'total_volume': 624132473},
#  {'ath': 676.89,
#   'atl': 24.73,
#   'circulating_supply': 1085790546.55935,
#   'coin_id': 'tezos',
#   'coin_name': 'Tezos',
#   'current_price': 32.24,
#   'last_updated': '2026-05-24T15:50:26.687Z',
#   'market_cap': 34991781060,
#   'market_cap_rank': 129,
#   'symbol': 'xtz',
#   'total_supply': 1105776218.300594,
#   'total_volume': 884692361},
#  {'ath': 79.28,
#   'atl': 6.0,
#   'circulating_supply': 3469831864.3,
#   'coin_id': 'doublezero',
#   'coin_name': 'DoubleZero',
#   'current_price': 9.97,
#   'last_updated': '2026-05-24T15:50:45.126Z',
#   'market_cap': 34585412445,
#   'market_cap_rank': 130,
#   'symbol': '2z',
#   'total_supply': 9998414364.3,
#   'total_volume': 872532070},
#  {'ath': 18851.55,
#   'atl': 3614.27,
#   'circulating_supply': 2386227.8342,
#   'coin_id': 'kinesis-gold',
#   'coin_name': 'Kinesis Gold',
#   'current_price': 14054.98,
#   'last_updated': '2026-05-24T15:50:42.510Z',
#   'market_cap': 33538377071,
#   'market_cap_rank': 131,
#   'symbol': 'kau',
#   'total_supply': 2386227.8342,
#   'total_volume': 1054132},
#  {'ath': 1150.14,
#   'atl': 15.17,
#   'circulating_supply': 1517292816.0,
#   'coin_id': 'curve-dao-token',
#   'coin_name': 'Curve DAO',
#   'current_price': 21.67,
#   'last_updated': '2026-05-24T15:50:41.186Z',
#   'market_cap': 32859072632,
#   'market_cap_rank': 132,
#   'symbol': 'crv',
#   'total_supply': 2383662859.933454,
#   'total_volume': 2474393978},
#  {'ath': 705.52,
#   'atl': 73.37,
#   'circulating_supply': 250000000.0,
#   'coin_id': 'lighter',
#   'coin_name': 'Lighter',
#   'current_price': 129.31,
#   'last_updated': '2026-05-24T15:50:45.703Z',
#   'market_cap': 32225473031,
#   'market_cap_rank': 133,
#   'symbol': 'lit',
#   'total_supply': 1000000000.0,
#   'total_volume': 6554758069},
#  {'ath': 96.99,
#   'atl': 91.54,
#   'circulating_supply': 333556954.94,
#   'coin_id': 'usdgo',
#   'coin_name': 'USDGO',
#   'current_price': 95.68,
#   'last_updated': '2026-05-24T15:50:40.539Z',
#   'market_cap': 31915299572,
#   'market_cap_rank': 134,
#   'symbol': 'usdgo',
#   'total_supply': 333556954.94,
#   'total_volume': 209702101},
#  {'ath': 81.21,
#   'atl': 1.27,
#   'circulating_supply': 998384107.7857016,
#   'coin_id': 'skyai',
#   'coin_name': 'SkyAI',
#   'current_price': 31.92,
#   'last_updated': '2026-05-24T15:50:44.264Z',
#   'market_cap': 31864226861,
#   'market_cap_rank': 135,
#   'symbol': 'skyai',
#   'total_supply': 998384107.7857016,
#   'total_volume': 2618978285},
#  {'ath': 639.26,
#   'atl': 6.66,
#   'circulating_supply': 76546099.142,
#   'coin_id': 'lab',
#   'coin_name': 'LAB',
#   'current_price': 416.48,
#   'last_updated': '2026-05-24T15:50:45.487Z',
#   'market_cap': 31820439401,
#   'market_cap_rank': 136,
#   'symbol': 'lab',
#   'total_supply': 1000000000.0,
#   'total_volume': 2021390687},
#  {'ath': 632.92,
#   'atl': 99.55,
#   'circulating_supply': 252331652.6536562,
#   'coin_id': 'layerzero',
#   'coin_name': 'LayerZero',
#   'current_price': 123.58,
#   'last_updated': '2026-05-24T15:50:42.219Z',
#   'market_cap': 31197088254,
#   'market_cap_rank': 137,
#   'symbol': 'zro',
#   'total_supply': 1000000000.0,
#   'total_volume': 2031415463},
#  {'ath': 99.17,
#   'atl': 3.36,
#   'circulating_supply': 7874982031.884853,
#   'coin_id': 'pyth-network',
#   'coin_name': 'Pyth Network',
#   'current_price': 3.95,
#   'last_updated': '2026-05-24T15:50:42.851Z',
#   'market_cap': 31125569701,
#   'market_cap_rank': 138,
#   'symbol': 'pyth',
#   'total_supply': 10000000000.0,
#   'total_volume': 1060853419},
#  {'ath': 711.06,
#   'atl': 33.33,
#   'circulating_supply': 880665741.0,
#   'coin_id': 'ether-fi',
#   'coin_name': 'Ether.fi',
#   'current_price': 35.22,
#   'last_updated': '2026-05-24T15:50:43.210Z',
#   'market_cap': 30997870418,
#   'market_cap_rank': 139,
#   'symbol': 'ethfi',
#   'total_supply': 998535999.0,
#   'total_volume': 2453489048},
#  {'ath': 196.84,
#   'atl': 0.109402,
#   'circulating_supply': 930993080.8870013,
#   'coin_id': 'spx6900',
#   'coin_name': 'SPX6900',
#   'current_price': 33.16,
#   'last_updated': '2026-05-24T15:50:42.463Z',
#   'market_cap': 30862720240,
# ...
#   'market_cap_rank': 204,
#   'symbol': 'wfi',
#   'total_supply': 1000000000.0,
#   'total_volume': 161335360},
#  {'ath': 88.3,
#   'atl': 3.36,
#   'circulating_supply': 3784775845.0,
#   'coin_id': 'sonic-3',
#   'coin_name': 'Sonic',
#   'current_price': 4.37,
#   'last_updated': '2026-05-24T15:50:43.362Z',
#   'market_cap': 16538768756,
#   'market_cap_rank': 205,
#   'symbol': 's',
#   'total_supply': 3885497663.0,
#   'total_volume': 1016851904},
#  {'ath': 1302.35,
#   'atl': 43.97,
#   'circulating_supply': 354718043.44,
#   'coin_id': 'story-2',
#   'coin_name': 'Story',
#   'current_price': 46.58,
#   'last_updated': '2026-05-24T15:50:44.215Z',
#   'market_cap': 16525211898,
#   'market_cap_rank': 206,
#   'symbol': 'ip',
#   'total_supply': 1028245251.4,
#   'total_volume': 2363310060},
#  {'ath': 120.97,
#   'atl': 0.34615,
#   'circulating_supply': 981852443.4419999,
#   'coin_id': 'swissborg',
#   'coin_name': 'SwissBorg',
#   'current_price': 16.74,
#   'last_updated': '2026-05-24T15:50:41.669Z',
#   'market_cap': 16382438480,
#   'market_cap_rank': 207,
#   'symbol': 'borg',
#   'total_supply': 981852443.4419999,
#   'total_volume': 22518552},
#  {'ath': 34.96,
#   'atl': 6.08,
#   'circulating_supply': 577156141.0,
#   'coin_id': 'centrifuge-2',
#   'coin_name': 'Centrifuge',
#   'current_price': 28.09,
#   'last_updated': '2026-05-24T15:50:44.601Z',
#   'market_cap': 16214158425,
#   'market_cap_rank': 208,
#   'symbol': 'cfg',
#   'total_supply': 680000000.0,
#   'total_volume': 1435602771},
#  {'ath': 479.53,
#   'atl': 13.8,
#   'circulating_supply': 741228566.6979554,
#   'coin_id': 'eigenlayer',
#   'coin_name': 'EigenCloud (prev. EigenLayer)',
#   'current_price': 21.83,
#   'last_updated': '2026-05-24T15:50:43.301Z',
#   'market_cap': 16119746978,
#   'market_cap_rank': 209,
#   'symbol': 'eigen',
#   'total_supply': 1822946853.685264,
#   'total_volume': 4030617625},
#  {'ath': 435.95,
#   'atl': 0.597438,
#   'circulating_supply': 1935128975.3057714,
#   'coin_id': 'decentraland',
#   'coin_name': 'Decentraland',
#   'current_price': 8.25,
#   'last_updated': '2026-05-24T15:50:39.869Z',
#   'market_cap': 15965930020,
#   'market_cap_rank': 210,
#   'symbol': 'mana',
#   'total_supply': 2193179327.320146,
#   'total_volume': 919075369},
#  {'ath': 14039.54,
#   'atl': 4334.92,
#   'circulating_supply': 1438592.631520657,
#   'coin_id': 'circle-internet-group-ondo-tokenized-stock',
#   'coin_name': 'Circle Internet Group (Ondo Tokenized Stock)',
#   'current_price': 10977.08,
#   'last_updated': '2026-05-24T15:50:45.160Z',
#   'market_cap': 15794347594,
#   'market_cap_rank': 211,
#   'symbol': 'crclon',
#   'total_supply': 1438592.631520657,
#   'total_volume': 51019527},
#  {'ath': 0.20674,
#   'atl': 0.00168742,
#   'circulating_supply': 108864805114.17,
#   'coin_id': 'tagger',
#   'coin_name': 'TAGGER',
#   'current_price': 0.144706,
#   'last_updated': '2026-05-24T15:50:43.890Z',
#   'market_cap': 15738949139,
#   'market_cap_rank': 212,
#   'symbol': 'tag',
#   'total_supply': 405380800000.0,
#   'total_volume': 692811216},
#  {'ath': 19.64,
#   'atl': 4.15,
#   'circulating_supply': 3697346477.1657457,
#   'coin_id': 'vision-3',
#   'coin_name': 'Vision',
#   'current_price': 4.21,
#   'last_updated': '2026-05-24T15:50:44.806Z',
#   'market_cap': 15562543269,
#   'market_cap_rank': 213,
#   'symbol': 'vsn',
#   'total_supply': 4200000000.0,
#   'total_volume': 241058261},
#  {'ath': 97.0,
#   'atl': 85.32,
#   'circulating_supply': 162500000.0,
#   'coin_id': 'tradable-apac-diversified-finance-provider-sstn',
#   'coin_name': 'Tradable APAC Diversified Finance Provider SSTN',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:50:06.302Z',
#   'market_cap': 15551327513,
#   'market_cap_rank': 214,
#   'symbol': 'pc0000033',
#   'total_supply': 162500000.0,
#   'total_volume': None},
#  {'ath': 487.24,
#   'atl': 3.02,
#   'circulating_supply': 91837334.0,
#   'coin_id': 'mx-token',
#   'coin_name': 'MX',
#   'current_price': 169.18,
#   'last_updated': '2026-05-24T15:50:44.257Z',
#   'market_cap': 15537018376,
#   'market_cap_rank': 215,
#   'symbol': 'mx',
#   'total_supply': 409024834.0,
#   'total_volume': 517215104},
#  {'ath': 105.15,
#   'atl': 84.8,
#   'circulating_supply': 149481443.29896,
#   'coin_id': 'spiko-us-t-bills-money-market-fund',
#   'coin_name': 'Spiko US T-Bills Money Market Fund',
#   'current_price': 103.76,
#   'last_updated': '2026-05-24T15:45:11.392Z',
#   'market_cap': 15510192818,
#   'market_cap_rank': 216,
#   'symbol': 'ustbl',
#   'total_supply': 149481443.29896,
#   'total_volume': 4430.57},
#  {'ath': 702.29,
#   'atl': 5.49,
#   'circulating_supply': 162061501.0,
#   'coin_id': 'btse-token',
#   'coin_name': 'BTSE Token',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:50:40.750Z',
#   'market_cap': 15509376124,
#   'market_cap_rank': 217,
#   'symbol': 'btse',
#   'total_supply': 200000000.0,
#   'total_volume': 243362279},
#  {'ath': 96.9,
#   'atl': 90.01,
#   'circulating_supply': 159641843.5,
#   'coin_id': 'usa',
#   'coin_name': 'USAT',
#   'current_price': 95.56,
#   'last_updated': '2026-05-24T15:50:43.684Z',
#   'market_cap': 15253927585,
#   'market_cap_rank': 218,
#   'symbol': 'usat',
#   'total_supply': 159641843.5,
#   'total_volume': 176226552},
#  {'ath': 145.33,
#   'atl': 53.22,
#   'circulating_supply': 159199022.6842478,
#   'coin_id': 'satoshi-stablecoin',
#   'coin_name': 'Satoshi Stablecoin',
#   'current_price': 95.28,
#   'last_updated': '2026-05-24T15:50:43.122Z',
#   'market_cap': 15140254740,
#   'market_cap_rank': 219,
#   'symbol': 'satusd',
#   'total_supply': 159199022.6842478,
#   'total_volume': 691196},
#  {'ath': 1525.95,
#   'atl': 0.601495,
#   'circulating_supply': 350133417.0,
#   'coin_id': 'thorchain',
#   'coin_name': 'THORChain',
#   'current_price': 42.79,
#   'last_updated': '2026-05-24T15:50:44.579Z',
#   'market_cap': 15009530867,
#   'market_cap_rank': 220,
#   'symbol': 'rune',
#   'total_supply': 360099464.0,
#   'total_volume': 1034745509},
#  {'ath': 61.46,
#   'atl': 0.00991417,
#   'circulating_supply': 47847406286.85422,
#   'coin_id': 'gala',
#   'coin_name': 'GALA',
#   'current_price': 0.306167,
#   'last_updated': '2026-05-24T15:50:41.460Z',
#   'market_cap': 14634094161,
#   'market_cap_rank': 221,
#   'symbol': 'gala',
#   'total_supply': 47847406286.85422,
#   'total_volume': 1553614852},
#  {'ath': 150.32,
#   'atl': 57.28,
#   'circulating_supply': 124125940.0,
#   'coin_id': 'stasis-eurs',
#   'coin_name': 'STASIS EURO',
#   'current_price': 117.39,
#   'last_updated': '2026-05-24T15:50:44.388Z',
#   'market_cap': 14570706499,
#   'market_cap_rank': 222,
#   'symbol': 'eurs',
#   'total_supply': 124125940.0,
#   'total_volume': 124153},
#  {'ath': 4477.35,
#   'atl': 120.95,
#   'circulating_supply': 90360893.86537892,
#   'coin_id': 'convex-finance',
#   'coin_name': 'Convex Finance',
#   'current_price': 159.16,
#   'last_updated': '2026-05-24T15:50:44.288Z',
#   'market_cap': 14381450494,
#   'market_cap_rank': 223,
#   'symbol': 'cvx',
#   'total_supply': 99969558.43629663,
#   'total_volume': 565695811},
#  {'ath': 64.7,
#   'atl': 5.81,
#   'circulating_supply': 2349583333.0,
#   'coin_id': 'walrus-2',
#   'coin_name': 'Walrus',
#   'current_price': 6.12,
#   'last_updated': '2026-05-24T15:50:44.434Z',
#   'market_cap': 14369058330,
#   'market_cap_rank': 224,
#   'symbol': 'wal',
#   'total_supply': 5000000000.0,
#   'total_volume': 482776413},
#  {'ath': 97.85,
#   'atl': 86.82,
#   'circulating_supply': 149790000.0,
#   'coin_id': 'gusd',
#   'coin_name': 'GUSD',
#   'current_price': 95.5,
#   'last_updated': '2026-05-24T15:50:45.079Z',
#   'market_cap': 14302220683,
#   'market_cap_rank': 225,
#   'symbol': 'gusd',
#   'total_supply': 320000000.0,
#   'total_volume': 11757707},
#  {'ath': 2581.9,
#   'atl': 19.02,
#   'circulating_supply': 252480555.0,
#   'coin_id': 'ravedao',
#   'coin_name': 'RaveDAO',
#   'current_price': 56.18,
#   'last_updated': '2026-05-24T15:50:45.562Z',
#   'market_cap': 14192588035,
#   'market_cap_rank': 226,
#   'symbol': 'rave',
#   'total_supply': 1000000000.0,
#   'total_volume': 921894920},
#  {'ath': 142.64,
#   'atl': 4.66,
#   'circulating_supply': 1495724656.9526057,
#   'coin_id': 'basic-attention-token',
#   'coin_name': 'Basic Attention',
#   'current_price': 9.41,
#   'last_updated': '2026-05-24T15:50:45.137Z',
#   'market_cap': 14073598169,
#   'market_cap_rank': 227,
#   'symbol': 'bat',
#   'total_supply': 1500000000.0,
#   'total_volume': 923543588},
#  {'ath': 97.09,
#   'atl': 86.49,
#   'circulating_supply': 146021055.795484,
#   'coin_id': 'nusd-2',
#   'coin_name': 'Neutrl USD',
#   'current_price': 95.62,
#   'last_updated': '2026-05-24T15:50:45.392Z',
#   'market_cap': 13962309079,
#   'market_cap_rank': 228,
#   'symbol': 'nusd',
#   'total_supply': 146021055.795484,
#   'total_volume': 6659282},
#  {'ath': 4079.96,
#   'atl': 8.66,
#   'circulating_supply': 183083658.8864777,
#   'coin_id': 'helium',
#   'coin_name': 'Helium',
#   'current_price': 75.31,
#   'last_updated': '2026-05-24T15:50:43.624Z',
#   'market_cap': 13777463030,
#   'market_cap_rank': 229,
#   'symbol': 'hnt',
#   'total_supply': 183083658.8864777,
#   'total_volume': 282554894},
#  {'ath': 0.02773893,
#   'atl': 0.00060864,
#   'circulating_supply': 20032629672580.0,
#   'coin_id': 'ecash',
#   'coin_name': 'eCash',
#   'current_price': 0.00067838,
#   'last_updated': '2026-05-24T15:50:41.429Z',
#   'market_cap': 13587474740,
#   'market_cap_rank': 230,
#   'symbol': 'xec',
#   'total_supply': 20032645297580.0,
#   'total_volume': 341635502},
#  {'ath': 0.00018517,
#   'atl': 4.73652e-07,
#   'circulating_supply': 203672952113698.72,
#   'coin_id': 'cheems-token',
#   'coin_name': 'Cheems Token',
#   'current_price': 6.639e-05,
#   'last_updated': '2026-05-24T15:50:42.435Z',
#   'market_cap': 13521488976,
#   'market_cap_rank': 231,
#   'symbol': 'cheems',
#   'total_supply': 203672952113698.72,
#   'total_volume': 149098900},
#  {'ath': 86.4,
#   'atl': 0.613205,
#   'circulating_supply': 1000000000.0,
#   'coin_id': 'golem',
#   'coin_name': 'Golem',
#   'current_price': 13.48,
#   'last_updated': '2026-05-24T15:50:44.149Z',
#   'market_cap': 13510770630,
#   'market_cap_rank': 232,
#   'symbol': 'glm',
#   'total_supply': 1000000000.0,
#   'total_volume': 587391279},
#  {'ath': 26.81,
#   'atl': 1.31,
#   'circulating_supply': 9703425807.0,
#   'coin_id': 'zksync',
#   'coin_name': 'ZKsync',
#   'current_price': 1.39,
#   'last_updated': '2026-05-24T15:50:43.363Z',
#   'market_cap': 13506513852,
#   'market_cap_rank': 233,
#   'symbol': 'zk',
#   'total_supply': 21000000000.0,
#   'total_volume': 916386426},
#  {'ath': 97.0,
#   'atl': 87.63,
#   'circulating_supply': 140174080.2,
#   'coin_id': 'fidelity-digital-interest-token',
#   'coin_name': 'Fidelity Digital Interest Token',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:45:22.650Z',
#   'market_cap': 13414726338,
#   'market_cap_rank': 234,
#   'symbol': 'fdit',
#   'total_supply': 140174080.2,
#   'total_volume': None},
#  {'ath': 305.14,
#   'atl': 21.02,
#   'circulating_supply': 500000000.0,
#   'coin_id': 'safepal',
#   'coin_name': 'SafePal',
#   'current_price': 26.71,
#   'last_updated': '2026-05-24T15:50:41.482Z',
#   'market_cap': 13356099995,
#   'market_cap_rank': 235,
#   'symbol': 'sfp',
#   'total_supply': 500000000.0,
#   'total_volume': 142407402},
#  {'ath': 709.31,
#   'atl': 12.12,
#   'circulating_supply': 842444578.3296283,
#   'coin_id': 'immutable-x',
#   'coin_name': 'Immutable',
#   'current_price': 15.72,
#   'last_updated': '2026-05-24T15:50:41.567Z',
#   'market_cap': 13238718860,
#   'market_cap_rank': 236,
#   'symbol': 'imx',
#   'total_supply': 2000000000.0,
#   'total_volume': 1012329009},
#  {'ath': 97.76,
#   'atl': 92.76,
#   'circulating_supply': 136442447.51924,
#   'coin_id': 'safo',
#   'coin_name': 'Spiko Amundi Overnight Swap Fund',
#   'current_price': 96.5,
#   'last_updated': '2026-05-24T15:50:05.261Z',
#   'market_cap': 13166847253,
#   'market_cap_rank': 237,
#   'symbol': 'safo',
#   'total_supply': 136442447.51924,
#   'total_volume': None},
#  {'ath': 10352.99,
#   'atl': 8523.09,
#   'circulating_supply': 1354000.472948681,
#   'coin_id': 'strategy-pp-variable-xstock',
#   'coin_name': 'Strategy PP Variable xStock',
#   'current_price': 9699.45,
#   'last_updated': '2026-05-24T15:50:45.546Z',
#   'market_cap': 13133125006,
#   'market_cap_rank': 238,
#   'symbol': 'strcx',
#   'total_supply': 2391444.792124266,
#   'total_volume': 4910735},
#  {'ath': 1.49,
#   'atl': 0.00031373,
#   'circulating_supply': 98823661261.46,
#   'coin_id': 'newton-project',
#   'coin_name': 'AB',
#   'current_price': 0.131815,
#   'last_updated': '2026-05-24T15:50:43.524Z',
#   'market_cap': 13006660535,
#   'market_cap_rank': 239,
#   'symbol': 'ab',
#   'total_supply': 98823661261.46,
#   'total_volume': 241840886},
#  {'ath': 7.64,
#   'atl': 0.268609,
#   'circulating_supply': 2737797495.975969,
#   'coin_id': 'xphere',
#   'coin_name': 'Xphere',
#   'current_price': 4.75,
#   'last_updated': '2026-05-24T15:50:44.193Z',
#   'market_cap': 12999127737,
#   'market_cap_rank': 240,
#   'symbol': 'xp',
#   'total_supply': 2737900692.160037,
#   'total_volume': 137703100},
#  {'ath': 2044.73,
#   'atl': 7.6,
#   'circulating_supply': 1000000000.0,
#   'coin_id': 'apecoin',
#   'coin_name': 'ApeCoin',
#   'current_price': 13.0,
#   'last_updated': '2026-05-24T15:50:41.966Z',
#   'market_cap': 12994806894,
#   'market_cap_rank': 241,
#   'symbol': 'ape',
#   'total_supply': 1000000000.0,
#   'total_volume': 1359803051},
#  {'ath': 6640.2,
#   'atl': 21.36,
#   'circulating_supply': 65652466.0,
#   'coin_id': 'arweave',
#   'coin_name': 'Arweave',
#   'current_price': 197.13,
#   'last_updated': '2026-05-24T15:50:43.574Z',
#   'market_cap': 12950962195,
#   'market_cap_rank': 242,
#   'symbol': 'ar',
#   'total_supply': 65652466.0,
#   'total_volume': 1126438373},
#  {'ath': 97.0,
#   'atl': 85.32,
#   'circulating_supply': 134000000.0,
#   'coin_id': 'tradable-latam-fintech-sstn',
#   'coin_name': 'Tradable LatAm Fintech SSTN',
#   'current_price': 95.7,
#   'last_updated': '2026-05-24T15:45:18.283Z',
#   'market_cap': 12823863918,
#   'market_cap_rank': 243,
#   'symbol': 'pc0000097',
#   'total_supply': 134000000.0,
#   'total_volume': None},
#  {'ath': 96.99,
#   'atl': 83.77,
#   'circulating_supply': 133241059.9183565,
#   'coin_id': 'frax-usd',
#   'coin_name': 'Frax USD',
#   'current_price': 95.67,
#   'last_updated': '2026-05-24T15:50:44.163Z',
#   'market_cap': 12747180230,
#   'market_cap_rank': 244,
#   'symbol': 'frxusd',
#   'total_supply': 133237873.3657171,
#   'total_volume': 531894811},
#  {'ath': 96.99,
#   'atl': 80.49,
#   'circulating_supply': 129222631.851641,
#   'coin_id': 'agora-dollar',
#   'coin_name': 'AUSD',
#   'current_price': 95.66,
#   'last_updated': '2026-05-24T15:50:43.380Z',
#   'market_cap': 12361882467,
#   'market_cap_rank': 245,
#   'symbol': 'ausd',
#   'total_supply': 129222631.851641,
#   'total_volume': 3517345144},
#  {'ath': 66.55,
#   'atl': 6.41,
#   'circulating_supply': 1643370241.7458,
#   'coin_id': 'vaulta',
#   'coin_name': 'Vaulta',
#   'current_price': 7.49,
#   'last_updated': '2026-05-24T15:50:44.512Z',
#   'market_cap': 12314406425,
#   'market_cap_rank': 246,
#   'symbol': 'a',
#   'total_supply': 2100000000.0,
#   'total_volume': 1145041761},
#  {'ath': 1799.83,
#   'atl': 30.33,
#   'circulating_supply': 77946996.82034639,
#   'coin_id': 'instadapp',
#   'coin_name': 'Fluid',
#   'current_price': 157.93,
#   'last_updated': '2026-05-24T15:50:41.360Z',
#   'market_cap': 12302563147,
#   'market_cap_rank': 247,
#   'symbol': 'fluid',
#   'total_supply': 100000000.0,
#   'total_volume': 278754665},
#  {'ath': 1836.35,
#   'atl': 9.55,
#   'circulating_supply': 462277841.3255647,
#   'coin_id': 'wemix-token',
#   'coin_name': 'WEMIX',
#   'current_price': 26.56,
#   'last_updated': '2026-05-24T15:50:41.231Z',
#   'market_cap': 12275525199,
#   'market_cap_rank': 248,
#   'symbol': 'wemix',
#   'total_supply': 552473209.5478008,
#   'total_volume': 101345471},
#  {'ath': 648.39,
#   'atl': 7.55,
#   'circulating_supply': 1405573965.7275033,
#   'coin_id': '1inch',
#   'coin_name': '1INCH',
#   'current_price': 8.68,
#   'last_updated': '2026-05-24T15:50:41.289Z',
#   'market_cap': 12195153213,
#   'market_cap_rank': 249,
#   'symbol': '1inch',
#   'total_supply': 1499999999.997,
#   'total_volume': 620990737},
#  {'ath': 100.55,
#   'atl': 80.46,
#   'circulating_supply': 123642410.177315,
#   'coin_id': 'theo-short-duration-us-treasury-fund',
#   'coin_name': 'Theo Short Duration US Treasury Fund',
#   'current_price': 98.06,
#   'last_updated': '2026-05-24T15:50:44.963Z',
#   'market_cap': 12111736268,
#   'market_cap_rank': 250,
#   'symbol': 'thbill',
#   'total_supply': 123642410.177315,
#   'total_volume': 16383173}]

# %%
print(f"Total data for filtered columns: {len(rename_columns)}")
# Out:
# Total data for filtered columns: 1250

# %%
crypto_df = pd.DataFrame(rename_columns) #visualizing data in pandas
crypto_df
# Out:
#                                    coin_id  symbol  \
# 0                                  bitcoin     btc
# 1                                 ethereum     eth
# 2                                   tether    usdt
# 3                              binancecoin     bnb
# 4                                   ripple     xrp
# ...                                    ...     ...
# 1245                                vaulta       a
# 1246                             instadapp   fluid
# 1247                           wemix-token   wemix
# 1248                                 1inch   1inch
# 1249  theo-short-duration-us-treasury-fund  thbill
#
#                                  coin_name  current_price       market_cap  \
# 0                                  Bitcoin     7308304.00  146386017371486
# 1                                 Ethereum      200378.00   24171984843745
# 2                                   Tether          95.59   18134047627886
# 3                                      BNB       62682.00    8446532286283
# 4                                      XRP         128.98    7981145342833
# ...                                    ...            ...              ...
# 1245                                Vaulta           7.49      12314406425
# 1246                                 Fluid         157.93      12302563147
# 1247                                 WEMIX          26.56      12275525199
# 1248                                 1INCH           8.68      12195153213
# 1249  Theo Short Duration US Treasury Fund          98.06      12111736268
#
#       market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                   1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                   2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                   3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                   4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                   5  1.310528e+11        6.185832e+10  9.998566e+10
# ...               ...           ...                 ...           ...
# 1245              246  1.145042e+09        1.643370e+09  2.100000e+09
# 1246              247  2.787547e+08        7.794700e+07  1.000000e+08
# 1247              248  1.013455e+08        4.622778e+08  5.524732e+08
# 1248              249  6.209907e+08        1.405574e+09  1.500000e+09
# 1249              250  1.638317e+07        1.236424e+08  1.236424e+08
#
#               ath          atl              last_updated
# 0     11187013.00  3993.420000  2026-05-24T15:50:44.026Z
# 1       431946.00    28.130000  2026-05-24T15:50:42.835Z
# 2          105.52    36.860000  2026-05-24T15:50:43.161Z
# 3       121422.00     2.580000  2026-05-24T15:50:44.003Z
# 4          313.99     0.159343  2026-05-24T15:50:43.908Z
# ...           ...          ...                       ...
# 1245        66.55     6.410000  2026-05-24T15:50:44.512Z
# 1246      1799.83    30.330000  2026-05-24T15:50:41.360Z
# 1247      1836.35     9.550000  2026-05-24T15:50:41.231Z
# 1248       648.39     7.550000  2026-05-24T15:50:41.289Z
# 1249       100.55    80.460000  2026-05-24T15:50:44.963Z
#
# [1250 rows x 12 columns]

# %%
# date only extract from last_updated
crypto_df["last_updated"] = pd.to_datetime(crypto_df["last_updated"]).dt.date
crypto_df
# Out:
#                                    coin_id  symbol  \
# 0                                  bitcoin     btc
# 1                                 ethereum     eth
# 2                                   tether    usdt
# 3                              binancecoin     bnb
# 4                                   ripple     xrp
# ...                                    ...     ...
# 1245                                vaulta       a
# 1246                             instadapp   fluid
# 1247                           wemix-token   wemix
# 1248                                 1inch   1inch
# 1249  theo-short-duration-us-treasury-fund  thbill
#
#                                  coin_name  current_price       market_cap  \
# 0                                  Bitcoin     7308304.00  146386017371486
# 1                                 Ethereum      200378.00   24171984843745
# 2                                   Tether          95.59   18134047627886
# 3                                      BNB       62682.00    8446532286283
# 4                                      XRP         128.98    7981145342833
# ...                                    ...            ...              ...
# 1245                                Vaulta           7.49      12314406425
# 1246                                 Fluid         157.93      12302563147
# 1247                                 WEMIX          26.56      12275525199
# 1248                                 1INCH           8.68      12195153213
# 1249  Theo Short Duration US Treasury Fund          98.06      12111736268
#
#       market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                   1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                   2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                   3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                   4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                   5  1.310528e+11        6.185832e+10  9.998566e+10
# ...               ...           ...                 ...           ...
# 1245              246  1.145042e+09        1.643370e+09  2.100000e+09
# 1246              247  2.787547e+08        7.794700e+07  1.000000e+08
# 1247              248  1.013455e+08        4.622778e+08  5.524732e+08
# 1248              249  6.209907e+08        1.405574e+09  1.500000e+09
# 1249              250  1.638317e+07        1.236424e+08  1.236424e+08
#
#               ath          atl last_updated
# 0     11187013.00  3993.420000   2026-05-24
# 1       431946.00    28.130000   2026-05-24
# 2          105.52    36.860000   2026-05-24
# 3       121422.00     2.580000   2026-05-24
# 4          313.99     0.159343   2026-05-24
# ...           ...          ...          ...
# 1245        66.55     6.410000   2026-05-24
# 1246      1799.83    30.330000   2026-05-24
# 1247      1836.35     9.550000   2026-05-24
# 1248       648.39     7.550000   2026-05-24
# 1249       100.55    80.460000   2026-05-24
#
# [1250 rows x 12 columns]

# %%
crypto_df.head()
# Out:
#        coin_id symbol coin_name  current_price       market_cap  \
# 0      bitcoin    btc   Bitcoin     7308304.00  146386017371486
# 1     ethereum    eth  Ethereum      200378.00   24171984843745
# 2       tether   usdt    Tether          95.59   18134047627886
# 3  binancecoin    bnb       BNB       62682.00    8446532286283
# 4       ripple    xrp       XRP         128.98    7981145342833
#
#    market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                5  1.310528e+11        6.185832e+10  9.998566e+10
#
#            ath          atl last_updated
# 0  11187013.00  3993.420000   2026-05-24
# 1    431946.00    28.130000   2026-05-24
# 2       105.52    36.860000   2026-05-24
# 3    121422.00     2.580000   2026-05-24
# 4       313.99     0.159343   2026-05-24

# %% [markdown]
# **Top Coins Historical Prices**

# %%
# getting data for top coins price history
all_coins = []

coin_ids = ['bitcoin','ethereum','tether','binancecoin','ripple']

for i in coin_ids:
  url = f"https://api.coingecko.com/api/v3/coins/{i}/market_chart?vs_currency=inr&days=365"
  response=requests.get(url)

  if response.status_code == 200:
    coins=response.json()
    prices = coins["prices"]#extracting data to table and converting ms to datestamp
    time.sleep(5)

    for ts, price in prices:
      all_coins.append({"coin_id": i,"date": pd.to_datetime(ts, unit="ms"),"price": price})

top_coins_df = pd.DataFrame(all_coins)

# %%
top_coins_df
# Out:
#       coin_id                date         price
# 0     bitcoin 2025-05-25 00:00:00  9.173866e+06
# 1     bitcoin 2025-05-26 00:00:00  9.274976e+06
# 2     bitcoin 2025-05-27 00:00:00  9.314437e+06
# 3     bitcoin 2025-05-28 00:00:00  9.310175e+06
# 4     bitcoin 2025-05-29 00:00:00  9.208281e+06
# ..        ...                 ...           ...
# 727  ethereum 2026-05-21 00:00:00  2.053445e+05
# 728  ethereum 2026-05-22 00:00:00  2.050139e+05
# 729  ethereum 2026-05-23 00:00:00  1.976018e+05
# 730  ethereum 2026-05-24 00:00:00  2.024743e+05
# 731  ethereum 2026-05-24 15:54:11  2.003096e+05
#
# [732 rows x 3 columns]

# %%
# date only extract from datestamp
top_coins_df["date"] = pd.to_datetime(top_coins_df["date"]).dt.date
top_coins_df
# Out:
#       coin_id        date         price
# 0     bitcoin  2025-05-25  9.173866e+06
# 1     bitcoin  2025-05-26  9.274976e+06
# 2     bitcoin  2025-05-27  9.314437e+06
# 3     bitcoin  2025-05-28  9.310175e+06
# 4     bitcoin  2025-05-29  9.208281e+06
# ..        ...         ...           ...
# 727  ethereum  2026-05-21  2.053445e+05
# 728  ethereum  2026-05-22  2.050139e+05
# 729  ethereum  2026-05-23  1.976018e+05
# 730  ethereum  2026-05-24  2.024743e+05
# 731  ethereum  2026-05-24  2.003096e+05
#
# [732 rows x 3 columns]

# %% [markdown]
# **Oil Prices(WTI Crude)**

# %%
# data collection from csv file - github link
import pandas as pd

oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")
oil_df
# Out:
#              Date   Price
# 0      1986-01-02   25.56
# 1      1986-01-03   26.00
# 2      1986-01-06   26.53
# 3      1986-01-07   25.85
# 4      1986-01-08   25.87
# ...           ...     ...
# 10158  2026-05-12  105.78
# 10159  2026-05-13  104.52
# 10160  2026-05-14  104.66
# 10161  2026-05-15  108.99
# 10162  2026-05-18  112.25
#
# [10163 rows x 2 columns]

# %%
# extracting data from Jan 2020 - Feb 2026 ==> mentioned in project file
oil_df['Date'] = pd.to_datetime(oil_df['Date'])
start_date = pd.to_datetime('2020-01-01')
end_date   = pd.to_datetime('2026-02-23')

oil_df = oil_df[(oil_df['Date'] >= start_date) & (oil_df['Date'] <= end_date)]

oil_df
# Out:
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10099 2026-02-17  62.53
# 10100 2026-02-18  65.33
# 10101 2026-02-19  66.66
# 10102 2026-02-20  66.69
# 10103 2026-02-23  66.36
#
# [1535 rows x 2 columns]

# %%
oil_df = oil_df.reset_index(drop=True)
oil_df
# Out:
#            Date  Price
# 0    2020-01-02  61.17
# 1    2020-01-03  63.00
# 2    2020-01-06  63.27
# 3    2020-01-07  62.70
# 4    2020-01-08  59.65
# ...         ...    ...
# 1530 2026-02-17  62.53
# 1531 2026-02-18  65.33
# 1532 2026-02-19  66.66
# 1533 2026-02-20  66.69
# 1534 2026-02-23  66.36
#
# [1535 rows x 2 columns]

# %% [markdown]
# **Stock Prices (Yahoo Finance API)**

# %%
# collect following stocks data from Yahoo Finance API
import yfinance as YF

# %%
tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-02-23"

stk_df = YF.download(tickers, start=start_date, end=end_date, group_by="ticker")
stk_df.head()
# Out:
# /tmp/ipykernel_61188/823814597.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stk_df = YF.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker             ^NSEI                                                      \
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0
#
# Ticker            ^IXIC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  9039.459961  9093.429688  9010.889648  9092.190430  2.862700e+09
# 2020-01-03  8976.429688  9065.759766  8976.429688  9020.769531  2.586520e+09
# 2020-01-06  8943.500000  9072.410156  8943.500000  9071.469727  2.810450e+09
# 2020-01-07  9076.639648  9091.929688  9042.549805  9068.580078  2.381740e+09
#
# Ticker            ^GSPC
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3.459930e+09
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3.484700e+09
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3.702460e+09
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3.435910e+09

# %%
# colleting data separately for easy undersating
# "^NSEI"
stocks1_df = stk_df["^NSEI"].reset_index()
stocks1_df.head()
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1     2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2     2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 3     2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 4     2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
#
# Price    Volume
# 0      304100.0
# 1      407700.0
# 2      428800.0
# 3      396500.0
# 4      447800.0

# %%
# adding column ==> "tickers"
stocks1_df.insert(1, "Ticker", "^NSEI")
stocks1_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1588  2026-02-16  ^NSEI  25423.599609  25697.000000  25372.699219
# 1589  2026-02-17  ^NSEI  25637.949219  25764.400391  25570.300781
# 1590  2026-02-18  ^NSEI  25752.650391  25828.050781  25645.150391
# 1591  2026-02-19  ^NSEI  25873.349609  25885.300781  25388.750000
# 1592  2026-02-20  ^NSEI  25406.550781  25663.550781  25379.750000
#
# Price         Close    Volume
# 0      12182.500000  304100.0
# 1      12282.200195  407700.0
# 2      12226.650391  428800.0
# 3      11993.049805  396500.0
# 4      12052.950195  447800.0
# ...             ...       ...
# 1588   25682.750000  275800.0
# 1589   25725.400391  344100.0
# 1590   25819.349609  310200.0
# 1591   25454.349609  298200.0
# 1592   25571.250000  296600.0
#
# [1593 rows x 7 columns]

# %%
# finding nulls from collected data
print(stocks1_df.isnull().sum())
# Out:
# Price
# Date       0
# Ticker     0
# Open      72
# High      72
# Low       72
# Close     72
# Volume    72
# dtype: int64

# %%
# remove null for clear undersating
stocks1_df = stocks1_df.dropna()

# %%
stocks1_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1588  2026-02-16  ^NSEI  25423.599609  25697.000000  25372.699219
# 1589  2026-02-17  ^NSEI  25637.949219  25764.400391  25570.300781
# 1590  2026-02-18  ^NSEI  25752.650391  25828.050781  25645.150391
# 1591  2026-02-19  ^NSEI  25873.349609  25885.300781  25388.750000
# 1592  2026-02-20  ^NSEI  25406.550781  25663.550781  25379.750000
#
# Price         Close    Volume
# 0      12182.500000  304100.0
# 1      12282.200195  407700.0
# 2      12226.650391  428800.0
# 3      11993.049805  396500.0
# 4      12052.950195  447800.0
# ...             ...       ...
# 1588   25682.750000  275800.0
# 1589   25725.400391  344100.0
# 1590   25819.349609  310200.0
# 1591   25454.349609  298200.0
# 1592   25571.250000  296600.0
#
# [1521 rows x 7 columns]

# %%
print(stocks1_df.isnull().sum())
# Out:
# Price
# Date      0
# Ticker    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# "^IXIC"
stocks2_df = stk_df["^IXIC"].reset_index()

stocks2_df.insert(1, "Ticker", "^IXIC") # inserting column

stocks2_df = stocks2_df.dropna() # removing nulls

stocks2_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 1     2020-01-02  ^IXIC   9039.459961   9093.429688   9010.889648
# 2     2020-01-03  ^IXIC   8976.429688   9065.759766   8976.429688
# 3     2020-01-06  ^IXIC   8943.500000   9072.410156   8943.500000
# 4     2020-01-07  ^IXIC   9076.639648   9091.929688   9042.549805
# 5     2020-01-08  ^IXIC   9068.030273   9168.889648   9059.379883
# ...          ...    ...           ...           ...           ...
# 1587  2026-02-13  ^IXIC  22561.460938  22742.060547  22402.380859
# 1589  2026-02-17  ^IXIC  22394.759766  22690.830078  22256.759766
# 1590  2026-02-18  ^IXIC  22629.849609  22895.960938  22597.769531
# 1591  2026-02-19  ^IXIC  22639.880859  22768.830078  22583.609375
# 1592  2026-02-20  ^IXIC  22542.279297  22948.869141  22539.050781
#
# Price         Close        Volume
# 1       9092.190430  2.862700e+09
# 2       9020.769531  2.586520e+09
# 3       9071.469727  2.810450e+09
# 4       9068.580078  2.381740e+09
# 5       9129.240234  2.472620e+09
# ...             ...           ...
# 1587   22546.669922  7.964830e+09
# 1589   22578.380859  7.654300e+09
# 1590   22753.630859  7.705590e+09
# 1591   22682.730469  6.984780e+09
# 1592   22886.070312  8.063070e+09
#
# [1542 rows x 7 columns]

# %%
stocks2_df.isnull().sum() # checking null values are removed
# Out:
# Price
# Date      0
# Ticker    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# "^GSPC"
stocks3_df = stk_df["^GSPC"].reset_index()

stocks3_df.insert(1, "Ticker", "^GSPC") # inserting column

stocks3_df = stocks3_df.dropna() # removing nulls

stocks3_df
# Out:
# Price       Date Ticker         Open         High          Low        Close  \
# 1     2020-01-02  ^GSPC  3244.669922  3258.139893  3235.530029  3257.850098
# 2     2020-01-03  ^GSPC  3226.360107  3246.149902  3222.340088  3234.850098
# 3     2020-01-06  ^GSPC  3217.550049  3246.840088  3214.639893  3246.280029
# 4     2020-01-07  ^GSPC  3241.860107  3244.909912  3232.429932  3237.179932
# 5     2020-01-08  ^GSPC  3238.590088  3267.070068  3236.669922  3253.050049
# ...          ...    ...          ...          ...          ...          ...
# 1587  2026-02-13  ^GSPC  6834.270020  6881.959961  6794.549805  6836.169922
# 1589  2026-02-17  ^GSPC  6819.859863  6866.990234  6775.500000  6843.220215
# 1590  2026-02-18  ^GSPC  6855.479980  6909.120117  6849.660156  6881.310059
# 1591  2026-02-19  ^GSPC  6861.339844  6879.120117  6833.060059  6861.890137
# 1592  2026-02-20  ^GSPC  6843.259766  6915.859863  6836.330078  6909.509766
#
# Price        Volume
# 1      3.459930e+09
# 2      3.484700e+09
# 3      3.702460e+09
# 4      3.435910e+09
# 5      3.726840e+09
# ...             ...
# 1587   5.718360e+09
# 1589   5.418480e+09
# 1590   5.098160e+09
# 1591   5.151690e+09
# 1592   5.432480e+09
#
# [1542 rows x 7 columns]

# %%
stocks3_df.isnull().sum() # checking null values are removed
# Out:
# Price
# Date      0
# Ticker    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# merging all stocks after cleaning nulls and adding column for comparision
stks_df = pd.concat([stocks1_df, stocks2_df, stocks3_df])
stks_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1587  2026-02-13  ^GSPC   6834.270020   6881.959961   6794.549805
# 1589  2026-02-17  ^GSPC   6819.859863   6866.990234   6775.500000
# 1590  2026-02-18  ^GSPC   6855.479980   6909.120117   6849.660156
# 1591  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 1592  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
#
# Price         Close        Volume
# 0      12182.500000  3.041000e+05
# 1      12282.200195  4.077000e+05
# 2      12226.650391  4.288000e+05
# 3      11993.049805  3.965000e+05
# 4      12052.950195  4.478000e+05
# ...             ...           ...
# 1587    6836.169922  5.718360e+09
# 1589    6843.220215  5.418480e+09
# 1590    6881.310059  5.098160e+09
# 1591    6861.890137  5.151690e+09
# 1592    6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %%
stks_df.isnull().sum() # verify nulls after merging all three data
# Out:
# Price
# Date      0
# Ticker    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
stks_df
# Out:
# Price       Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 1587  2026-02-13  ^GSPC   6834.270020   6881.959961   6794.549805
# 1589  2026-02-17  ^GSPC   6819.859863   6866.990234   6775.500000
# 1590  2026-02-18  ^GSPC   6855.479980   6909.120117   6849.660156
# 1591  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 1592  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
#
# Price         Close        Volume
# 0      12182.500000  3.041000e+05
# 1      12282.200195  4.077000e+05
# 2      12226.650391  4.288000e+05
# 3      11993.049805  3.965000e+05
# 4      12052.950195  4.478000e+05
# ...             ...           ...
# 1587    6836.169922  5.718360e+09
# 1589    6843.220215  5.418480e+09
# 1590    6881.310059  5.098160e+09
# 1591    6861.890137  5.151690e+09
# 1592    6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %% [markdown]
# # **Saving data into csv**

# %%
crypto_df = crypto_df.to_csv("crypto_df.csv", index=False)

top_coins_df = top_coins_df.to_csv("top_coins_df.csv", index=False)

oil_df = oil_df.to_csv("oil_df.csv", index=False)

stks_df = stks_df.to_csv("stks_df.csv", index=False)

# %%
# reading collected csv data
crypto_df = pd.read_csv("crypto_df.csv")
crypto_df
# Out:
#                                    coin_id  symbol  \
# 0                                  bitcoin     btc
# 1                                 ethereum     eth
# 2                                   tether    usdt
# 3                              binancecoin     bnb
# 4                                   ripple     xrp
# ...                                    ...     ...
# 1245                                vaulta       a
# 1246                             instadapp   fluid
# 1247                           wemix-token   wemix
# 1248                                 1inch   1inch
# 1249  theo-short-duration-us-treasury-fund  thbill
#
#                                  coin_name  current_price       market_cap  \
# 0                                  Bitcoin     7308304.00  146386017371486
# 1                                 Ethereum      200378.00   24171984843745
# 2                                   Tether          95.59   18134047627886
# 3                                      BNB       62682.00    8446532286283
# 4                                      XRP         128.98    7981145342833
# ...                                    ...            ...              ...
# 1245                                Vaulta           7.49      12314406425
# 1246                                 Fluid         157.93      12302563147
# 1247                                 WEMIX          26.56      12275525199
# 1248                                 1INCH           8.68      12195153213
# 1249  Theo Short Duration US Treasury Fund          98.06      12111736268
#
#       market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                   1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                   2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                   3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                   4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                   5  1.310528e+11        6.185832e+10  9.998566e+10
# ...               ...           ...                 ...           ...
# 1245              246  1.145042e+09        1.643370e+09  2.100000e+09
# 1246              247  2.787547e+08        7.794700e+07  1.000000e+08
# 1247              248  1.013455e+08        4.622778e+08  5.524732e+08
# 1248              249  6.209907e+08        1.405574e+09  1.500000e+09
# 1249              250  1.638317e+07        1.236424e+08  1.236424e+08
#
#               ath          atl last_updated
# 0     11187013.00  3993.420000   2026-05-24
# 1       431946.00    28.130000   2026-05-24
# 2          105.52    36.860000   2026-05-24
# 3       121422.00     2.580000   2026-05-24
# 4          313.99     0.159343   2026-05-24
# ...           ...          ...          ...
# 1245        66.55     6.410000   2026-05-24
# 1246      1799.83    30.330000   2026-05-24
# 1247      1836.35     9.550000   2026-05-24
# 1248       648.39     7.550000   2026-05-24
# 1249       100.55    80.460000   2026-05-24
#
# [1250 rows x 12 columns]

# %%
top_coins_df = pd.read_csv("top_coins_df.csv")
top_coins_df
# Out:
#       coin_id        date         price
# 0     bitcoin  2025-05-25  9.173866e+06
# 1     bitcoin  2025-05-26  9.274976e+06
# 2     bitcoin  2025-05-27  9.314437e+06
# 3     bitcoin  2025-05-28  9.310175e+06
# 4     bitcoin  2025-05-29  9.208281e+06
# ..        ...         ...           ...
# 727  ethereum  2026-05-21  2.053445e+05
# 728  ethereum  2026-05-22  2.050139e+05
# 729  ethereum  2026-05-23  1.976018e+05
# 730  ethereum  2026-05-24  2.024743e+05
# 731  ethereum  2026-05-24  2.003096e+05
#
# [732 rows x 3 columns]

# %%
oil_df = pd.read_csv("oil_df.csv")
oil_df
# Out:
#             Date  Price
# 0     2020-01-02  61.17
# 1     2020-01-03  63.00
# 2     2020-01-06  63.27
# 3     2020-01-07  62.70
# 4     2020-01-08  59.65
# ...          ...    ...
# 1530  2026-02-17  62.53
# 1531  2026-02-18  65.33
# 1532  2026-02-19  66.66
# 1533  2026-02-20  66.69
# 1534  2026-02-23  66.36
#
# [1535 rows x 2 columns]

# %%
stks_df = pd.read_csv("stks_df.csv")
stks_df
# Out:
#             Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 4600  2026-02-13  ^GSPC   6834.270020   6881.959961   6794.549805
# 4601  2026-02-17  ^GSPC   6819.859863   6866.990234   6775.500000
# 4602  2026-02-18  ^GSPC   6855.479980   6909.120117   6849.660156
# 4603  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 4604  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
#
#              Close        Volume
# 0     12182.500000  3.041000e+05
# 1     12282.200195  4.077000e+05
# 2     12226.650391  4.288000e+05
# 3     11993.049805  3.965000e+05
# 4     12052.950195  4.478000e+05
# ...            ...           ...
# 4600   6836.169922  5.718360e+09
# 4601   6843.220215  5.418480e+09
# 4602   6881.310059  5.098160e+09
# 4603   6861.890137  5.151690e+09
# 4604   6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %% [markdown]
# # **SQL connection Table Creation**

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.12/dist-packages (9.7.0)

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
    user = "3fXqCw6nxxduoS8.root",
    password = "u2dctQHUVuOXcZhS",
    port = 4000
)

# %%
cma = conn.cursor()

# %%
cma.execute("DROP DATABASE IF EXISTS Cross_Market_Analysis")
conn.commit()

# %%
cma.execute("CREATE DATABASE Cross_Market_Analysis")
conn.commit()

# %%
cma.execute("show databases")
cma.fetchall()
# Out:
# [('INFORMATION_SCHEMA',),
#  ('Cross_Market_Analysis',),
#  ('Global_Literacy',),
#  ('PERFORMANCE_SCHEMA',),
#  ('mysql',)]

# %%
cma.execute("use Cross_Market_Analysis")

# %%
# creating tables for cryptocurrencies

cma.execute("""CREATE TABLE cryptocurrencies
                 (id VARCHAR(50) PRIMARY KEY,
                 symbol VARCHAR(10),
                 name VARCHAR(100),
                 current_price DECIMAL(18, 6),
                 market_cap BIGINT,
                 market_cap_rank INT,
                 total_volume BIGINT,
                 circulating_supply DECIMAL(20, 6),
                 total_supply DECIMAL(20, 6),
                 ath DECIMAL(18, 6),
                 atl DECIMAL(18, 6),
                 date DATE
                 );

                 """)
conn.commit() # apply the changes to the sqlite3

# %%
#creating table for Crypto_prices

cma.execute("""CREATE TABLE top_coins
                 (coin_id VARCHAR(50),
                 date DATE,
                 price DECIMAL(18, 6)
                 );

                 """)
conn.commit()

# %%
#creating table for Oil_prices

cma.execute("""CREATE TABLE oil_prices
                 (date DATE PRIMARY KEY,
                 price_INR DECIMAL(18, 6)
                 );

                 """)
conn.commit()

# %%
#creating table for Stock_prices
cma.execute("""CREATE TABLE stk_prices
                 (date DATE,
                 open DECIMAL(18, 6),
                 high DECIMAL(18, 6),
                 low DECIMAL(18, 6),
                 close DECIMAL(18, 6),
                 volume BIGINT,
                 ticker VARCHAR(20)
                 );

                 """)
conn.commit()

# %%
cma.execute("show tables")
cma.fetchall()
# Out:
# [('cryptocurrencies',), ('oil_prices',), ('stk_prices',), ('top_coins',)]

# %% [markdown]
# # **Pushing data frames in to SQL and create sql engine**

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.49)
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.12/dist-packages (9.7.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqlconnector://3fXqCw6nxxduoS8.root:u2dctQHUVuOXcZhS@gateway01.ap-southeast-1.prod.aws.tidbcloud.com:4000/Cross_Market_Analysis")

# %%
crypto_df.to_sql ("cryptocurrencies", con = engine, if_exists = "replace", index = False) # push crypto_df to sqlite
# Out:
# -1

# %%
top_coins_df.to_sql ("top_coins", con = engine, if_exists = "replace", index = False)
# Out:
# -1

# %%
oil_df.to_sql ("oil_prices", con = engine, if_exists = "replace", index = False)
# Out:
# -1

# %%
stks_df.to_sql ("stks_prices", con = engine, if_exists = "replace", index = False)
# Out:
# -1

# %% [markdown]
# # **Querries where mentioned in project file**

# %% [markdown]
# ### **Cryptocurrencies**

# %%
# show/read cryptocurrencies table
df = pd.read_sql("SELECT * FROM  cryptocurrencies;", engine)
df
# Out:
#                                    coin_id  symbol  \
# 0                                  bitcoin     btc
# 1                                 ethereum     eth
# 2                                   tether    usdt
# 3                              binancecoin     bnb
# 4                                   ripple     xrp
# ...                                    ...     ...
# 1245                                vaulta       a
# 1246                             instadapp   fluid
# 1247                           wemix-token   wemix
# 1248                                 1inch   1inch
# 1249  theo-short-duration-us-treasury-fund  thbill
#
#                                  coin_name  current_price       market_cap  \
# 0                                  Bitcoin     7308304.00  146386017371486
# 1                                 Ethereum      200378.00   24171984843745
# 2                                   Tether          95.59   18134047627886
# 3                                      BNB       62682.00    8446532286283
# 4                                      XRP         128.98    7981145342833
# ...                                    ...            ...              ...
# 1245                                Vaulta           7.49      12314406425
# 1246                                 Fluid         157.93      12302563147
# 1247                                 WEMIX          26.56      12275525199
# 1248                                 1INCH           8.68      12195153213
# 1249  Theo Short Duration US Treasury Fund          98.06      12111736268
#
#       market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                   1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                   2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                   3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                   4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                   5  1.310528e+11        6.185832e+10  9.998566e+10
# ...               ...           ...                 ...           ...
# 1245              246  1.145042e+09        1.643370e+09  2.100000e+09
# 1246              247  2.787547e+08        7.794700e+07  1.000000e+08
# 1247              248  1.013455e+08        4.622778e+08  5.524732e+08
# 1248              249  6.209907e+08        1.405574e+09  1.500000e+09
# 1249              250  1.638317e+07        1.236424e+08  1.236424e+08
#
#               ath          atl last_updated
# 0     11187013.00  3993.420000   2026-05-24
# 1       431946.00    28.130000   2026-05-24
# 2          105.52    36.860000   2026-05-24
# 3       121422.00     2.580000   2026-05-24
# 4          313.99     0.159343   2026-05-24
# ...           ...          ...          ...
# 1245        66.55     6.410000   2026-05-24
# 1246      1799.83    30.330000   2026-05-24
# 1247      1836.35     9.550000   2026-05-24
# 1248       648.39     7.550000   2026-05-24
# 1249       100.55    80.460000   2026-05-24
#
# [1250 rows x 12 columns]

# %%
# 1. Find the top 5 cryptocurrencies by market cap.
top_cryp = pd.read_sql (
    """SELECT coin_name, MAX(market_cap) AS market_cap FROM cryptocurrencies WHERE market_cap IS NOT NULL GROUP BY coin_name ORDER BY market_cap DESC LIMIT 5;""", engine)

top_cryp
# Out:
#   coin_name       market_cap
# 0   Bitcoin  146386017371486
# 1  Ethereum   24171984843745
# 2    Tether   18134047627886
# 3       BNB    8446532286283
# 4       XRP    7981145342833

# %%
# 2. List all coins where circulating supply exceeds 90% of total supply.

cir_sup = pd.read_sql (
    """SELECT * FROM cryptocurrencies WHERE total_supply IS NOT NULL AND total_supply > 0 AND circulating_supply >= 0.9 * total_supply AND circulating_supply IS NOT NULL;""", engine)

cir_sup
# Out:
#                                   coin_id     symbol  \
# 0                                 bitcoin        btc
# 1                                ethereum        eth
# 2                                  tether       usdt
# 3                             binancecoin        bnb
# 4                                usd-coin       usdc
# ..                                    ...        ...
# 720           tradable-latam-fintech-sstn  pc0000097
# 721                              frax-usd     frxusd
# 722                          agora-dollar       ausd
# 723                                 1inch      1inch
# 724  theo-short-duration-us-treasury-fund     thbill
#
#                                 coin_name  current_price       market_cap  \
# 0                                 Bitcoin     7308304.00  146386017371486
# 1                                Ethereum      200378.00   24171984843745
# 2                                  Tether          95.59   18134047627886
# 3                                     BNB       62682.00    8446532286283
# 4                                    USDC          95.67    7313713649235
# ..                                    ...            ...              ...
# 720           Tradable LatAm Fintech SSTN          95.70      12823863918
# 721                              Frax USD          95.67      12747180230
# 722                                  AUSD          95.66      12361882467
# 723                                 1INCH           8.68      12195153213
# 724  Theo Short Duration US Treasury Fund          98.06      12111736268
#
#      market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                  1  3.076642e+12        2.003380e+07  2.003381e+07
# 1                  2  1.266677e+12        1.206855e+08  1.206855e+08
# 2                  3  4.368705e+12        1.897211e+11  1.951881e+11
# 3                  4  6.561453e+10        1.347849e+08  1.347849e+08
# 4                  6  9.270800e+11        7.643307e+10  7.643161e+10
# ..               ...           ...                 ...           ...
# 720              243           NaN        1.340000e+08  1.340000e+08
# 721              244  5.318948e+08        1.332411e+08  1.332379e+08
# 722              245  3.517345e+09        1.292226e+08  1.292226e+08
# 723              249  6.209907e+08        1.405574e+09  1.500000e+09
# 724              250  1.638317e+07        1.236424e+08  1.236424e+08
#
#              ath      atl last_updated
# 0    11187013.00  3993.42   2026-05-24
# 1      431946.00    28.13   2026-05-24
# 2         105.52    36.86   2026-05-24
# 3      121422.00     2.58   2026-05-24
# 4          96.98    65.31   2026-05-24
# ..           ...      ...          ...
# 720        97.00    85.32   2026-05-24
# 721        96.99    83.77   2026-05-24
# 722        96.99    80.49   2026-05-24
# 723       648.39     7.55   2026-05-24
# 724       100.55    80.46   2026-05-24
#
# [725 rows x 12 columns]

# %%
# 3. Get coins that are within 10% of their all-time-high (ATH).

ath = pd.read_sql(""" SELECT * FROM cryptocurrencies WHERE current_price >= 0.9 * ath
AND current_price IS NOT NULL ORDER BY current_price DESC;
""", engine)

ath
# Out:
#     coin_id symbol coin_name  current_price     market_cap  market_cap_rank  \
# 0      ousg   ousg      OUSG       11036.77    52943413128               99
# 1      ousg   ousg      OUSG       11036.77    52943413128               99
# 2      ousg   ousg      OUSG       11036.77    52943413128               99
# 3      ousg   ousg      OUSG       11036.77    52943413128               99
# 4      ousg   ousg      OUSG       11036.77    52943413128               99
# ..      ...    ...       ...            ...            ...              ...
# 275    tron    trx      TRON          34.97  3315695110115                8
# 276    tron    trx      TRON          34.97  3315695110115                8
# 277    tron    trx      TRON          34.97  3315695110115                8
# 278    tron    trx      TRON          34.97  3315695110115                8
# 279    tron    trx      TRON          34.97  3315695110115                8
#
#      total_volume  circulating_supply  total_supply       ath          atl  \
# 0    0.000000e+00        4.797003e+06  4.797003e+06  11182.59  7844.420000
# 1    0.000000e+00        4.797003e+06  4.797003e+06  11182.59  7844.420000
# 2    0.000000e+00        4.797003e+06  4.797003e+06  11182.59  7844.420000
# 3    0.000000e+00        4.797003e+06  4.797003e+06  11182.59  7844.420000
# 4    0.000000e+00        4.797003e+06  4.797003e+06  11182.59  7844.420000
# ..            ...                 ...           ...       ...          ...
# 275  4.331375e+10        9.480472e+10  9.480795e+10     36.53     0.117589
# 276  4.331375e+10        9.480472e+10  9.480795e+10     36.53     0.117589
# 277  4.331375e+10        9.480472e+10  9.480795e+10     36.53     0.117589
# 278  4.331375e+10        9.480472e+10  9.480795e+10     36.53     0.117589
# 279  4.331375e+10        9.480472e+10  9.480795e+10     36.53     0.117589
#
#     last_updated
# 0     2026-05-24
# 1     2026-05-24
# 2     2026-05-24
# 3     2026-05-24
# 4     2026-05-24
# ..           ...
# 275   2026-05-24
# 276   2026-05-24
# 277   2026-05-24
# 278   2026-05-24
# 279   2026-05-24
#
# [280 rows x 12 columns]

# %%
# 4. Find the average market cap rank of coins with volume above $1B.

df = pd.read_sql ("SELECT AVG(market_cap_rank) FROM cryptocurrencies WHERE total_volume > 1000000000 AND total_volume IS NOT NULL;", engine)

df
# Out:
#    AVG(market_cap_rank)
# 0              100.3481

# %%
# 5. Get the most recently updated coin.

df = pd.read_sql ("SELECT * FROM cryptocurrencies ORDER BY last_updated DESC LIMIT 1;", engine)

df
# Out:
#    coin_id symbol coin_name  current_price       market_cap  market_cap_rank  \
# 0  bitcoin    btc   Bitcoin      7308304.0  146386017371486                1
#
#    total_volume  circulating_supply  total_supply         ath      atl  \
# 0  3.076642e+12          20033796.0    20033812.0  11187013.0  3993.42
#
#   last_updated
# 0   2026-05-24

# %% [markdown]
# ### **Crypto_Prices (Daily Prices of Top Coins)**

# %%
df = pd.read_sql("SELECT * FROM  top_coins;", engine)
df
# Out:
#       coin_id        date         price
# 0     bitcoin  2025-05-25  9.173866e+06
# 1     bitcoin  2025-05-26  9.274976e+06
# 2     bitcoin  2025-05-27  9.314437e+06
# 3     bitcoin  2025-05-28  9.310175e+06
# 4     bitcoin  2025-05-29  9.208281e+06
# ..        ...         ...           ...
# 727  ethereum  2026-05-21  2.053445e+05
# 728  ethereum  2026-05-22  2.050139e+05
# 729  ethereum  2026-05-23  1.976018e+05
# 730  ethereum  2026-05-24  2.024743e+05
# 731  ethereum  2026-05-24  2.003096e+05
#
# [732 rows x 3 columns]

# %%
# 1. Find the highest daily price of Bitcoin in the last 365 days.

df = pd.read_sql(
    """SELECT coin_id, MAX(price) AS highest_daily_price FROM top_coins WHERE coin_id = 'bitcoin' AND DATE(date) >= DATE_SUB(CURDATE(), INTERVAL 365 DAY);""", engine
)

df
# Out:
#    coin_id  highest_daily_price
# 0  bitcoin         1.107047e+07

# %%
# 2. Calculate the average daily price of Ethereum in the past 1 year.

df = pd.read_sql ("SELECT coin_id, AVG(price) as Avg_price FROM top_coins WHERE coin_id = 'ethereum' AND DATE(date) >= DATE_SUB(CURDATE(), INTERVAL 365 DAY);", engine)

df
# Out:
#     coin_id      Avg_price
# 0  ethereum  271467.115309

# %%
# 3. Show the daily price trend of Bitcoin in January 2025. (or change the month and year according you your data)

df = pd.read_sql(
    """SELECT coin_id, price AS daily_price, date FROM top_coins WHERE coin_id = 'bitcoin' AND Date BETWEEN '2025-01-01' AND '2026-02-28' ORDER BY Date;""", engine)

df
# Out:
#      coin_id   daily_price        date
# 0    bitcoin  9.173866e+06  2025-05-25
# 1    bitcoin  9.274976e+06  2025-05-26
# 2    bitcoin  9.314437e+06  2025-05-27
# 3    bitcoin  9.310175e+06  2025-05-28
# 4    bitcoin  9.208281e+06  2025-05-29
# ..       ...           ...         ...
# 275  bitcoin  5.877905e+06  2026-02-24
# 276  bitcoin  5.825506e+06  2026-02-25
# 277  bitcoin  6.179907e+06  2026-02-26
# 278  bitcoin  6.139222e+06  2026-02-27
# 279  bitcoin  6.000770e+06  2026-02-28
#
# [280 rows x 3 columns]

# %%
# 4. Find the coin with the highest average price over 1 year.

df = pd.read_sql (
    """SELECT coin_id, AVG(price) AS avg_price FROM top_coins WHERE DATE(date) >= DATE_SUB(CURDATE(), INTERVAL 365 DAY)
    GROUP BY coin_id ORDER BY avg_price DESC LIMIT 1;""",
    engine)

df
# Out:
#    coin_id     avg_price
# 0  bitcoin  8.470050e+06

# %%
# 5. Get the % change in Bitcoin’s price between Feb 2025 and Feb 2026.

df = pd.read_sql(
    """ SELECT
        (
            (MAX(CASE WHEN DATE(date) BETWEEN '2026-02-01' AND '2026-02-28' THEN price END)
                -
                MAX(CASE WHEN DATE(date) BETWEEN '2025-02-01' AND '2025-02-28' THEN price END)
            )
            /
            MAX(CASE WHEN DATE(date) BETWEEN '2025-02-01' AND '2025-02-28' THEN price END)
        ) * 100 AS percentage_change
    FROM top_coins WHERE coin_id = 'bitcoin';""",
    engine
)

df
# Out:
#   percentage_change
# 0              None

# %% [markdown]
# ### **Oil_Price**

# %%
df = pd.read_sql ("SELECT * FROM  oil_prices;", engine)
df
# Out:
#             Date  Price
# 0     2020-01-02  61.17
# 1     2020-01-03  63.00
# 2     2020-01-06  63.27
# 3     2020-01-07  62.70
# 4     2020-01-08  59.65
# ...          ...    ...
# 1530  2026-02-17  62.53
# 1531  2026-02-18  65.33
# 1532  2026-02-19  66.66
# 1533  2026-02-20  66.69
# 1534  2026-02-23  66.36
#
# [1535 rows x 2 columns]

# %%
# 1. Find the highest oil price in the last 5 years.

df = pd.read_sql(""" SELECT MAX(price) AS highest_price FROM oil_prices WHERE date >= DATE_SUB(CURDATE(), INTERVAL 5 YEAR);
""", engine)

df
# Out:
#    highest_price
# 0         123.64

# %%
# 2. Get the average oil price per year.

df = pd.read_sql("""SELECT YEAR(date) AS year, AVG(price) AS avg_price
FROM oil_prices GROUP BY YEAR(date) ORDER BY YEAR(date);""", engine)

df
# Out:
#    year  avg_price
# 0  2020  39.160437
# 1  2021  68.135100
# 2  2022  94.902869
# 3  2023  77.576532
# 4  2024  76.632240
# 5  2025  65.388105
# 6  2026  61.812000

# %%
# 3. Show oil prices during COVID crash (March–April 2020).

df = pd.read_sql("""SELECT date, price FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-30' ORDER BY date;
""", engine)

df
# Out:
#           date  price
# 0   2020-03-02  46.78
# 1   2020-03-03  47.27
# 2   2020-03-04  46.78
# 3   2020-03-05  45.90
# 4   2020-03-06  41.14
# 5   2020-03-09  31.05
# 6   2020-03-10  34.47
# 7   2020-03-11  33.13
# 8   2020-03-12  31.56
# 9   2020-03-13  31.72
# 10  2020-03-16  28.96
# 11  2020-03-17  26.96
# 12  2020-03-18  20.48
# 13  2020-03-19  25.09
# 14  2020-03-20  19.48
# 15  2020-03-23  23.33
# 16  2020-03-24  21.03
# 17  2020-03-25  20.75
# 18  2020-03-26  16.60
# 19  2020-03-27  15.48
# 20  2020-03-30  14.10
# 21  2020-03-31  20.51
# 22  2020-04-01  20.28
# 23  2020-04-02  25.18
# 24  2020-04-03  28.36
# 25  2020-04-06  26.21
# 26  2020-04-07  23.54
# 27  2020-04-08  24.97
# 28  2020-04-09  22.90
# 29  2020-04-13  22.36
# 30  2020-04-14  20.15
# 31  2020-04-15  19.96
# 32  2020-04-16  19.82
# 33  2020-04-17  18.31
# 34  2020-04-20 -36.98
# 35  2020-04-21   8.91
# 36  2020-04-22  13.64
# 37  2020-04-23  15.06
# 38  2020-04-24  15.99
# 39  2020-04-27  12.17
# 40  2020-04-28  12.40
# 41  2020-04-29  15.04
# 42  2020-04-30  19.23

# %%
# 4. Find the lowest price of oil in the last 10 years.

df = pd.read_sql("""SELECT date, price FROM oil_prices
WHERE price = (SELECT MIN(price) FROM oil_prices WHERE date >= DATE_SUB(CURDATE(), INTERVAL 10 YEAR));
""", engine)

df
# Out:
#          date  price
# 0  2020-04-20 -36.98

# %%
# 5. Calculate the volatility of oil prices (max-min difference per year).

df = pd.read_sql("""SELECT YEAR(date) AS year, MAX(price) AS highest_price, MIN(price) AS lowest_price, MAX(price) - MIN(price) AS volatility
FROM oil_prices GROUP BY YEAR(date) ORDER BY YEAR(date);
""", engine)

df
# Out:
#    year  highest_price  lowest_price  volatility
# 0  2020          63.27        -36.98      100.25
# 1  2021          85.64         47.47       38.17
# 2  2022         123.64         71.05       52.59
# 3  2023          93.67         66.61       27.06
# 4  2024          87.69         66.73       20.96
# 5  2025          80.73         55.44       25.29
# 6  2026          66.69         56.01       10.68

# %% [markdown]
# ### **Stock_Prices**

# %%
df = pd.read_sql("SELECT * FROM stks_prices;", engine)
df
# Out:
#             Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-03  ^NSEI  12261.099609  12265.599609  12191.349609
# 3     2020-01-06  ^NSEI  12170.599609  12179.099609  11974.200195
# 4     2020-01-07  ^NSEI  12079.099609  12152.150391  12005.349609
# ...          ...    ...           ...           ...           ...
# 4600  2026-02-13  ^GSPC   6834.270020   6881.959961   6794.549805
# 4601  2026-02-17  ^GSPC   6819.859863   6866.990234   6775.500000
# 4602  2026-02-18  ^GSPC   6855.479980   6909.120117   6849.660156
# 4603  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 4604  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
#
#              Close        Volume
# 0     12182.500000  3.041000e+05
# 1     12282.200195  4.077000e+05
# 2     12226.650391  4.288000e+05
# 3     11993.049805  3.965000e+05
# 4     12052.950195  4.478000e+05
# ...            ...           ...
# 4600   6836.169922  5.718360e+09
# 4601   6843.220215  5.418480e+09
# 4602   6881.310059  5.098160e+09
# 4603   6861.890137  5.151690e+09
# 4604   6909.509766  5.432480e+09
#
# [4605 rows x 7 columns]

# %%
# 1. Get all stock prices for a given ticker

df = pd.read_sql(""" SELECT * FROM stks_prices WHERE Ticker IN ('^IXIC', '^NSEI', '^GSPC')
AND Open IS NOT NULL AND High IS NOT NULL
AND Low IS NOT NULL AND Close IS NOT NULL
AND Volume IS NOT NULL ORDER BY Date;
""", engine)

df
# Out:
#             Date Ticker          Open          High           Low  \
# 0     2020-01-01  ^NSEI  12202.150391  12222.200195  12165.299805
# 1     2020-01-02  ^NSEI  12198.549805  12289.900391  12195.250000
# 2     2020-01-02  ^GSPC   3244.669922   3258.139893   3235.530029
# 3     2020-01-02  ^IXIC   9039.459961   9093.429688   9010.889648
# 4     2020-01-03  ^IXIC   8976.429688   9065.759766   8976.429688
# ...          ...    ...           ...           ...           ...
# 4600  2026-02-19  ^GSPC   6861.339844   6879.120117   6833.060059
# 4601  2026-02-19  ^NSEI  25873.349609  25885.300781  25388.750000
# 4602  2026-02-20  ^NSEI  25406.550781  25663.550781  25379.750000
# 4603  2026-02-20  ^GSPC   6843.259766   6915.859863   6836.330078
# 4604  2026-02-20  ^IXIC  22542.279297  22948.869141  22539.050781
#
#              Close        Volume
# 0     12182.500000  3.041000e+05
# 1     12282.200195  4.077000e+05
# 2      3257.850098  3.459930e+09
# 3      9092.190430  2.862700e+09
# 4      9020.769531  2.586520e+09
# ...            ...           ...
# 4600   6861.890137  5.151690e+09
# 4601  25454.349609  2.982000e+05
# 4602  25571.250000  2.966000e+05
# 4603   6909.509766  5.432480e+09
# 4604  22886.070312  8.063070e+09
#
# [4605 rows x 7 columns]

# %%
# 2. Find the highest closing price for NASDAQ (^IXIC)

df = pd.read_sql ("SELECT MAX(close) AS highest_closing_price FROM stks_prices WHERE ticker = '^IXIC';", engine)

df
# Out:
#    highest_closing_price
# 0           23958.470703

# %%
# 3. List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)

df = pd.read_sql ("""SELECT date, high - low AS price_difference FROM stks_prices
WHERE ticker = '^GSPC' ORDER BY price_difference DESC LIMIT 5
;""", engine)

df
# Out:
#          date  price_difference
# 0  2025-04-09        532.909668
# 1  2025-04-07        411.529785
# 2  2025-04-08        357.050293
# 3  2025-04-10        237.879883
# 4  2025-11-20        236.300293

# %%
# 4. Get monthly average closing price for each ticker

df = pd.read_sql("""
SELECT Ticker,
       DATE_FORMAT(Date, '%Y-%m') AS month,
       AVG(Close) AS avg_closing_price
FROM stks_prices
WHERE Close IS NOT NULL AND Date IS NOT NULL
GROUP BY Ticker, month ORDER BY Ticker, month;
""", engine)

df
# Out:
#     Ticker    month  avg_closing_price
# 0    ^GSPC  2020-01        3278.202858
# 1    ^GSPC  2020-02        3277.314183
# 2    ^GSPC  2020-03        2652.393632
# 3    ^GSPC  2020-04        2761.975226
# 4    ^GSPC  2020-05        2919.608484
# ..     ...      ...                ...
# 217  ^NSEI  2025-10       25494.083519
# 218  ^NSEI  2025-11       25894.834396
# 219  ^NSEI  2025-12       25997.738725
# 220  ^NSEI  2026-01       25652.962695
# 221  ^NSEI  2026-02       25681.076693
#
# [222 rows x 3 columns]

# %% [markdown]
# ### **Joint Querries**

# %%
# 1. Compare Bitcoin vs Oil average price in 2025.

df = pd.read_sql("""
SELECT
    DATE(c.date) AS date,
    c.price AS btc_close,
    o.price AS oil_close
FROM top_coins c
LEFT JOIN oil_prices o
    ON DATE(c.date) = DATE(o.date)
WHERE c.coin_id = 'bitcoin'
AND c.price IS NOT NULL
AND o.price IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date     btc_close  oil_close
# 0    2025-05-27  9.314437e+06      61.61
# 1    2025-05-28  9.310175e+06      62.54
# 2    2025-05-29  9.208281e+06      61.66
# 3    2025-05-30  9.026593e+06      61.46
# 4    2025-06-02  9.040802e+06      63.27
# ..          ...           ...        ...
# 180  2026-02-17  6.255750e+06      62.53
# 181  2026-02-18  6.116330e+06      65.33
# 182  2026-02-19  6.033802e+06      66.66
# 183  2026-02-20  6.092367e+06      66.69
# 184  2026-02-23  6.132044e+06      66.36
#
# [185 rows x 3 columns]

# %%
# 2. Check if Bitcoin moves with S&P 500 (correlation idea).

df = pd.read_sql("""
SELECT
    DATE(t.date) AS date,
    t.price AS btc_close,
    s.Close AS stks_close
FROM top_coins t
LEFT JOIN stks_prices s
    ON DATE(t.date) = DATE(s.Date)
   AND s.Ticker = '^GSPC'
WHERE t.coin_id = 'bitcoin'
AND t.price IS NOT NULL
AND s.Close IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date     btc_close   stks_close
# 0    2025-05-27  9.314437e+06  5921.540039
# 1    2025-05-28  9.310175e+06  5888.549805
# 2    2025-05-29  9.208281e+06  5912.169922
# 3    2025-05-30  9.026593e+06  5911.689941
# 4    2025-06-02  9.040802e+06  5935.939941
# ..          ...           ...          ...
# 181  2026-02-13  5.993963e+06  6836.169922
# 182  2026-02-17  6.255750e+06  6843.220215
# 183  2026-02-18  6.116330e+06  6881.310059
# 184  2026-02-19  6.033802e+06  6861.890137
# 185  2026-02-20  6.092367e+06  6909.509766
#
# [186 rows x 3 columns]

# %%
# 3. Compare Ethereum and NASDAQ daily prices for 2025.

df = pd.read_sql("""
SELECT
    DATE(t.date) AS date,
    t.price AS eth_close,
    s.Close AS nasdaq_close
FROM top_coins t
JOIN stks_prices s
    ON DATE(t.date) = DATE(s.Date)
WHERE t.coin_id = 'ethereum'
AND s.Ticker = '^IXIC'
AND YEAR(t.date) = 2025
AND t.price IS NOT NULL
AND s.Close IS NOT NULL
ORDER BY date;
""", engine)


df
# Out:
#            date      eth_close  nasdaq_close
# 0    2025-05-27  218190.675235  19199.160156
# 1    2025-05-28  227238.584850  19100.939453
# 2    2025-05-29  228525.939096  19175.869141
# 3    2025-05-30  224768.844035  19113.769531
# 4    2025-06-02  217089.574074  19242.609375
# ..          ...            ...           ...
# 147  2025-12-24  265308.330577  23613.310547
# 148  2025-12-26  261698.838882  23593.099609
# 149  2025-12-29  264760.550466  23474.349609
# 150  2025-12-30  263786.422730  23419.080078
# 151  2025-12-31  266620.867155  23241.990234
#
# [152 rows x 3 columns]

# %%
# 4. Find days when oil price spiked and compare with Bitcoin price change.

df = pd.read_sql ("""SELECT date(o.Date) AS date,
    o.Price AS oil_price,
    t.price AS btc_price
FROM oil_prices o
JOIN top_coins t
    ON date(o.Date) = date(t.Date)
WHERE t.coin_id = 'bitcoin'
AND t.price IS NOT NULL
AND o.price IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date  oil_price     btc_price
# 0    2025-05-27      61.61  9.314437e+06
# 1    2025-05-28      62.54  9.310175e+06
# 2    2025-05-29      61.66  9.208281e+06
# 3    2025-05-30      61.46  9.026593e+06
# 4    2025-06-02      63.27  9.040802e+06
# ..          ...        ...           ...
# 180  2026-02-17      62.53  6.255750e+06
# 181  2026-02-18      65.33  6.116330e+06
# 182  2026-02-19      66.66  6.033802e+06
# 183  2026-02-20      66.69  6.092367e+06
# 184  2026-02-23      66.36  6.132044e+06
#
# [185 rows x 3 columns]

# %%
# 5. Compare top 3 coins daily price trend vs Nifty (^NSEI).

df = pd.read_sql ("""
SELECT
    date(c.Date) AS date,
    c.coin_id AS coins,
    c.price AS coin_prices,
    s.Close AS nifty_close
FROM top_coins c
JOIN stks_prices s
    ON date(c.Date) = date(s.Date)
WHERE c.coin_id IN ('bitcoin', 'ethereum', 'binancecoin')
  AND s.Ticker = '^NSEI'
  AND c.price IS NOT NULL
  AND s.Close IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date     coins   coin_prices   nifty_close
# 0    2025-05-26  ethereum  2.169709e+05  25001.150391
# 1    2025-05-26   bitcoin  9.274976e+06  25001.150391
# 2    2025-05-27  ethereum  2.181907e+05  24826.199219
# 3    2025-05-27   bitcoin  9.314437e+06  24826.199219
# 4    2025-05-28   bitcoin  9.310175e+06  24752.449219
# ..          ...       ...           ...           ...
# 369  2026-02-18  ethereum  1.805283e+05  25819.349609
# 370  2026-02-19   bitcoin  6.033802e+06  25454.349609
# 371  2026-02-19  ethereum  1.774785e+05  25454.349609
# 372  2026-02-20   bitcoin  6.092367e+06  25571.250000
# 373  2026-02-20  ethereum  1.772492e+05  25571.250000
#
# [374 rows x 4 columns]

# %%
# 6. Compare stock prices (^GSPC) with crude oil prices on the same dates


df = pd.read_sql("""
SELECT
    date(s.Date) AS date,
    s.Close AS nifty_close,
    o.Price AS oil_price
FROM stks_prices s
JOIN oil_prices o
    ON date(s.Date) = date(o.Date)
WHERE s.Ticker = '^GSPC'
AND s.Close IS NOT NULL
AND o.Price IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#             date  nifty_close  oil_price
# 0     2020-01-02  3257.850098      61.17
# 1     2020-01-03  3234.850098      63.00
# 2     2020-01-06  3246.280029      63.27
# 3     2020-01-07  3237.179932      62.70
# 4     2020-01-08  3253.050049      59.65
# ...          ...          ...        ...
# 1529  2026-02-13  6836.169922      63.05
# 1530  2026-02-17  6843.220215      62.53
# 1531  2026-02-18  6881.310059      65.33
# 1532  2026-02-19  6861.890137      66.66
# 1533  2026-02-20  6909.509766      66.69
#
# [1534 rows x 3 columns]

# %%
# 7. Correlate Bitcoin closing price with crude oil closing price (same date)

df = pd.read_sql("""
SELECT
    date(t.Date) AS date,
    t.price AS btc_price,
    o.Price AS oil_price
FROM top_coins t
JOIN oil_prices o
    ON date(t.Date) = date(o.Date)
WHERE t.coin_id = 'bitcoin'
AND t.price IS NOT NULL
AND o.Price IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date     btc_price  oil_price
# 0    2025-05-27  9.314437e+06      61.61
# 1    2025-05-28  9.310175e+06      62.54
# 2    2025-05-29  9.208281e+06      61.66
# 3    2025-05-30  9.026593e+06      61.46
# 4    2025-06-02  9.040802e+06      63.27
# ..          ...           ...        ...
# 180  2026-02-17  6.255750e+06      62.53
# 181  2026-02-18  6.116330e+06      65.33
# 182  2026-02-19  6.033802e+06      66.66
# 183  2026-02-20  6.092367e+06      66.69
# 184  2026-02-23  6.132044e+06      66.36
#
# [185 rows x 3 columns]

# %%
# 8. Compare NASDAQ (^IXIC) with Ethereum price trends

df = pd.read_sql("""
SELECT
    date(t.Date) AS date,
    t.price AS eth_price,
    s.Close AS ixic_close
FROM top_coins t
JOIN stks_prices s
    ON date(t.Date) = date(s.Date)
WHERE t.coin_id = 'ethereum'
  AND s.Ticker = '^IXIC'
  AND t.price IS NOT NULL
  AND s.Close IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date      eth_price    ixic_close
# 0    2025-05-27  218190.675235  19199.160156
# 1    2025-05-28  227238.584850  19100.939453
# 2    2025-05-29  228525.939096  19175.869141
# 3    2025-05-30  224768.844035  19113.769531
# 4    2025-06-02  217089.574074  19242.609375
# ..          ...            ...           ...
# 181  2026-02-13  176214.238345  22546.669922
# 182  2026-02-17  181624.154700  22578.380859
# 183  2026-02-18  180528.328343  22753.630859
# 184  2026-02-19  177478.459914  22682.730469
# 185  2026-02-20  177249.247482  22886.070312
#
# [186 rows x 3 columns]

# %%
# 9. Join top 3 crypto coins with stock indices for 2025
df = pd.read_sql("""
SELECT
    DATE(c.Date) AS date,
    c.coin_id AS crypto_coin,
    c.price AS crypto_price,
    s.Ticker AS stock_index,
    s.Close AS stock_close
FROM top_coins c
JOIN stks_prices s
    ON DATE(c.Date) = DATE(s.Date)
WHERE c.coin_id IN ('bitcoin', 'ethereum', 'binancecoin')
AND s.Ticker IN ('^GSPC', '^IXIC', '^NSEI')
AND YEAR(c.Date) = 2025
AND c.price IS NOT NULL
AND s.Close IS NOT NULL
ORDER BY date, crypto_coin;
""", engine)

df
# Out:
#            date crypto_coin  crypto_price stock_index   stock_close
# 0    2025-05-26     bitcoin  9.274976e+06       ^NSEI  25001.150391
# 1    2025-05-26    ethereum  2.169709e+05       ^NSEI  25001.150391
# 2    2025-05-27     bitcoin  9.314437e+06       ^GSPC   5921.540039
# 3    2025-05-27     bitcoin  9.314437e+06       ^IXIC  19199.160156
# 4    2025-05-27     bitcoin  9.314437e+06       ^NSEI  24826.199219
# ..          ...         ...           ...         ...           ...
# 907  2025-12-31     bitcoin  7.936951e+06       ^IXIC  23241.990234
# 908  2025-12-31     bitcoin  7.936951e+06       ^NSEI  26129.599609
# 909  2025-12-31    ethereum  2.666209e+05       ^GSPC   6845.500000
# 910  2025-12-31    ethereum  2.666209e+05       ^IXIC  23241.990234
# 911  2025-12-31    ethereum  2.666209e+05       ^NSEI  26129.599609
#
# [912 rows x 5 columns]

# %%
# 10. Multi-join: stock prices, oil prices, and Bitcoin prices for daily comparison

df = pd.read_sql("""
SELECT
    date(t.Date) AS date,
    t.price AS btc_price,
    s.Close AS stk_close,
    o.Price AS oil_price
FROM top_coins t
JOIN stks_prices s
    ON date(t.Date) = date(s.Date)
JOIN oil_prices o
    ON date(t.Date) = date(o.Date)
WHERE t.coin_id = 'bitcoin'
  AND s.Ticker = '^GSPC'
  AND t.price IS NOT NULL
  AND s.Close IS NOT NULL
  AND o.Price IS NOT NULL
ORDER BY date;
""", engine)

df
# Out:
#            date     btc_price    stk_close  oil_price
# 0    2025-05-27  9.314437e+06  5921.540039      61.61
# 1    2025-05-28  9.310175e+06  5888.549805      62.54
# 2    2025-05-29  9.208281e+06  5912.169922      61.66
# 3    2025-05-30  9.026593e+06  5911.689941      61.46
# 4    2025-06-02  9.040802e+06  5935.939941      63.27
# ..          ...           ...          ...        ...
# 179  2026-02-13  5.993963e+06  6836.169922      63.05
# 180  2026-02-17  6.255750e+06  6843.220215      62.53
# 181  2026-02-18  6.116330e+06  6881.310059      65.33
# 182  2026-02-19  6.033802e+06  6861.890137      66.66
# 183  2026-02-20  6.092367e+06  6909.509766      66.69
#
# [184 rows x 4 columns]
